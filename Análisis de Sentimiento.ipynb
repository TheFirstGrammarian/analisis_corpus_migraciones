# %% [markdown]
# # Sentiment Analysis
#
#
# ## 1. Librerías

# %%
import pickle
import pandas as pd
import os
import requests
import re
import string
import sys
import meaningcloud
from collections import Counter

# %% [markdown]
# ## 2. Función sentiment y primera prueba
# Primero, definimos la función analizadora sentiment e intentamos utilizarla en uno de los textos del corpus

# %%
#Información importante
license_key = "" #se puede obtener registrándose en la página de meaningcloud.com
diccionario = {'ilang': 'es'} #se puede definir otros parámetros
#diccionario = 'migraciones'


#Definición de la función para hacer el análisis de sentimiento
def sentiment(texto):
    sentiment_response = meaningcloud.SentimentResponse(meaningcloud.SentimentRequest(license_key, lang='es', txt=texto, txtf='plain', otherparams=diccionario).sendReq())
    return(sentiment_response.getResponse())

#definición de función para quitar saltos de línea
def clean(text):
    '''Get rid of some additional punctuation and non-sensical text that was missed the first time around.'''
    text = re.sub('\n', ' ', text)
    return(text)

# %%
#abrimos el corpus y cargamos tan solo una nota para la prueba
with open("Corpus/El video sobre la brutal represión de la Policía de la Ciudad que censuró Facebook - ELDESTAPE", encoding='utf-8') as file:
    texto = file.read()

# %%
#Hacemos el análisis de sentimiento de esa nota e imprimimos el diccionario
sentiment(clean(texto))
# Out:
# {'status': {'code': '0',
#   'msg': 'OK',
#   'credits': '2',
#   'remaining_credits': '18661'},
#  'model': 'general_es',
#  'score_tag': 'N',
#  'agreement': 'DISAGREEMENT',
#  'subjectivity': 'SUBJECTIVE',
#  'confidence': '86',
#  'irony': 'NONIRONIC',
#  'sentence_list': [{'text': 'El video sobre la brutal represión de la Policía de la Ciudad que censuró Facebook Se trata de una grabación en la que se ve cómo los efectivos golpean a un vendedor senegalés con una fractura expuesta en el brazo.',
#    'inip': '0',
#    'endp': '214',
#    'bop': 'y',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'El video sobre la brutal represión de la Policía de la Ciudad que censuró Facebook Se trata de una grabación en la que se ve cómo los efectivos golpean a un vendedor senegalés con una fractura expuesta en el brazo',
#      'segment_type': 'main',
#      'inip': '0',
#      'endp': '213',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'golpear',
#        'inip': '145',
#        'endp': '151',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_concept_list': [{'form': 'grabación',
#          'id': 'affae0aef3',
#          'variant': 'grabación',
#          'inip': '100',
#          'endp': '108',
#          'type': 'Top',
#          'score_tag': 'N'},
#         {'form': 'efectivo',
#          'id': '015edcd94f',
#          'variant': 'efectivos',
#          'inip': '135',
#          'endp': '143',
#          'type': 'Top>Organization',
#          'score_tag': 'N'},
#         {'form': 'efectivo',
#          'id': '78a9d0e997',
#          'variant': 'efectivos',
#          'inip': '135',
#          'endp': '143',
#          'type': 'Top>Organization',
#          'score_tag': 'N'},
#         {'form': 'vendedor',
#          'id': 'dacecb32bc',
#          'variant': 'vendedor',
#          'inip': '158',
#          'endp': '165',
#          'type': 'Top>OtherEntity>Vocation',
#          'score_tag': 'N'},
#         {'form': 'fractura',
#          'id': '16ff59d24a',
#          'variant': 'fractura',
#          'inip': '185',
#          'endp': '192',
#          'type': 'Top>OtherEntity>Disease',
#          'score_tag': 'N'}]}],
#      'sentimented_entity_list': [{'form': 'Senegalés',
#        'id': '5d2df4f6a4caf',
#        'variant': 'senegalés',
#        'inip': '167',
#        'endp': '175',
#        'type': 'Top>Nacionalidad',
#        'score_tag': 'NONE'},
#       {'form': 'policía',
#        'id': '5d2df7073a370',
#        'variant': 'la Policía de la Ciudad',
#        'inip': '38',
#        'endp': '60',
#        'type': 'Top>Organization',
#        'score_tag': 'NONE'},
#       {'form': 'Facebook',
#        'id': 'e328525500',
#        'variant': 'Facebook',
#        'inip': '74',
#        'endp': '81',
#        'type': 'Top>Organization>Company>TechnologyCompany>SoftwareCompany',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'represión',
#        'id': '0387a12e30',
#        'variant': 'represión',
#        'inip': '25',
#        'endp': '33',
#        'type': 'Top',
#        'score_tag': 'NONE'},
#       {'form': 'brazo',
#        'id': '24cdb52d12',
#        'variant': 'brazo',
#        'inip': '209',
#        'endp': '213',
#        'type': 'Top>LivingThing>BodyPart',
#        'score_tag': 'NONE'}],
#      'segment_list': [{'text': 'la brutal represión de la Policía de la Ciudad que censuró Facebook',
#        'segment_type': 'main',
#        'inip': '15',
#        'endp': '81',
#        'confidence': '98',
#        'score_tag': 'N+',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': '(brutal) que censuró Facebook',
#          'inip': '15',
#          'endp': '81',
#          'confidence': '98',
#          'score_tag': 'N+',
#          'sentimented_entity_list': [{'form': 'policía',
#            'id': '5d2df7073a370',
#            'variant': 'la Policía de la Ciudad',
#            'inip': '38',
#            'endp': '60',
#            'type': 'Top>Organization',
#            'score_tag': 'N+'}],
#          'sentimented_concept_list': [{'form': 'represión',
#            'id': '0387a12e30',
#            'variant': 'represión',
#            'inip': '25',
#            'endp': '33',
#            'type': 'Top',
#            'score_tag': 'N+'}]}],
#        'sentimented_entity_list': [{'form': 'Facebook',
#          'id': 'e328525500',
#          'variant': 'Facebook',
#          'inip': '74',
#          'endp': '81',
#          'type': 'Top>Organization>Company>TechnologyCompany>SoftwareCompany',
#          'score_tag': 'NONE'}]},
#       {'text': 'con una fractura expuesta en el brazo',
#        'segment_type': 'main',
#        'inip': '177',
#        'endp': '213',
#        'confidence': '100',
#        'score_tag': 'N',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'fractura',
#          'inip': '185',
#          'endp': '192',
#          'confidence': '100',
#          'score_tag': 'N',
#          'sentimented_concept_list': [{'form': 'fractura',
#            'id': '16ff59d24a',
#            'variant': 'fractura',
#            'inip': '185',
#            'endp': '192',
#            'type': 'Top>OtherEntity>Disease',
#            'score_tag': 'N'}]}],
#        'sentimented_concept_list': [{'form': 'brazo',
#          'id': '24cdb52d12',
#          'variant': 'brazo',
#          'inip': '209',
#          'endp': '213',
#          'type': 'Top>LivingThing>BodyPart',
#          'score_tag': 'NONE'}]}]}],
#    'sentimented_entity_list': [{'form': 'Senegalés',
#      'id': '5d2df4f6a4caf',
#      'type': 'Top>Nacionalidad',
#      'score_tag': 'NONE'},
#     {'form': 'policía',
#      'id': '5d2df7073a370',
#      'type': 'Top>Organization',
#      'score_tag': 'N+'},
#     {'form': 'Facebook',
#      'id': 'e328525500',
#      'type': 'Top>Organization>Company>TechnologyCompany>SoftwareCompany',
#      'score_tag': 'NEU'}],
#    'sentimented_concept_list': [{'form': 'efectivo',
#      'id': '015edcd94f',
#      'type': 'Top>Organization',
#      'score_tag': 'N'},
#     {'form': 'represión',
#      'id': '0387a12e30',
#      'type': 'Top',
#      'score_tag': 'N+'},
#     {'form': 'fractura',
#      'id': '16ff59d24a',
#      'type': 'Top>OtherEntity>Disease',
#      'score_tag': 'N'},
#     {'form': 'brazo',
#      'id': '24cdb52d12',
#      'type': 'Top>LivingThing>BodyPart',
#      'score_tag': 'NONE'},
#     {'form': 'efectivo',
#      'id': '78a9d0e997',
#      'type': 'Top>Organization',
#      'score_tag': 'N'},
#     {'form': 'grabación', 'id': 'affae0aef3', 'type': 'Top', 'score_tag': 'N'},
#     {'form': 'vendedor',
#      'id': 'dacecb32bc',
#      'type': 'Top>OtherEntity>Vocation',
#      'score_tag': 'N'}]},
#   {'text': '07 de junio 2018 Una vez más la represión, una vez más la censura de Facebook a los medios de comunicación que muestran la realidad.',
#    'inip': '217',
#    'endp': '350',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': '07 de junio 2018 Una vez más la represión, una vez más la censura de Facebook a los medios de comunicación que muestran la realidad',
#      'segment_type': 'main',
#      'inip': '217',
#      'endp': '349',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'represión',
#        'inip': '251',
#        'endp': '259',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_entity_list': [{'form': 'Facebook',
#          'id': 'e328525500',
#          'variant': 'Facebook',
#          'inip': '288',
#          'endp': '295',
#          'type': 'Top>Organization>Company>TechnologyCompany>SoftwareCompany',
#          'score_tag': 'N'}],
#        'sentimented_concept_list': [{'form': 'represión',
#          'id': '0387a12e30',
#          'variant': 'represión',
#          'inip': '251',
#          'endp': '259',
#          'type': 'Top',
#          'score_tag': 'N'},
#         {'form': 'censura',
#          'id': '4b94fed85b',
#          'variant': 'censura',
#          'inip': '277',
#          'endp': '283',
#          'type': 'Top',
#          'score_tag': 'N'}]},
#       {'text': 'censura',
#        'inip': '277',
#        'endp': '283',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_entity_list': [{'form': 'Facebook',
#          'id': 'e328525500',
#          'variant': 'Facebook',
#          'inip': '288',
#          'endp': '295',
#          'type': 'Top>Organization>Company>TechnologyCompany>SoftwareCompany',
#          'score_tag': 'N'}],
#        'sentimented_concept_list': [{'form': 'represión',
#          'id': '0387a12e30',
#          'variant': 'represión',
#          'inip': '251',
#          'endp': '259',
#          'type': 'Top',
#          'score_tag': 'N'},
#         {'form': 'censura',
#          'id': '4b94fed85b',
#          'variant': 'censura',
#          'inip': '277',
#          'endp': '283',
#          'type': 'Top',
#          'score_tag': 'N'}]}]}],
#    'sentimented_entity_list': [{'form': 'Facebook',
#      'id': 'e328525500',
#      'type': 'Top>Organization>Company>TechnologyCompany>SoftwareCompany',
#      'score_tag': 'N'}],
#    'sentimented_concept_list': [{'form': 'represión',
#      'id': '0387a12e30',
#      'type': 'Top',
#      'score_tag': 'N'},
#     {'form': 'censura', 'id': '4b94fed85b', 'type': 'Top', 'score_tag': 'N'}]},
#   {'text': 'La red social inhabilitó a Revista Cítrica a agregar contenido a su página luego de publicar el video en el que se muestra la brutalidad con la que la Policía de la Ciudad golpeó a un vendedor senegalés en la calle este martes.',
#    'inip': '352',
#    'endp': '578',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'La red social inhabilitó a Revista Cítrica a agregar contenido a su página luego de publicar el video en el que se muestra la brutalidad con la que la Policía de la Ciudad golpeó a un vendedor senegalés en la calle este martes',
#      'segment_type': 'main',
#      'inip': '352',
#      'endp': '577',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'inhabilitar',
#        'inip': '366',
#        'endp': '375',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_entity_list': [{'form': 'Revista Cítrica',
#          'id': '5d2f2d398671f',
#          'variant': 'Revista Cítrica',
#          'inip': '379',
#          'endp': '393',
#          'type': 'Top>Organization',
#          'score_tag': 'N'}],
#        'sentimented_concept_list': [{'form': 'red social',
#          'id': '1f1d00751f',
#          'variant': 'red social',
#          'inip': '355',
#          'endp': '364',
#          'type': 'Top',
#          'score_tag': 'N'}]}],
#      'sentimented_entity_list': [{'form': 'Senegalés',
#        'id': '5d2df4f6a4caf',
#        'variant': 'senegalés',
#        'inip': '545',
#        'endp': '553',
#        'type': 'Top>Nacionalidad',
#        'score_tag': 'NONE'},
#       {'form': 'policía',
#        'id': '5d2df7073a370',
#        'variant': 'la Policía de la Ciudad',
#        'inip': '500',
#        'endp': '522',
#        'type': 'Top>Organization',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'calle',
#        'id': '13f4067384',
#        'variant': 'calle',
#        'inip': '561',
#        'endp': '565',
#        'type': 'Top>Location>Facility>Line',
#        'score_tag': 'NONE'},
#       {'form': 'página',
#        'id': '773b6d6f59',
#        'variant': 'página',
#        'inip': '420',
#        'endp': '425',
#        'type': 'Top>Product>CulturalProduct>Printing',
#        'score_tag': 'NONE'},
#       {'form': 'martes',
#        'id': '90cb92e5fb',
#        'variant': 'martes',
#        'inip': '572',
#        'endp': '577',
#        'type': 'Top>Unit>TimeUnit>Day',
#        'score_tag': 'NONE'},
#       {'form': 'vendedor',
#        'id': 'dacecb32bc',
#        'variant': 'vendedor',
#        'inip': '536',
#        'endp': '543',
#        'type': 'Top>OtherEntity>Vocation',
#        'score_tag': 'NONE'}],
#      'segment_list': [{'text': 'la brutalidad con la que la Policía de la Ciudad golpeó a un vendedor senegalés en la calle este martes',
#        'segment_type': 'main',
#        'inip': '475',
#        'endp': '577',
#        'confidence': '100',
#        'score_tag': 'N',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'golpear',
#          'inip': '524',
#          'endp': '529',
#          'confidence': '100',
#          'score_tag': 'N',
#          'sentimented_entity_list': [{'form': 'policía',
#            'id': '5d2df7073a370',
#            'variant': 'la Policía de la Ciudad',
#            'inip': '500',
#            'endp': '522',
#            'type': 'Top>Organization',
#            'score_tag': 'N'}],
#          'sentimented_concept_list': [{'form': 'página',
#            'id': '773b6d6f59',
#            'variant': 'página',
#            'inip': '420',
#            'endp': '425',
#            'type': 'Top>Product>CulturalProduct>Printing',
#            'score_tag': 'N'},
#           {'form': 'vendedor',
#            'id': 'dacecb32bc',
#            'variant': 'vendedor',
#            'inip': '536',
#            'endp': '543',
#            'type': 'Top>OtherEntity>Vocation',
#            'score_tag': 'N'},
#           {'form': 'calle',
#            'id': '13f4067384',
#            'variant': 'calle',
#            'inip': '561',
#            'endp': '565',
#            'type': 'Top>Location>Facility>Line',
#            'score_tag': 'N'}]}],
#        'sentimented_entity_list': [{'form': 'Senegalés',
#          'id': '5d2df4f6a4caf',
#          'variant': 'senegalés',
#          'inip': '545',
#          'endp': '553',
#          'type': 'Top>Nacionalidad',
#          'score_tag': 'NONE'}],
#        'sentimented_concept_list': [{'form': 'martes',
#          'id': '90cb92e5fb',
#          'variant': 'martes',
#          'inip': '572',
#          'endp': '577',
#          'type': 'Top>Unit>TimeUnit>Day',
#          'score_tag': 'NONE'}]}]}],
#    'sentimented_entity_list': [{'form': 'Senegalés',
#      'id': '5d2df4f6a4caf',
#      'type': 'Top>Nacionalidad',
#      'score_tag': 'NONE'},
#     {'form': 'policía',
#      'id': '5d2df7073a370',
#      'type': 'Top>Organization',
#      'score_tag': 'N'},
#     {'form': 'Revista Cítrica',
#      'id': '5d2f2d398671f',
#      'type': 'Top>Organization',
#      'score_tag': 'N'}],
#    'sentimented_concept_list': [{'form': 'calle',
#      'id': '13f4067384',
#      'type': 'Top>Location>Facility>Line',
#      'score_tag': 'N'},
#     {'form': 'red social',
#      'id': '1f1d00751f',
#      'type': 'Top',
#      'score_tag': 'N'},
#     {'form': 'página',
#      'id': '773b6d6f59',
#      'type': 'Top>Product>CulturalProduct>Printing',
#      'score_tag': 'N'},
#     {'form': 'martes',
#      'id': '90cb92e5fb',
#      'type': 'Top>Unit>TimeUnit>Day',
#      'score_tag': 'NONE'},
#     {'form': 'vendedor',
#      'id': 'dacecb32bc',
#      'type': 'Top>OtherEntity>Vocation',
#      'score_tag': 'N'}]},
#   {'text': 'El medio denunció este “acto que coarta el derecho a la información” y resaltó que 24 horas después, “en el día del periodista”, Facebook les "’regaló’ la posibilidad de volver a informar” en su fan page.',
#    'inip': '581',
#    'endp': '784',
#    'bop': 'n',
#    'confidence': '94',
#    'score_tag': 'NEU',
#    'agreement': 'DISAGREEMENT',
#    'segment_list': [{'text': 'El medio denunció este “acto que coarta el derecho a la información”',
#      'segment_type': 'main',
#      'inip': '581',
#      'endp': '648',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'denunciar',
#        'inip': '590',
#        'endp': '597',
#        'confidence': '100',
#        'score_tag': 'N'}],
#      'sentimented_concept_list': [{'form': 'derecho a la información',
#        'id': '3ae2457b18',
#        'variant': 'derecho a la información',
#        'inip': '624',
#        'endp': '647',
#        'type': 'Top',
#        'score_tag': 'NONE'},
#       {'form': 'ceremonia',
#        'id': '54236208be',
#        'variant': 'acto',
#        'inip': '605',
#        'endp': '608',
#        'type': 'Top>Event>Occasion',
#        'score_tag': 'NONE'},
#       {'form': 'derecho a la información',
#        'id': '5a73bd1f24',
#        'variant': 'derecho a la información',
#        'inip': '624',
#        'endp': '647',
#        'type': 'Top',
#        'score_tag': 'NONE'},
#       {'form': 'acto',
#        'id': '8a9b9f5c9c',
#        'variant': 'acto',
#        'inip': '605',
#        'endp': '608',
#        'type': 'Top>OtherEntity>Rule',
#        'score_tag': 'NONE'},
#       {'form': 'acto',
#        'id': 'ae6d6f2e1a',
#        'variant': 'acto',
#        'inip': '605',
#        'endp': '608',
#        'type': 'Top>Process',
#        'score_tag': 'NONE'},
#       {'form': 'acto',
#        'id': 'b89ae739f1',
#        'variant': 'acto',
#        'inip': '605',
#        'endp': '608',
#        'type': 'Top>Product>CulturalProduct>Composition',
#        'score_tag': 'NONE'}]},
#     {'text': 'resaltó',
#      'segment_type': 'secondary',
#      'inip': '652',
#      'endp': '658',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': []},
#     {'text': '24 horas después, “en el día del periodista”, Facebook les "’regaló’ la posibilidad de volver a informar” en su fan page',
#      'segment_type': 'main',
#      'inip': '664',
#      'endp': '783',
#      'confidence': '100',
#      'score_tag': 'P',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'regalar',
#        'inip': '725',
#        'endp': '730',
#        'confidence': '100',
#        'score_tag': 'P',
#        'sentimented_entity_list': [{'form': 'Facebook',
#          'id': 'e328525500',
#          'variant': 'Facebook',
#          'inip': '710',
#          'endp': '717',
#          'type': 'Top>Organization>Company>TechnologyCompany>SoftwareCompany',
#          'score_tag': 'P'}],
#        'sentimented_concept_list': [{'form': 'admirador',
#          'id': '073afdc39c',
#          'variant': 'fan',
#          'inip': '776',
#          'endp': '778',
#          'type': 'Top>Person',
#          'score_tag': 'P'}]}],
#      'sentimented_concept_list': [{'form': 'periodista',
#        'id': '0d2a86e544',
#        'variant': 'periodista',
#        'inip': '697',
#        'endp': '706',
#        'type': 'Top>OtherEntity>Vocation',
#        'score_tag': 'NONE'}],
#      'segment_list': [{'text': '"’regaló’ la posibilidad de volver a informar”',
#        'segment_type': 'main',
#        'inip': '723',
#        'endp': '768',
#        'confidence': '100',
#        'score_tag': 'P',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'regalar',
#          'inip': '725',
#          'endp': '730',
#          'confidence': '100',
#          'score_tag': 'P'}]}]}],
#    'sentimented_entity_list': [{'form': 'Facebook',
#      'id': 'e328525500',
#      'type': 'Top>Organization>Company>TechnologyCompany>SoftwareCompany',
#      'score_tag': 'P'}],
#    'sentimented_concept_list': [{'form': 'admirador',
#      'id': '073afdc39c',
#      'type': 'Top>Person',
#      'score_tag': 'P'},
#     {'form': 'periodista',
#      'id': '0d2a86e544',
#      'type': 'Top>OtherEntity>Vocation',
#      'score_tag': 'NONE'},
#     {'form': 'derecho a la información',
#      'id': '3ae2457b18',
#      'type': 'Top',
#      'score_tag': 'NONE'},
#     {'form': 'ceremonia',
#      'id': '54236208be',
#      'type': 'Top>Event>Occasion',
#      'score_tag': 'NONE'},
#     {'form': 'derecho a la información',
#      'id': '5a73bd1f24',
#      'type': 'Top',
#      'score_tag': 'NONE'},
#     {'form': 'acto',
#      'id': '8a9b9f5c9c',
#      'type': 'Top>OtherEntity>Rule',
#      'score_tag': 'NONE'},
#     {'form': 'acto',
#      'id': 'ae6d6f2e1a',
#      'type': 'Top>Process',
#      'score_tag': 'NONE'},
#     {'form': 'acto',
#      'id': 'b89ae739f1',
#      'type': 'Top>Product>CulturalProduct>Composition',
#      'score_tag': 'NONE'}]},
#   {'text': 'ATENCIÓN:',
#    'inip': '787',
#    'endp': '795',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'NONE',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'ATENCIÓN:',
#      'segment_type': 'secondary',
#      'inip': '787',
#      'endp': '795',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': []}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': []},
#   {'text': 'IMÁGENES SENSIBLES Por esto fue que en Facebook no pudieron mostrar, además, la marcha que realizaron los trabajadores ambulantes y vendedores callejeros senegaleses en protesta a la brutal represión que dejó a Kane Serigne Dame con el brazo ensangrentado y una fractura expuesta tirado sobre la vereda mientras le seguían pegando, y, más tarde, hospitalizado y detenido.',
#    'inip': '797',
#    'endp': '1168',
#    'bop': 'n',
#    'confidence': '97',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'IMÁGENES SENSIBLES Por esto fue que en Facebook no pudieron mostrar, además',
#      'segment_type': 'main',
#      'inip': '797',
#      'endp': '872',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_entity_list': [{'form': 'Facebook',
#        'id': 'e328525500',
#        'variant': 'Facebook',
#        'inip': '837',
#        'endp': '844',
#        'type': 'Top>Organization>Company>TechnologyCompany>SoftwareCompany',
#        'score_tag': 'NONE'}]},
#     {'text': 'la marcha que realizaron los trabajadores ambulantes y vendedores callejeros senegaleses en protesta a la brutal represión que dejó a Kane Serigne Dame con el brazo ensangrentado',
#      'segment_type': 'main',
#      'inip': '875',
#      'endp': '1052',
#      'confidence': '97',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'dar>fractura',
#        'inip': '1022',
#        'endp': '1025',
#        'confidence': '97',
#        'score_tag': 'N',
#        'sentimented_concept_list': [{'form': 'brazo',
#          'id': '24cdb52d12',
#          'variant': 'brazo',
#          'inip': '1034',
#          'endp': '1038',
#          'type': 'Top>LivingThing>BodyPart',
#          'score_tag': 'N'}]}],
#      'sentimented_entity_list': [{'form': 'Senegalés',
#        'id': '5d2df4f6a4caf',
#        'variant': 'senegaleses',
#        'inip': '952',
#        'endp': '962',
#        'type': 'Top>Nacionalidad',
#        'score_tag': 'NONE'},
#       {'form': 'Serigne Dame Kane',
#        'id': '5d2dfcf0ae119',
#        'variant': 'Kane Serigne',
#        'inip': '1009',
#        'endp': '1020',
#        'type': 'Top>Person',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'represión',
#        'id': '0387a12e30',
#        'variant': 'represión',
#        'inip': '988',
#        'endp': '996',
#        'type': 'Top',
#        'score_tag': 'NONE'},
#       {'form': 'trabajador',
#        'id': '04956a16c6',
#        'variant': 'trabajadores',
#        'inip': '904',
#        'endp': '915',
#        'type': 'Top>OtherEntity>Vocation',
#        'score_tag': 'NONE'},
#       {'form': 'vendedor callejero',
#        'id': '3154aa53dc',
#        'variant': 'vendedores callejeros',
#        'inip': '930',
#        'endp': '950',
#        'type': 'Top',
#        'score_tag': 'NONE'}],
#      'segment_list': [{'text': 'la brutal represión que dejó a Kane Serigne',
#        'segment_type': 'main',
#        'inip': '978',
#        'endp': '1020',
#        'confidence': '100',
#        'score_tag': 'N+',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'brutal',
#          'inip': '978',
#          'endp': '1020',
#          'confidence': '100',
#          'score_tag': 'N+',
#          'sentimented_concept_list': [{'form': 'represión',
#            'id': '0387a12e30',
#            'variant': 'represión',
#            'inip': '988',
#            'endp': '996',
#            'type': 'Top',
#            'score_tag': 'N+'}]}],
#        'sentimented_entity_list': [{'form': 'Serigne Dame Kane',
#          'id': '5d2dfcf0ae119',
#          'variant': 'Kane Serigne',
#          'inip': '1009',
#          'endp': '1020',
#          'type': 'Top>Person',
#          'score_tag': 'NONE'}]}]},
#     {'text': 'una fractura expuesta tirado sobre la vereda mientras le seguían pegando',
#      'segment_type': 'main',
#      'inip': '1056',
#      'endp': '1127',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'pegar',
#        'inip': '1113',
#        'endp': '1127',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_concept_list': [{'form': 'fractura',
#          'id': '16ff59d24a',
#          'variant': 'fractura',
#          'inip': '1060',
#          'endp': '1067',
#          'type': 'Top>OtherEntity>Disease',
#          'score_tag': 'N'}]}],
#      'sentimented_concept_list': [{'form': 'camino',
#        'id': '52b872ac4d',
#        'variant': 'vereda',
#        'inip': '1094',
#        'endp': '1099',
#        'type': 'Top>Location>Facility>Line',
#        'score_tag': 'NONE'}]},
#     {'text': 'más tarde, hospitalizado y detenido',
#      'segment_type': 'main',
#      'inip': '1133',
#      'endp': '1167',
#      'confidence': '98',
#      'score_tag': 'N+',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': '(más) tarde@E',
#        'inip': '1137',
#        'endp': '1141',
#        'confidence': '98',
#        'score_tag': 'N+',
#        'sentimented_concept_list': [{'form': 'detenido',
#          'id': 'd7b05994d8',
#          'variant': 'detenido',
#          'inip': '1160',
#          'endp': '1167',
#          'type': 'Top',
#          'score_tag': 'N+'}]},
#       {'text': 'hospitalizar',
#        'inip': '1144',
#        'endp': '1156',
#        'confidence': '100',
#        'score_tag': 'N+',
#        'sentimented_concept_list': [{'form': 'detenido',
#          'id': 'd7b05994d8',
#          'variant': 'detenido',
#          'inip': '1160',
#          'endp': '1167',
#          'type': 'Top',
#          'score_tag': 'N+'}]},
#       {'text': 'detenido',
#        'inip': '1160',
#        'endp': '1167',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_concept_list': [{'form': 'detenido',
#          'id': 'd7b05994d8',
#          'variant': 'detenido',
#          'inip': '1160',
#          'endp': '1167',
#          'type': 'Top',
#          'score_tag': 'N'}]}],
#      'segment_list': [{'text': 'hospitalizado y detenido',
#        'segment_type': 'main',
#        'inip': '1144',
#        'endp': '1167',
#        'confidence': '100',
#        'score_tag': 'N+',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'hospitalizar',
#          'inip': '1144',
#          'endp': '1156',
#          'confidence': '100',
#          'score_tag': 'N+',
#          'sentimented_concept_list': [{'form': 'detenido',
#            'id': 'd7b05994d8',
#            'variant': 'detenido',
#            'inip': '1160',
#            'endp': '1167',
#            'type': 'Top',
#            'score_tag': 'N+'}]},
#         {'text': 'detenido',
#          'inip': '1160',
#          'endp': '1167',
#          'confidence': '100',
#          'score_tag': 'N',
#          'sentimented_concept_list': [{'form': 'detenido',
#            'id': 'd7b05994d8',
#            'variant': 'detenido',
#            'inip': '1160',
#            'endp': '1167',
#            'type': 'Top',
#            'score_tag': 'N'}]}]}]}],
#    'sentimented_entity_list': [{'form': 'Senegalés',
#      'id': '5d2df4f6a4caf',
#      'type': 'Top>Nacionalidad',
#      'score_tag': 'NONE'},
#     {'form': 'Serigne Dame Kane',
#      'id': '5d2dfcf0ae119',
#      'type': 'Top>Person',
#      'score_tag': 'NONE'},
#     {'form': 'Facebook',
#      'id': 'e328525500',
#      'type': 'Top>Organization>Company>TechnologyCompany>SoftwareCompany',
#      'score_tag': 'NONE'}],
#    'sentimented_concept_list': [{'form': 'represión',
#      'id': '0387a12e30',
#      'type': 'Top',
#      'score_tag': 'N+'},
#     {'form': 'trabajador',
#      'id': '04956a16c6',
#      'type': 'Top>OtherEntity>Vocation',
#      'score_tag': 'N+'},
#     {'form': 'fractura',
#      'id': '16ff59d24a',
#      'type': 'Top>OtherEntity>Disease',
#      'score_tag': 'N'},
#     {'form': 'brazo',
#      'id': '24cdb52d12',
#      'type': 'Top>LivingThing>BodyPart',
#      'score_tag': 'N'},
#     {'form': 'vendedor callejero',
#      'id': '3154aa53dc',
#      'type': 'Top',
#      'score_tag': 'N+'},
#     {'form': 'camino',
#      'id': '52b872ac4d',
#      'type': 'Top>Location>Facility>Line',
#      'score_tag': 'NONE'},
#     {'form': 'detenido',
#      'id': 'd7b05994d8',
#      'type': 'Top',
#      'score_tag': 'N+'}]},
#   {'text': 'Más imágenes que no nos dejó subir Facebook y que tampoco aparecen en la tele.',
#    'inip': '1175',
#    'endp': '1252',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'NONE',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Más imágenes que no nos dejó subir Facebook y que tampoco aparecen en la tele',
#      'segment_type': 'main',
#      'inip': '1175',
#      'endp': '1251',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_entity_list': [{'form': 'Facebook',
#        'id': 'e328525500',
#        'variant': 'Facebook',
#        'inip': '1210',
#        'endp': '1217',
#        'type': 'Top>Organization>Company>TechnologyCompany>SoftwareCompany',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [{'form': 'Facebook',
#      'id': 'e328525500',
#      'type': 'Top>Organization>Company>TechnologyCompany>SoftwareCompany',
#      'score_tag': 'NONE'}],
#    'sentimented_concept_list': []},
#   {'text': 'La marcha de hoy, por la avenida Avellaneda, en reclamo por la violenta represión contra Kane Serigne Dame, a quien hoy entrevistamos.',
#    'inip': '1254',
#    'endp': '1387',
#    'bop': 'n',
#    'confidence': '94',
#    'score_tag': 'NEU',
#    'agreement': 'DISAGREEMENT',
#    'segment_list': [{'text': 'La marcha de hoy, por la avenida Avellaneda, en reclamo por la violenta represión contra Kane Serigne Dame, a quien hoy entrevistamos',
#      'segment_type': 'main',
#      'inip': '1254',
#      'endp': '1386',
#      'confidence': '100',
#      'score_tag': 'NEU',
#      'agreement': 'DISAGREEMENT',
#      'polarity_term_list': [{'text': 'reclamo',
#        'inip': '1302',
#        'endp': '1308',
#        'confidence': '100',
#        'score_tag': 'P',
#        'sentimented_entity_list': [{'form': 'avenida Avellaneda',
#          'id': '__19857996936203458',
#          'variant': 'avenida Avellaneda',
#          'inip': '1279',
#          'endp': '1296',
#          'type': 'Top>Location>Address',
#          'score_tag': 'P'},
#         {'form': 'Serigne Dame Kane',
#          'id': '5d2dfcf0ae119',
#          'variant': 'Kane Serigne',
#          'inip': '1343',
#          'endp': '1354',
#          'type': 'Top>Person',
#          'score_tag': 'P'}],
#        'sentimented_concept_list': [{'form': 'violento',
#          'id': '15a8050fe2',
#          'variant': 'violenta',
#          'inip': '1317',
#          'endp': '1324',
#          'type': 'Top',
#          'score_tag': 'P'},
#         {'form': 'represión',
#          'id': '0387a12e30',
#          'variant': 'represión',
#          'inip': '1326',
#          'endp': '1334',
#          'type': 'Top',
#          'score_tag': 'P'}]},
#       {'text': 'violento',
#        'inip': '1317',
#        'endp': '1324',
#        'confidence': '100',
#        'score_tag': 'N+',
#        'sentimented_entity_list': [{'form': 'avenida Avellaneda',
#          'id': '__19857996936203458',
#          'variant': 'avenida Avellaneda',
#          'inip': '1279',
#          'endp': '1296',
#          'type': 'Top>Location>Address',
#          'score_tag': 'N+'},
#         {'form': 'Serigne Dame Kane',
#          'id': '5d2dfcf0ae119',
#          'variant': 'Kane Serigne',
#          'inip': '1343',
#          'endp': '1354',
#          'type': 'Top>Person',
#          'score_tag': 'N+'}],
#        'sentimented_concept_list': [{'form': 'violento',
#          'id': '15a8050fe2',
#          'variant': 'violenta',
#          'inip': '1317',
#          'endp': '1324',
#          'type': 'Top',
#          'score_tag': 'N+'},
#         {'form': 'represión',
#          'id': '0387a12e30',
#          'variant': 'represión',
#          'inip': '1326',
#          'endp': '1334',
#          'type': 'Top',
#          'score_tag': 'N+'}]},
#       {'text': 'represión',
#        'inip': '1326',
#        'endp': '1334',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_entity_list': [{'form': 'avenida Avellaneda',
#          'id': '__19857996936203458',
#          'variant': 'avenida Avellaneda',
#          'inip': '1279',
#          'endp': '1296',
#          'type': 'Top>Location>Address',
#          'score_tag': 'N'},
#         {'form': 'Serigne Dame Kane',
#          'id': '5d2dfcf0ae119',
#          'variant': 'Kane Serigne',
#          'inip': '1343',
#          'endp': '1354',
#          'type': 'Top>Person',
#          'score_tag': 'N'}],
#        'sentimented_concept_list': [{'form': 'violento',
#          'id': '15a8050fe2',
#          'variant': 'violenta',
#          'inip': '1317',
#          'endp': '1324',
#          'type': 'Top',
#          'score_tag': 'N'},
#         {'form': 'represión',
#          'id': '0387a12e30',
#          'variant': 'represión',
#          'inip': '1326',
#          'endp': '1334',
#          'type': 'Top',
#          'score_tag': 'N'}]},
#       {'text': 'contra',
#        'inip': '1336',
#        'endp': '1341',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_entity_list': [{'form': 'avenida Avellaneda',
#          'id': '__19857996936203458',
#          'variant': 'avenida Avellaneda',
#          'inip': '1279',
#          'endp': '1296',
#          'type': 'Top>Location>Address',
#          'score_tag': 'N'},
#         {'form': 'Serigne Dame Kane',
#          'id': '5d2dfcf0ae119',
#          'variant': 'Kane Serigne',
#          'inip': '1343',
#          'endp': '1354',
#          'type': 'Top>Person',
#          'score_tag': 'N'}],
#        'sentimented_concept_list': [{'form': 'violento',
#          'id': '15a8050fe2',
#          'variant': 'violenta',
#          'inip': '1317',
#          'endp': '1324',
#          'type': 'Top',
#          'score_tag': 'N'},
#         {'form': 'represión',
#          'id': '0387a12e30',
#          'variant': 'represión',
#          'inip': '1326',
#          'endp': '1334',
#          'type': 'Top',
#          'score_tag': 'N'}]}],
#      'segment_list': [{'text': 'la violenta represión contra Kane Serigne',
#        'segment_type': 'main',
#        'inip': '1314',
#        'endp': '1354',
#        'confidence': '100',
#        'score_tag': 'N',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'violento',
#          'inip': '1317',
#          'endp': '1324',
#          'confidence': '100',
#          'score_tag': 'N+',
#          'sentimented_entity_list': [{'form': 'Serigne Dame Kane',
#            'id': '5d2dfcf0ae119',
#            'variant': 'Kane Serigne',
#            'inip': '1343',
#            'endp': '1354',
#            'type': 'Top>Person',
#            'score_tag': 'N+'}],
#          'sentimented_concept_list': [{'form': 'violento',
#            'id': '15a8050fe2',
#            'variant': 'violenta',
#            'inip': '1317',
#            'endp': '1324',
#            'type': 'Top',
#            'score_tag': 'N+'},
#           {'form': 'represión',
#            'id': '0387a12e30',
#            'variant': 'represión',
#            'inip': '1326',
#            'endp': '1334',
#            'type': 'Top',
#            'score_tag': 'N+'}]},
#         {'text': 'represión',
#          'inip': '1326',
#          'endp': '1334',
#          'confidence': '100',
#          'score_tag': 'N',
#          'sentimented_entity_list': [{'form': 'Serigne Dame Kane',
#            'id': '5d2dfcf0ae119',
#            'variant': 'Kane Serigne',
#            'inip': '1343',
#            'endp': '1354',
#            'type': 'Top>Person',
#            'score_tag': 'N'}],
#          'sentimented_concept_list': [{'form': 'violento',
#            'id': '15a8050fe2',
#            'variant': 'violenta',
#            'inip': '1317',
#            'endp': '1324',
#            'type': 'Top',
#            'score_tag': 'N'},
#           {'form': 'represión',
#            'id': '0387a12e30',
#            'variant': 'represión',
#            'inip': '1326',
#            'endp': '1334',
#            'type': 'Top',
#            'score_tag': 'N'}]},
#         {'text': 'contra',
#          'inip': '1336',
#          'endp': '1341',
#          'confidence': '100',
#          'score_tag': 'N',
#          'sentimented_entity_list': [{'form': 'Serigne Dame Kane',
#            'id': '5d2dfcf0ae119',
#            'variant': 'Kane Serigne',
#            'inip': '1343',
#            'endp': '1354',
#            'type': 'Top>Person',
#            'score_tag': 'N'}],
#          'sentimented_concept_list': [{'form': 'violento',
#            'id': '15a8050fe2',
#            'variant': 'violenta',
#            'inip': '1317',
#            'endp': '1324',
#            'type': 'Top',
#            'score_tag': 'N'},
#           {'form': 'represión',
#            'id': '0387a12e30',
#            'variant': 'represión',
#            'inip': '1326',
#            'endp': '1334',
#            'type': 'Top',
#            'score_tag': 'N'}]}]}]}],
#    'sentimented_entity_list': [{'form': 'Serigne Dame Kane',
#      'id': '5d2dfcf0ae119',
#      'type': 'Top>Person',
#      'score_tag': 'N'},
#     {'form': 'avenida Avellaneda',
#      'id': '__19857996936203458',
#      'type': 'Top>Location>Address',
#      'score_tag': 'NEU'}],
#    'sentimented_concept_list': [{'form': 'represión',
#      'id': '0387a12e30',
#      'type': 'Top',
#      'score_tag': 'N'},
#     {'form': 'violento',
#      'id': '15a8050fe2',
#      'type': 'Top',
#      'score_tag': 'N'}]},
#   {'text': 'pic.twitter.com/EJ65aW0Nur',
#    'inip': '1389',
#    'endp': '1414',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'NONE',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'pic.twitter.com/EJ65aW0Nur',
#      'segment_type': 'secondary',
#      'inip': '1389',
#      'endp': '1414',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_entity_list': [{'form': 'pic.twitter.com/EJ65aW0Nur',
#        'id': '__12324353272857338254',
#        'variant': 'pic.twitter.com/EJ65aW0Nur',
#        'inip': '1389',
#        'endp': '1414',
#        'type': 'Top>Id>Url',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [{'form': 'pic.twitter.com/EJ65aW0Nur',
#      'id': '__12324353272857338254',
#      'type': 'Top>Id>Url',
#      'score_tag': 'NONE'}],
#    'sentimented_concept_list': []},
#   {'text': '— Revista Cítrica (@revistacitrica) 6 de junio de 2018 Tampoco pudieron mostrar una entrevista que le hicieron a Kane, en la que él cuenta como puede, con su poco manejo del castellano, la manera en que lo reprimieron y cómo se recupera luego de haber tenido que pasar la noche en una comisaría a pesar de tener todo el cuerpo lastimado.',
#    'inip': '1420',
#    'endp': '1757',
#    'bop': 'n',
#    'confidence': '86',
#    'score_tag': 'P',
#    'agreement': 'DISAGREEMENT',
#    'segment_list': [{'text': '— Revista Cítrica (@revistacitrica) 6 de junio de 2018 Tampoco pudieron mostrar una entrevista que le hicieron a Kane, en la que él cuenta como puede, con su poco manejo del castellano, la manera en que lo reprimieron',
#      'segment_type': 'main',
#      'inip': '1420',
#      'endp': '1637',
#      'confidence': '92',
#      'score_tag': 'P',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': '(tampoco) reprimir',
#        'inip': '1627',
#        'endp': '1637',
#        'confidence': '92',
#        'score_tag': 'P',
#        'sentimented_entity_list': [{'form': 'Revista Cítrica',
#          'id': '5d2f2d398671f',
#          'variant': 'Revista Cítrica',
#          'inip': '1422',
#          'endp': '1436',
#          'type': 'Top>Organization',
#          'score_tag': 'P'}],
#        'sentimented_concept_list': [{'form': 'entrevista',
#          'id': 'e6804e6507',
#          'variant': 'entrevista',
#          'inip': '1505',
#          'endp': '1514',
#          'type': 'Top',
#          'score_tag': 'P'}]}],
#      'sentimented_entity_list': [{'form': 'Serigne Dame Kane',
#        'id': '5d2dfcf0ae119',
#        'variant': 'Kane',
#        'inip': '1534',
#        'endp': '1537',
#        'type': 'Top>Person',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'castellano',
#        'id': 'ae3d807c6b',
#        'variant': 'castellano',
#        'inip': '1595',
#        'endp': '1604',
#        'type': 'Top>Person',
#        'score_tag': 'NONE'},
#       {'form': 'castellano',
#        'id': 'b3d9dadd47',
#        'variant': 'castellano',
#        'inip': '1595',
#        'endp': '1604',
#        'type': 'Top>OtherEntity>Language',
#        'score_tag': 'NONE'},
#       {'form': 'castellano',
#        'id': 'ba002baa71',
#        'variant': 'castellano',
#        'inip': '1595',
#        'endp': '1604',
#        'type': 'Top>OtherEntity>Title',
#        'score_tag': 'NONE'}],
#      'segment_list': [{'text': 'con su poco manejo del castellano',
#        'segment_type': 'main',
#        'inip': '1572',
#        'endp': '1604',
#        'confidence': '100',
#        'score_tag': 'N',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'poco',
#          'inip': '1579',
#          'endp': '1582',
#          'confidence': '100',
#          'score_tag': 'N'}],
#        'sentimented_concept_list': [{'form': 'castellano',
#          'id': 'ae3d807c6b',
#          'variant': 'castellano',
#          'inip': '1595',
#          'endp': '1604',
#          'type': 'Top>Person',
#          'score_tag': 'NONE'},
#         {'form': 'castellano',
#          'id': 'b3d9dadd47',
#          'variant': 'castellano',
#          'inip': '1595',
#          'endp': '1604',
#          'type': 'Top>OtherEntity>Language',
#          'score_tag': 'NONE'},
#         {'form': 'castellano',
#          'id': 'ba002baa71',
#          'variant': 'castellano',
#          'inip': '1595',
#          'endp': '1604',
#          'type': 'Top>OtherEntity>Title',
#          'score_tag': 'NONE'}]}]},
#     {'text': 'cómo se recupera luego de haber tenido que pasar la noche en una comisaría a pesar de tener todo el cuerpo lastimado',
#      'segment_type': 'main',
#      'inip': '1641',
#      'endp': '1756',
#      'confidence': '96',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': '(recuperar) (a pesar de) (todo) lastimar',
#        'inip': '1748',
#        'endp': '1756',
#        'confidence': '96',
#        'score_tag': 'N'}],
#      'sentimented_concept_list': [{'form': 'cuerpo',
#        'id': 'a21dd2d1b5',
#        'variant': 'cuerpo',
#        'inip': '1741',
#        'endp': '1746',
#        'type': 'Top>Organization',
#        'score_tag': 'NONE'},
#       {'form': 'cuerpo',
#        'id': 'b09f3b72bb',
#        'variant': 'cuerpo',
#        'inip': '1741',
#        'endp': '1746',
#        'type': 'Top',
#        'score_tag': 'NONE'},
#       {'form': 'comisaría',
#        'id': 'd32a5bd869',
#        'variant': 'comisaría',
#        'inip': '1706',
#        'endp': '1714',
#        'type': 'Top>Location>Facility',
#        'score_tag': 'NONE'}],
#      'segment_list': [{'text': 'de haber tenido que pasar la noche en una comisaría a pesar de tener todo el cuerpo lastimado',
#        'segment_type': 'main',
#        'inip': '1664',
#        'endp': '1756',
#        'confidence': '96',
#        'score_tag': 'N',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': '(a pesar de) (todo) lastimar',
#          'inip': '1748',
#          'endp': '1756',
#          'confidence': '96',
#          'score_tag': 'N',
#          'sentimented_concept_list': [{'form': 'comisaría',
#            'id': 'd32a5bd869',
#            'variant': 'comisaría',
#            'inip': '1706',
#            'endp': '1714',
#            'type': 'Top>Location>Facility',
#            'score_tag': 'N'}]}],
#        'sentimented_concept_list': [{'form': 'cuerpo',
#          'id': 'a21dd2d1b5',
#          'variant': 'cuerpo',
#          'inip': '1741',
#          'endp': '1746',
#          'type': 'Top>Organization',
#          'score_tag': 'NONE'},
#         {'form': 'cuerpo',
#          'id': 'b09f3b72bb',
#          'variant': 'cuerpo',
#          'inip': '1741',
#          'endp': '1746',
#          'type': 'Top',
#          'score_tag': 'NONE'}]}]}],
#    'sentimented_entity_list': [{'form': 'Serigne Dame Kane',
#      'id': '5d2dfcf0ae119',
#      'type': 'Top>Person',
#      'score_tag': 'NONE'},
#     {'form': 'Revista Cítrica',
#      'id': '5d2f2d398671f',
#      'type': 'Top>Organization',
#      'score_tag': 'P'}],
#    'sentimented_concept_list': [{'form': 'cuerpo',
#      'id': 'a21dd2d1b5',
#      'type': 'Top>Organization',
#      'score_tag': 'N+'},
#     {'form': 'castellano',
#      'id': 'ae3d807c6b',
#      'type': 'Top>Person',
#      'score_tag': 'NONE'},
#     {'form': 'cuerpo', 'id': 'b09f3b72bb', 'type': 'Top', 'score_tag': 'N+'},
#     {'form': 'castellano',
#      'id': 'b3d9dadd47',
#      'type': 'Top>OtherEntity>Language',
#      'score_tag': 'NONE'},
#     {'form': 'castellano',
#      'id': 'ba002baa71',
#      'type': 'Top>OtherEntity>Title',
#      'score_tag': 'NONE'},
#     {'form': 'comisaría',
#      'id': 'd32a5bd869',
#      'type': 'Top>Location>Facility',
#      'score_tag': 'N'},
#     {'form': 'entrevista',
#      'id': 'e6804e6507',
#      'type': 'Top',
#      'score_tag': 'P'}]},
#   {'text': 'Kane Serigne Dame vive en Ciudadela, en una pieza al fondo de un garaje, cerca de la estación.',
#    'inip': '1764',
#    'endp': '1857',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'NONE',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Kane Serigne Dame vive en Ciudadela, en una pieza al fondo de un garaje, cerca de la estación',
#      'segment_type': 'main',
#      'inip': '1764',
#      'endp': '1856',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_entity_list': [{'form': 'Serigne Dame Kane',
#        'id': '5d2dfcf0ae119',
#        'variant': 'Kane Serigne',
#        'inip': '1764',
#        'endp': '1775',
#        'type': 'Top>Person',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'ciudadela',
#        'id': '42f055b42e',
#        'variant': 'Ciudadela',
#        'inip': '1790',
#        'endp': '1798',
#        'type': 'Top>Location>GeoPoliticalEntity>City',
#        'score_tag': 'NONE'},
#       {'form': 'fondo',
#        'id': '478ea60931',
#        'variant': 'fondo',
#        'inip': '1817',
#        'endp': '1821',
#        'type': 'Top',
#        'score_tag': 'NONE'},
#       {'form': 'aparcamiento',
#        'id': '5ca7bc2365',
#        'variant': 'garaje',
#        'inip': '1829',
#        'endp': '1834',
#        'type': 'Top>Location>Facility>StationTop',
#        'score_tag': 'NONE'},
#       {'form': 'fondo',
#        'id': '6fd0506729',
#        'variant': 'fondo',
#        'inip': '1817',
#        'endp': '1821',
#        'type': 'Top',
#        'score_tag': 'NONE'},
#       {'form': 'fondo',
#        'id': 'a5620c3e1e',
#        'variant': 'fondo',
#        'inip': '1817',
#        'endp': '1821',
#        'type': 'Top',
#        'score_tag': 'NONE'},
#       {'form': 'pieza',
#        'id': 'bf9ee5550c',
#        'variant': 'pieza',
#        'inip': '1808',
#        'endp': '1812',
#        'type': 'Top>Person',
#        'score_tag': 'NONE'},
#       {'form': 'estación',
#        'id': 'dec0ba5572',
#        'variant': 'estación',
#        'inip': '1849',
#        'endp': '1856',
#        'type': 'Top>Location>Facility>StationTop>Station',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [{'form': 'Serigne Dame Kane',
#      'id': '5d2dfcf0ae119',
#      'type': 'Top>Person',
#      'score_tag': 'NONE'}],
#    'sentimented_concept_list': [{'form': 'ciudadela',
#      'id': '42f055b42e',
#      'type': 'Top>Location>GeoPoliticalEntity>City',
#      'score_tag': 'NONE'},
#     {'form': 'fondo', 'id': '478ea60931', 'type': 'Top', 'score_tag': 'NONE'},
#     {'form': 'aparcamiento',
#      'id': '5ca7bc2365',
#      'type': 'Top>Location>Facility>StationTop',
#      'score_tag': 'NONE'},
#     {'form': 'fondo', 'id': '6fd0506729', 'type': 'Top', 'score_tag': 'NONE'},
#     {'form': 'fondo', 'id': 'a5620c3e1e', 'type': 'Top', 'score_tag': 'NONE'},
#     {'form': 'pieza',
#      'id': 'bf9ee5550c',
#      'type': 'Top>Person',
#      'score_tag': 'NONE'},
#     {'form': 'estación',
#      'id': 'dec0ba5572',
#      'type': 'Top>Location>Facility>StationTop>Station',
#      'score_tag': 'NONE'}]},
#   {'text': 'No tiene ducha:',
#    'inip': '1859',
#    'endp': '1873',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'NONE',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'No tiene ducha:',
#      'segment_type': 'main',
#      'inip': '1859',
#      'endp': '1873',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
# ...
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'yo caer',
#          'inip': '2413',
#          'endp': '2418',
#          'confidence': '100',
#          'score_tag': 'N'}]}]},
#     {'text': 'me lastimaron mucho el brazo”',
#      'segment_type': 'main',
#      'inip': '2451',
#      'endp': '2479',
#      'confidence': '100',
#      'score_tag': 'N+',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'lastimar',
#        'inip': '2454',
#        'endp': '2463',
#        'confidence': '100',
#        'score_tag': 'N+',
#        'sentimented_concept_list': [{'form': 'brazo',
#          'id': '24cdb52d12',
#          'variant': 'brazo',
#          'inip': '2474',
#          'endp': '2478',
#          'type': 'Top>LivingThing>BodyPart',
#          'score_tag': 'N+'}]}]},
#     {'text': 'relató el hombre a la revista censurada',
#      'segment_type': 'main',
#      'inip': '2482',
#      'endp': '2520',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'censurar',
#        'inip': '2512',
#        'endp': '2520',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_concept_list': [{'form': 'hombre',
#          'id': '20a218cbdf',
#          'variant': 'hombre',
#          'inip': '2492',
#          'endp': '2497',
#          'type': 'Top>Person',
#          'score_tag': 'N'},
#         {'form': 'revista',
#          'id': 'a0a1a5401f',
#          'variant': 'revista',
#          'inip': '2504',
#          'endp': '2510',
#          'type': 'Top>Product>CulturalProduct>Printing>Magazine',
#          'score_tag': 'N'}]}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': [{'form': 'hombre',
#      'id': '20a218cbdf',
#      'type': 'Top>Person',
#      'score_tag': 'N'},
#     {'form': 'brazo',
#      'id': '24cdb52d12',
#      'type': 'Top>LivingThing>BodyPart',
#      'score_tag': 'N+'},
#     {'form': 'revista',
#      'id': 'a0a1a5401f',
#      'type': 'Top>Product>CulturalProduct>Printing>Magazine',
#      'score_tag': 'N'}]},
#   {'text': 'Además, se refirió al principal reclamo que tienen los trabajadores senegaleses en Argentina sobre el hostigamiento policial y que muchas veces pasa desapercibido:',
#    'inip': '2524',
#    'endp': '2686',
#    'bop': 'n',
#    'confidence': '94',
#    'score_tag': 'NEU',
#    'agreement': 'DISAGREEMENT',
#    'segment_list': [{'text': 'Además, se refirió al principal reclamo que tienen los trabajadores senegaleses en Argentina sobre el hostigamiento policial y que muchas veces pasa desapercibido:',
#      'segment_type': 'main',
#      'inip': '2524',
#      'endp': '2686',
#      'confidence': '100',
#      'score_tag': 'NEU',
#      'agreement': 'DISAGREEMENT',
#      'polarity_term_list': [{'text': 'reclamo',
#        'inip': '2556',
#        'endp': '2562',
#        'confidence': '100',
#        'score_tag': 'P'},
#       {'text': 'hostigamiento',
#        'inip': '2626',
#        'endp': '2638',
#        'confidence': '100',
#        'score_tag': 'N'}],
#      'sentimented_entity_list': [{'form': 'Senegalés',
#        'id': '5d2df4f6a4caf',
#        'variant': 'senegaleses',
#        'inip': '2592',
#        'endp': '2602',
#        'type': 'Top>Nacionalidad',
#        'score_tag': 'NONE'},
#       {'form': 'policía',
#        'id': '5d2df7073a370',
#        'variant': 'policial',
#        'inip': '2640',
#        'endp': '2647',
#        'type': 'Top>Organization',
#        'score_tag': 'NONE'},
#       {'form': 'Argentina',
#        'id': 'efb13c2f4e',
#        'variant': 'Argentina',
#        'inip': '2607',
#        'endp': '2615',
#        'type': 'Top>Location>GeoPoliticalEntity>Country',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'trabajador',
#        'id': '04956a16c6',
#        'variant': 'trabajadores',
#        'inip': '2579',
#        'endp': '2590',
#        'type': 'Top>OtherEntity>Vocation',
#        'score_tag': 'NONE'}],
#      'segment_list': [{'text': 'al principal reclamo',
#        'segment_type': 'main',
#        'inip': '2543',
#        'endp': '2562',
#        'confidence': '100',
#        'score_tag': 'P',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'reclamo',
#          'inip': '2556',
#          'endp': '2562',
#          'confidence': '100',
#          'score_tag': 'P'}]},
#       {'text': 'que tienen los trabajadores senegaleses en Argentina sobre el hostigamiento policial y que muchas veces pasa desapercibido',
#        'segment_type': 'main',
#        'inip': '2564',
#        'endp': '2685',
#        'confidence': '100',
#        'score_tag': 'N',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'hostigamiento',
#          'inip': '2626',
#          'endp': '2638',
#          'confidence': '100',
#          'score_tag': 'N',
#          'sentimented_entity_list': [{'form': 'Argentina',
#            'id': 'efb13c2f4e',
#            'variant': 'Argentina',
#            'inip': '2607',
#            'endp': '2615',
#            'type': 'Top>Location>GeoPoliticalEntity>Country',
#            'score_tag': 'N'}],
#          'sentimented_concept_list': [{'form': 'trabajador',
#            'id': '04956a16c6',
#            'variant': 'trabajadores',
#            'inip': '2579',
#            'endp': '2590',
#            'type': 'Top>OtherEntity>Vocation',
#            'score_tag': 'N'}]}],
#        'sentimented_entity_list': [{'form': 'Senegalés',
#          'id': '5d2df4f6a4caf',
#          'variant': 'senegaleses',
#          'inip': '2592',
#          'endp': '2602',
#          'type': 'Top>Nacionalidad',
#          'score_tag': 'NONE'},
#         {'form': 'policía',
#          'id': '5d2df7073a370',
#          'variant': 'policial',
#          'inip': '2640',
#          'endp': '2647',
#          'type': 'Top>Organization',
#          'score_tag': 'NONE'}]}]}],
#    'sentimented_entity_list': [{'form': 'Senegalés',
#      'id': '5d2df4f6a4caf',
#      'type': 'Top>Nacionalidad',
#      'score_tag': 'NONE'},
#     {'form': 'policía',
#      'id': '5d2df7073a370',
#      'type': 'Top>Organization',
#      'score_tag': 'NONE'},
#     {'form': 'Argentina',
#      'id': 'efb13c2f4e',
#      'type': 'Top>Location>GeoPoliticalEntity>Country',
#      'score_tag': 'N'}],
#    'sentimented_concept_list': [{'form': 'trabajador',
#      'id': '04956a16c6',
#      'type': 'Top>OtherEntity>Vocation',
#      'score_tag': 'N'}]},
#   {'text': '“Nosotros no vinimos para que nos golpeen, solo venimos para trabajar a la Argentina.',
#    'inip': '2688',
#    'endp': '2772',
#    'bop': 'n',
#    'confidence': '92',
#    'score_tag': 'P',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': '“Nosotros no vinimos para que nos golpeen, solo venimos para trabajar a la Argentina',
#      'segment_type': 'main',
#      'inip': '2688',
#      'endp': '2771',
#      'confidence': '92',
#      'score_tag': 'P',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': '(no) golpear',
#        'inip': '2722',
#        'endp': '2728',
#        'confidence': '92',
#        'score_tag': 'P'}],
#      'sentimented_entity_list': [{'form': 'Argentina',
#        'id': 'efb13c2f4e',
#        'variant': 'la Argentina',
#        'inip': '2760',
#        'endp': '2771',
#        'type': 'Top>Location>GeoPoliticalEntity>Country',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [{'form': 'Argentina',
#      'id': 'efb13c2f4e',
#      'type': 'Top>Location>GeoPoliticalEntity>Country',
#      'score_tag': 'NONE'}],
#    'sentimented_concept_list': []},
#   {'text': 'Dicen que los negros golpeamos a la policía y no es cierto.',
#    'inip': '2774',
#    'endp': '2832',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Dicen que los negros golpeamos a la policía',
#      'segment_type': 'main',
#      'inip': '2774',
#      'endp': '2816',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'golpear',
#        'inip': '2795',
#        'endp': '2803',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_entity_list': [{'form': 'policía',
#          'id': '5d2df7073a370',
#          'variant': 'policía',
#          'inip': '2810',
#          'endp': '2816',
#          'type': 'Top>Organization',
#          'score_tag': 'N'}],
#        'sentimented_concept_list': [{'form': 'negro',
#          'id': '2408c36eb8',
#          'variant': 'negros',
#          'inip': '2788',
#          'endp': '2793',
#          'type': 'Top>OtherEntity>Color',
#          'score_tag': 'N'},
#         {'form': 'negro',
#          'id': '977deaea89',
#          'variant': 'negros',
#          'inip': '2788',
#          'endp': '2793',
#          'type': 'Top>Person',
#          'score_tag': 'N'}]}]},
#     {'text': 'no es cierto',
#      'segment_type': 'main',
#      'inip': '2820',
#      'endp': '2831',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': []}],
#    'sentimented_entity_list': [{'form': 'policía',
#      'id': '5d2df7073a370',
#      'type': 'Top>Organization',
#      'score_tag': 'N'}],
#    'sentimented_concept_list': [{'form': 'negro',
#      'id': '2408c36eb8',
#      'type': 'Top>OtherEntity>Color',
#      'score_tag': 'N'},
#     {'form': 'negro',
#      'id': '977deaea89',
#      'type': 'Top>Person',
#      'score_tag': 'N'}]},
#   {'text': 'No es para pelear que vinimos acá”, lamentó.',
#    'inip': '2834',
#    'endp': '2877',
#    'bop': 'n',
#    'confidence': '92',
#    'score_tag': 'P',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'No es para pelear que vinimos acá”, lamentó',
#      'segment_type': 'main',
#      'inip': '2834',
#      'endp': '2876',
#      'confidence': '92',
#      'score_tag': 'P',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': '(no) pelear',
#        'inip': '2845',
#        'endp': '2850',
#        'confidence': '92',
#        'score_tag': 'P'},
#       {'text': '(no) lamentar',
#        'inip': '2870',
#        'endp': '2876',
#        'confidence': '92',
#        'score_tag': 'P'}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': []}],
#  'sentimented_entity_list': [{'form': 'Twitter',
#    'id': '0db1b25b2b',
#    'type': 'Top>Organization>Company>TechnologyCompany>SoftwareCompany',
#    'score_tag': 'NONE'},
#   {'form': 'Senegalés',
#    'id': '5d2df4f6a4caf',
#    'type': 'Top>Nacionalidad',
#    'score_tag': 'NONE'},
#   {'form': 'policía',
#    'id': '5d2df7073a370',
#    'type': 'Top>Organization',
#    'score_tag': 'N'},
#   {'form': 'Serigne Dame Kane',
#    'id': '5d2dfcf0ae119',
#    'type': 'Top>Person',
#    'score_tag': 'N'},
#   {'form': 'La Salada',
#    'id': '5d2f2d1b289d2',
#    'type': 'Top>Location',
#    'score_tag': 'NONE'},
#   {'form': 'Revista Cítrica',
#    'id': '5d2f2d398671f',
#    'type': 'Top>Organization',
#    'score_tag': 'N'},
#   {'form': 'pic.twitter.com/EJ65aW0Nur',
#    'id': '__12324353272857338254',
#    'type': 'Top>Id>Url',
#    'score_tag': 'NONE'},
#   {'form': 'avenida Avellaneda',
#    'id': '__19857996936203458',
#    'type': 'Top>Location>Address',
#    'score_tag': 'NEU'},
#   {'form': 'https://t.co/s9rNhBNDlv',
#    'id': '__6118559569902622494',
#    'type': 'Top>Id>Url',
#    'score_tag': 'NONE'},
#   {'form': 'Pic',
#    'id': 'a5915ef2e5',
#    'type': 'Top>Person>LastName',
#    'score_tag': 'NONE'},
#   {'form': 'Facebook',
#    'id': 'e328525500',
#    'type': 'Top>Organization>Company>TechnologyCompany>SoftwareCompany',
#    'score_tag': 'NEU'},
#   {'form': 'Argentina',
#    'id': 'efb13c2f4e',
#    'type': 'Top>Location>GeoPoliticalEntity>Country',
#    'score_tag': 'N'}],
#  'sentimented_concept_list': [{'form': 'efectivo',
#    'id': '015edcd94f',
#    'type': 'Top>Organization',
#    'score_tag': 'N'},
#   {'form': 'represión', 'id': '0387a12e30', 'type': 'Top', 'score_tag': 'N'},
#   {'form': 'trabajador',
#    'id': '04956a16c6',
#    'type': 'Top>OtherEntity>Vocation',
#    'score_tag': 'N+'},
#   {'form': 'admirador',
#    'id': '073afdc39c',
#    'type': 'Top>Person',
#    'score_tag': 'P'},
#   {'form': 'periodista',
#    'id': '0d2a86e544',
#    'type': 'Top>OtherEntity>Vocation',
#    'score_tag': 'NONE'},
#   {'form': 'local',
#    'id': '0f85642308',
#    'type': 'Top>Location>Facility',
#    'score_tag': 'NONE'},
#   {'form': 'calle',
#    'id': '13f4067384',
#    'type': 'Top>Location>Facility>Line',
#    'score_tag': 'N'},
#   {'form': 'violento', 'id': '15a8050fe2', 'type': 'Top', 'score_tag': 'N'},
#   {'form': 'fractura',
#    'id': '16ff59d24a',
#    'type': 'Top>OtherEntity>Disease',
#    'score_tag': 'N'},
#   {'form': 'red social', 'id': '1f1d00751f', 'type': 'Top', 'score_tag': 'N'},
#   {'form': 'hombre',
#    'id': '20a218cbdf',
#    'type': 'Top>Person',
#    'score_tag': 'N'},
#   {'form': 'negro',
#    'id': '2408c36eb8',
#    'type': 'Top>OtherEntity>Color',
#    'score_tag': 'N'},
#   {'form': 'brazo',
#    'id': '24cdb52d12',
#    'type': 'Top>LivingThing>BodyPart',
#    'score_tag': 'N+'},
#   {'form': 'vendedor callejero',
#    'id': '3154aa53dc',
#    'type': 'Top',
#    'score_tag': 'N+'},
#   {'form': 'vidrio', 'id': '37d87a86be', 'type': 'Top', 'score_tag': 'N'},
#   {'form': 'derecho a la información',
#    'id': '3ae2457b18',
#    'type': 'Top',
#    'score_tag': 'NONE'},
#   {'form': 'ropa',
#    'id': '3cecc4b42d',
#    'type': 'Top>Product>Textile>Clothes',
#    'score_tag': 'NONE'},
#   {'form': 'ciudadela',
#    'id': '42f055b42e',
#    'type': 'Top>Location>GeoPoliticalEntity>City',
#    'score_tag': 'NONE'},
#   {'form': 'fondo', 'id': '478ea60931', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'censura', 'id': '4b94fed85b', 'type': 'Top', 'score_tag': 'N'},
#   {'form': 'camino',
#    'id': '52b872ac4d',
#    'type': 'Top>Location>Facility>Line',
#    'score_tag': 'NONE'},
#   {'form': 'ceremonia',
#    'id': '54236208be',
#    'type': 'Top>Event>Occasion',
#    'score_tag': 'NONE'},
#   {'form': 'derecho a la información',
#    'id': '5a73bd1f24',
#    'type': 'Top',
#    'score_tag': 'NONE'},
#   {'form': 'aparcamiento',
#    'id': '5ca7bc2365',
#    'type': 'Top>Location>Facility>StationTop',
#    'score_tag': 'NONE'},
#   {'form': 'fondo', 'id': '6fd0506729', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'página',
#    'id': '773b6d6f59',
#    'type': 'Top>Product>CulturalProduct>Printing',
#    'score_tag': 'N'},
#   {'form': 'efectivo',
#    'id': '78a9d0e997',
#    'type': 'Top>Organization',
#    'score_tag': 'N'},
#   {'form': 'acto',
#    'id': '8a9b9f5c9c',
#    'type': 'Top>OtherEntity>Rule',
#    'score_tag': 'NONE'},
#   {'form': 'martes',
#    'id': '90cb92e5fb',
#    'type': 'Top>Unit>TimeUnit>Day',
#    'score_tag': 'NONE'},
#   {'form': 'negro',
#    'id': '977deaea89',
#    'type': 'Top>Person',
#    'score_tag': 'N'},
#   {'form': 'revista',
#    'id': 'a0a1a5401f',
#    'type': 'Top>Product>CulturalProduct>Printing>Magazine',
#    'score_tag': 'N'},
#   {'form': 'cuerpo',
#    'id': 'a21dd2d1b5',
#    'type': 'Top>Organization',
#    'score_tag': 'N+'},
#   {'form': 'fondo', 'id': 'a5620c3e1e', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'hermano',
#    'id': 'ac9a5a05e2',
#    'type': 'Top>Person',
#    'score_tag': 'NONE'},
#   {'form': 'castellano',
#    'id': 'ae3d807c6b',
#    'type': 'Top>Person',
#    'score_tag': 'NONE'},
#   {'form': 'acto',
#    'id': 'ae6d6f2e1a',
#    'type': 'Top>Process',
#    'score_tag': 'NONE'},
#   {'form': 'grabación', 'id': 'affae0aef3', 'type': 'Top', 'score_tag': 'N'},
#   {'form': 'cuerpo', 'id': 'b09f3b72bb', 'type': 'Top', 'score_tag': 'N+'},
#   {'form': 'castellano',
#    'id': 'b3d9dadd47',
#    'type': 'Top>OtherEntity>Language',
#    'score_tag': 'NONE'},
#   {'form': 'acto',
#    'id': 'b89ae739f1',
#    'type': 'Top>Product>CulturalProduct>Composition',
#    'score_tag': 'NONE'},
#   {'form': 'castellano',
#    'id': 'ba002baa71',
#    'type': 'Top>OtherEntity>Title',
#    'score_tag': 'NONE'},
#   {'form': 'pieza',
#    'id': 'bf9ee5550c',
#    'type': 'Top>Person',
#    'score_tag': 'NONE'},
#   {'form': 'comisaría',
#    'id': 'd32a5bd869',
#    'type': 'Top>Location>Facility',
#    'score_tag': 'N'},
#   {'form': 'detenido', 'id': 'd7b05994d8', 'type': 'Top', 'score_tag': 'N+'},
#   {'form': 'vendedor',
#    'id': 'dacecb32bc',
#    'type': 'Top>OtherEntity>Vocation',
#    'score_tag': 'N'},
#   {'form': 'estación',
#    'id': 'dec0ba5572',
#    'type': 'Top>Location>Facility>StationTop>Station',
#    'score_tag': 'NONE'},
#   {'form': 'entrevista', 'id': 'e6804e6507', 'type': 'Top', 'score_tag': 'P'}]}

# %% [markdown]
# ## 3. Análisis de sentimiento de las noticias del corpus
# Ahora, cargamos todo nuestro corpus y lo analizamos con sentiment

# %%
corpus = pickle.load(open("corpus.pkl", "rb")) #sacamos el corpus de su pickle (df de 87 x 3)

# %%
corpus_noticias = corpus.iloc[:,2] #seleccionamos tan solo las notas (columna 2)
# Out:
# "\n#código para analizar la primera noticia del corpus\nnoticia = corpus_noticias[0]\ntexto = texto.encode('utf-8')\nsentimento = sentiment(noticia)\n"

# %%
#A continuación, analizamos todas las noticias del corpus
sentiment_analysis = []
for noticia in corpus_noticias:
    analisis_sent = sentiment(clean(noticia))
    sentiment_analysis.append(analisis_sent)

# %%
ej = sentiment_analysis[78]
ej
# Out:
# {'status': {'code': '0',
#   'msg': 'OK',
#   'credits': '1',
#   'remaining_credits': '18384'},
#  'model': 'general_es',
#  'score_tag': 'N',
#  'agreement': 'DISAGREEMENT',
#  'subjectivity': 'SUBJECTIVE',
#  'confidence': '86',
#  'irony': 'NONIRONIC',
#  'sentence_list': [{'text': 'Prohibido ser negro en Buenos Aires 05/06/2018 Por Cosecha Roja 0 Un grupo de Infantería de la Policía de la Ciudad empuja a Kane Serigne Dame, un ciudadano Senegalés, contra una vidriera.',
#    'inip': '1',
#    'endp': '189',
#    'bop': 'y',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Prohibido ser negro en Buenos Aires 05/06/2018 Por Cosecha Roja 0 Un grupo de Infantería de la Policía de la Ciudad',
#      'segment_type': 'secondary',
#      'inip': '1',
#      'endp': '116',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_entity_list': [{'form': 'Buenos Aires',
#        'id': '5d2df9543aa42',
#        'variant': 'Buenos Aires',
#        'inip': '24',
#        'endp': '35',
#        'type': 'Top>Location>GeoPoliticalEntity>City',
#        'score_tag': 'NONE'},
#       {'form': 'Cosecha Roja',
#        'id': '__12233334718966634480',
#        'variant': 'Cosecha Roja',
#        'inip': '52',
#        'endp': '63',
#        'type': 'Top',
#        'score_tag': 'NONE'},
#       {'form': 'Infantería de la Policía de la Ciudad',
#        'id': '__4978655492218510607',
#        'variant': 'Infantería de la Policía de la Ciudad',
#        'inip': '80',
#        'endp': '116',
#        'type': 'Top',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'grupo',
#        'id': '2d2ce0cce8',
#        'variant': 'grupo',
#        'inip': '71',
#        'endp': '75',
#        'type': 'Top>Organization',
#        'score_tag': 'NONE'}]},
#     {'text': 'empuja a Kane Serigne Dame, un ciudadano Senegalés, contra una vidriera',
#      'segment_type': 'main',
#      'inip': '118',
#      'endp': '188',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'empujar',
#        'inip': '118',
#        'endp': '123',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_entity_list': [{'form': 'Serigne Dame Kane',
#          'id': '5d2dfcf0ae119',
#          'variant': 'Kane Serigne',
#          'inip': '127',
#          'endp': '138',
#          'type': 'Top>Person',
#          'score_tag': 'N'}],
#        'sentimented_concept_list': [{'form': 'grupo',
#          'id': '2d2ce0cce8',
#          'variant': 'grupo',
#          'inip': '71',
#          'endp': '75',
#          'type': 'Top>Organization',
#          'score_tag': 'N'},
#         {'form': 'ciudadano',
#          'id': '512e1a8ba7',
#          'variant': 'ciudadano',
#          'inip': '149',
#          'endp': '157',
#          'type': 'Top>Person',
#          'score_tag': 'N'},
#         {'form': 'vidriero',
#          'id': '8f3616613c',
#          'variant': 'vidriera',
#          'inip': '181',
#          'endp': '188',
#          'type': 'Top>OtherEntity>Vocation',
#          'score_tag': 'N'},
#         {'form': 'vidriera',
#          'id': '9b9d78cb73',
#          'variant': 'vidriera',
#          'inip': '181',
#          'endp': '188',
#          'type': 'Top>Product',
#          'score_tag': 'N'},
#         {'form': 'vidriera',
#          'id': 'f05d3a6974',
#          'variant': 'vidriera',
#          'inip': '181',
#          'endp': '188',
#          'type': 'Top>Location>Facility>Market',
#          'score_tag': 'N'}]}],
#      'sentimented_entity_list': [{'form': 'Senegalés',
#        'id': '5d2df4f6a4caf',
#        'variant': 'Senegalés',
#        'inip': '159',
#        'endp': '167',
#        'type': 'Top>Nacionalidad',
#        'score_tag': 'NONE'}],
#      'segment_list': [{'text': 'contra una vidriera',
#        'segment_type': 'main',
#        'inip': '170',
#        'endp': '188',
#        'confidence': '100',
#        'score_tag': 'N',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'contra',
#          'inip': '170',
#          'endp': '175',
#          'confidence': '100',
#          'score_tag': 'N',
#          'sentimented_concept_list': [{'form': 'vidriero',
#            'id': '8f3616613c',
#            'variant': 'vidriera',
#            'inip': '181',
#            'endp': '188',
#            'type': 'Top>OtherEntity>Vocation',
#            'score_tag': 'N'},
#           {'form': 'vidriera',
#            'id': '9b9d78cb73',
#            'variant': 'vidriera',
#            'inip': '181',
#            'endp': '188',
#            'type': 'Top>Product',
#            'score_tag': 'N'},
#           {'form': 'vidriera',
#            'id': 'f05d3a6974',
#            'variant': 'vidriera',
#            'inip': '181',
#            'endp': '188',
#            'type': 'Top>Location>Facility>Market',
#            'score_tag': 'N'}]}]}]}],
#    'sentimented_entity_list': [{'form': 'Senegalés',
#      'id': '5d2df4f6a4caf',
#      'type': 'Top>Nacionalidad',
#      'score_tag': 'NONE'},
#     {'form': 'Buenos Aires',
#      'id': '5d2df9543aa42',
#      'type': 'Top>Location>GeoPoliticalEntity>City',
#      'score_tag': 'NONE'},
#     {'form': 'Serigne Dame Kane',
#      'id': '5d2dfcf0ae119',
#      'type': 'Top>Person',
#      'score_tag': 'N'},
#     {'form': 'Cosecha Roja',
#      'id': '__12233334718966634480',
#      'type': 'Top',
#      'score_tag': 'NONE'},
#     {'form': 'Infantería de la Policía de la Ciudad',
#      'id': '__4978655492218510607',
#      'type': 'Top',
#      'score_tag': 'NONE'}],
#    'sentimented_concept_list': [{'form': 'grupo',
#      'id': '2d2ce0cce8',
#      'type': 'Top>Organization',
#      'score_tag': 'N'},
#     {'form': 'ciudadano',
#      'id': '512e1a8ba7',
#      'type': 'Top>Person',
#      'score_tag': 'N'},
#     {'form': 'vidriero',
#      'id': '8f3616613c',
#      'type': 'Top>OtherEntity>Vocation',
#      'score_tag': 'N'},
#     {'form': 'vidriera',
#      'id': '9b9d78cb73',
#      'type': 'Top>Product',
#      'score_tag': 'N'},
#     {'form': 'vidriera',
#      'id': 'f05d3a6974',
#      'type': 'Top>Location>Facility>Market',
#      'score_tag': 'N'}]},
#   {'text': 'Lo golpean y lo arrastran.',
#    'inip': '191',
#    'endp': '216',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Lo golpean',
#      'segment_type': 'main',
#      'inip': '191',
#      'endp': '200',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'golpear',
#        'inip': '194',
#        'endp': '200',
#        'confidence': '100',
#        'score_tag': 'N'}]},
#     {'text': 'lo arrastran',
#      'segment_type': 'secondary',
#      'inip': '204',
#      'endp': '215',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': []}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': []},
#   {'text': 'El hombre grita de dolor:',
#    'inip': '218',
#    'endp': '242',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'El hombre grita de dolor:',
#      'segment_type': 'main',
#      'inip': '218',
#      'endp': '242',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': '(gritar) dolor',
#        'inip': '237',
#        'endp': '241',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_concept_list': [{'form': 'hombre',
#          'id': '20a218cbdf',
#          'variant': 'hombre',
#          'inip': '221',
#          'endp': '226',
#          'type': 'Top>Person',
#          'score_tag': 'N'},
#         {'form': 'dolor',
#          'id': '2c30c78d53',
#          'variant': 'dolor',
#          'inip': '237',
#          'endp': '241',
#          'type': 'Top>OtherEntity>Disease',
#          'score_tag': 'N'}]}],
#      'segment_list': [{'text': 'de dolor',
#        'segment_type': 'main',
#        'inip': '234',
#        'endp': '241',
#        'confidence': '100',
#        'score_tag': 'N',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'dolor',
#          'inip': '237',
#          'endp': '241',
#          'confidence': '100',
#          'score_tag': 'N',
#          'sentimented_concept_list': [{'form': 'dolor',
#            'id': '2c30c78d53',
#            'variant': 'dolor',
#            'inip': '237',
#            'endp': '241',
#            'type': 'Top>OtherEntity>Disease',
#            'score_tag': 'N'}]}]}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': [{'form': 'hombre',
#      'id': '20a218cbdf',
#      'type': 'Top>Person',
#      'score_tag': 'N'},
#     {'form': 'dolor',
#      'id': '2c30c78d53',
#      'type': 'Top>OtherEntity>Disease',
#      'score_tag': 'N'}]},
#   {'text': 'tiene una fractura expuesta en el brazo, del que chorrea sangre.',
#    'inip': '244',
#    'endp': '307',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'tiene una fractura expuesta en el brazo, del que chorrea sangre',
#      'segment_type': 'main',
#      'inip': '244',
#      'endp': '306',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'fractura',
#        'inip': '254',
#        'endp': '261',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_concept_list': [{'form': 'fractura',
#          'id': '16ff59d24a',
#          'variant': 'fractura',
#          'inip': '254',
#          'endp': '261',
#          'type': 'Top>OtherEntity>Disease',
#          'score_tag': 'N'}]}],
#      'sentimented_concept_list': [{'form': 'brazo',
#        'id': '24cdb52d12',
#        'variant': 'brazo',
#        'inip': '278',
#        'endp': '282',
#        'type': 'Top>LivingThing>BodyPart',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': [{'form': 'fractura',
#      'id': '16ff59d24a',
#      'type': 'Top>OtherEntity>Disease',
#      'score_tag': 'N'},
#     {'form': 'brazo',
#      'id': '24cdb52d12',
#      'type': 'Top>LivingThing>BodyPart',
#      'score_tag': 'NONE'}]},
#   {'text': 'Los agentes lo tiran al piso al senegalés y forman un cordón para contener la bronca de los vecinos de Flores que los rodean.',
#    'inip': '309',
#    'endp': '433',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Los agentes lo tiran al piso al senegalés',
#      'segment_type': 'secondary',
#      'inip': '309',
#      'endp': '349',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_entity_list': [{'form': 'Senegalés',
#        'id': '5d2df4f6a4caf',
#        'variant': 'senegalés',
#        'inip': '341',
#        'endp': '349',
#        'type': 'Top>Nacionalidad',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'agente',
#        'id': '0cc03e7181',
#        'variant': 'agentes',
#        'inip': '313',
#        'endp': '319',
#        'type': 'Top>Person',
#        'score_tag': 'NONE'},
#       {'form': 'agente',
#        'id': '34049c0818',
#        'variant': 'agentes',
#        'inip': '313',
#        'endp': '319',
#        'type': 'Top>Person',
#        'score_tag': 'NONE'},
#       {'form': 'agente',
#        'id': 'ce19c885fb',
#        'variant': 'agentes',
#        'inip': '313',
#        'endp': '319',
#        'type': 'Top>OtherEntity>Vocation',
#        'score_tag': 'NONE'},
#       {'form': 'piso',
#        'id': 'f8052aa1f8',
#        'variant': 'piso',
#        'inip': '333',
#        'endp': '336',
#        'type': 'Top>Location>Facility',
#        'score_tag': 'NONE'}]},
#     {'text': 'forman un cordón para contener la bronca de los vecinos de Flores que los rodean',
#      'segment_type': 'main',
#      'inip': '353',
#      'endp': '432',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'bronca',
#        'inip': '387',
#        'endp': '392',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_entity_list': [{'form': 'Flores',
#          'id': '5d2f11b7d930f',
#          'variant': 'Flores',
#          'inip': '412',
#          'endp': '417',
#          'type': 'Top>neighborhood',
#          'score_tag': 'N'}],
#        'sentimented_concept_list': [{'form': 'agente',
#          'id': '0cc03e7181',
#          'variant': 'agentes',
#          'inip': '313',
#          'endp': '319',
#          'type': 'Top>Person',
#          'score_tag': 'N'},
#         {'form': 'agente',
#          'id': '34049c0818',
#          'variant': 'agentes',
#          'inip': '313',
#          'endp': '319',
#          'type': 'Top>Person',
#          'score_tag': 'N'},
#         {'form': 'agente',
#          'id': 'ce19c885fb',
#          'variant': 'agentes',
#          'inip': '313',
#          'endp': '319',
#          'type': 'Top>OtherEntity>Vocation',
#          'score_tag': 'N'},
#         {'form': 'vecino',
#          'id': '7a0b4e931e',
#          'variant': 'vecinos',
#          'inip': '401',
#          'endp': '407',
#          'type': 'Top>Person',
#          'score_tag': 'N'}]}]}],
#    'sentimented_entity_list': [{'form': 'Senegalés',
#      'id': '5d2df4f6a4caf',
#      'type': 'Top>Nacionalidad',
#      'score_tag': 'NONE'},
#     {'form': 'Flores',
#      'id': '5d2f11b7d930f',
#      'type': 'Top>neighborhood',
#      'score_tag': 'N'}],
#    'sentimented_concept_list': [{'form': 'agente',
#      'id': '0cc03e7181',
#      'type': 'Top>Person',
#      'score_tag': 'N'},
#     {'form': 'agente',
#      'id': '34049c0818',
#      'type': 'Top>Person',
#      'score_tag': 'N'},
#     {'form': 'vecino',
#      'id': '7a0b4e931e',
#      'type': 'Top>Person',
#      'score_tag': 'N'},
#     {'form': 'agente',
#      'id': 'ce19c885fb',
#      'type': 'Top>OtherEntity>Vocation',
#      'score_tag': 'N'},
#     {'form': 'piso',
#      'id': 'f8052aa1f8',
#      'type': 'Top>Location>Facility',
#      'score_tag': 'NONE'}]},
#   {'text': 'Después se llevan detenido a Kane.',
#    'inip': '435',
#    'endp': '468',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Después se llevan detenido a Kane',
#      'segment_type': 'main',
#      'inip': '435',
#      'endp': '467',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'detener a',
#        'inip': '453',
#        'endp': '462',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_entity_list': [{'form': 'Serigne Dame Kane',
#          'id': '5d2dfcf0ae119',
#          'variant': 'Kane',
#          'inip': '464',
#          'endp': '467',
#          'type': 'Top>Person',
#          'score_tag': 'N'}]}]}],
#    'sentimented_entity_list': [{'form': 'Serigne Dame Kane',
#      'id': '5d2dfcf0ae119',
#      'type': 'Top>Person',
#      'score_tag': 'N'}],
#    'sentimented_concept_list': []},
#   {'text': 'Kane quedó internado en el Hospital Álvarez.',
#    'inip': '471',
#    'endp': '514',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'NONE',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Kane quedó internado en el Hospital Álvarez',
#      'segment_type': 'secondary',
#      'inip': '471',
#      'endp': '513',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_entity_list': [{'form': 'Serigne Dame Kane',
#        'id': '5d2dfcf0ae119',
#        'variant': 'Kane',
#        'inip': '471',
#        'endp': '474',
#        'type': 'Top>Person',
#        'score_tag': 'NONE'},
#       {'form': 'Hospital Álvarez',
#        'id': '__3344804039205521094',
#        'variant': 'Hospital Álvarez',
#        'inip': '498',
#        'endp': '513',
#        'type': 'Top>Organization>Company>HealthcareCompany>HealthcareServicesCompany>Hospitals',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [{'form': 'Serigne Dame Kane',
#      'id': '5d2dfcf0ae119',
#      'type': 'Top>Person',
#      'score_tag': 'NONE'},
#     {'form': 'Hospital Álvarez',
#      'id': '__3344804039205521094',
#      'type': 'Top>Organization>Company>HealthcareCompany>HealthcareServicesCompany>Hospitals',
#      'score_tag': 'NONE'}],
#    'sentimented_concept_list': []},
#   {'text': 'Hoy los médicos definirán si lo operan por la fractura en el brazo.',
#    'inip': '516',
#    'endp': '582',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Hoy los médicos definirán si lo operan por la fractura en el brazo',
#      'segment_type': 'main',
#      'inip': '516',
#      'endp': '581',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'fractura',
#        'inip': '562',
#        'endp': '569',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_concept_list': [{'form': 'médico',
#          'id': '305c40967f',
#          'variant': 'médicos',
#          'inip': '524',
#          'endp': '530',
#          'type': 'Top>OtherEntity>Vocation',
#          'score_tag': 'N'},
#         {'form': 'fractura',
#          'id': '16ff59d24a',
#          'variant': 'fractura',
#          'inip': '562',
#          'endp': '569',
#          'type': 'Top>OtherEntity>Disease',
#          'score_tag': 'N'},
#         {'form': 'brazo',
#          'id': '24cdb52d12',
#          'variant': 'brazo',
#          'inip': '577',
#          'endp': '581',
#          'type': 'Top>LivingThing>BodyPart',
#          'score_tag': 'N'}]}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': [{'form': 'fractura',
#      'id': '16ff59d24a',
#      'type': 'Top>OtherEntity>Disease',
#      'score_tag': 'N'},
#     {'form': 'brazo',
#      'id': '24cdb52d12',
#      'type': 'Top>LivingThing>BodyPart',
#      'score_tag': 'N'},
#     {'form': 'médico',
#      'id': '305c40967f',
#      'type': 'Top>OtherEntity>Vocation',
#      'score_tag': 'N'}]},
#   {'text': 'flores-represion En una foto que circuló ayer en las redes sociales se ve Kane tirado en el suelo al lado de un charco de sangre.',
#    'inip': '585',
#    'endp': '714',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'NONE',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'flores-represion En una foto que circuló ayer en las redes sociales se ve Kane tirado en el suelo al lado de un charco de sangre',
#      'segment_type': 'secondary',
#      'inip': '585',
#      'endp': '713',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_entity_list': [{'form': 'Serigne Dame Kane',
#        'id': '5d2dfcf0ae119',
#        'variant': 'Kane',
#        'inip': '660',
#        'endp': '663',
#        'type': 'Top>Person',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'red social',
#        'id': '1f1d00751f',
#        'variant': 'redes sociales',
#        'inip': '639',
#        'endp': '652',
#        'type': 'Top',
#        'score_tag': 'NONE'},
#       {'form': 'fotografía',
#        'id': '4e1219a1da',
#        'variant': 'foto',
#        'inip': '610',
#        'endp': '613',
#        'type': 'Top>Product',
#        'score_tag': 'NONE'},
#       {'form': 'suelo',
#        'id': '599093b066',
#        'variant': 'suelo',
#        'inip': '678',
#        'endp': '682',
#        'type': 'Top>Location',
#        'score_tag': 'NONE'},
#       {'form': 'charco',
#        'id': 'f065f3b2db',
#        'variant': 'charco',
#        'inip': '698',
#        'endp': '703',
#        'type': 'Top>Location>GeographicalEntity>WaterForm',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [{'form': 'Serigne Dame Kane',
#      'id': '5d2dfcf0ae119',
#      'type': 'Top>Person',
#      'score_tag': 'NONE'}],
#    'sentimented_concept_list': [{'form': 'red social',
#      'id': '1f1d00751f',
#      'type': 'Top',
#      'score_tag': 'NONE'},
#     {'form': 'fotografía',
#      'id': '4e1219a1da',
#      'type': 'Top>Product',
#      'score_tag': 'NONE'},
#     {'form': 'suelo',
#      'id': '599093b066',
#      'type': 'Top>Location',
#      'score_tag': 'NONE'},
#     {'form': 'charco',
#      'id': 'f065f3b2db',
#      'type': 'Top>Location>GeographicalEntity>WaterForm',
#      'score_tag': 'NONE'}]},
#   {'text': 'Una barrera de policías separa el cuerpo del hombre en el piso del grupo de vecinos y trabajadores que repudió la represión policial.',
#    'inip': '716',
#    'endp': '848',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N+',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Una barrera de policías separa el cuerpo del hombre en el piso del grupo de vecinos y trabajadores que repudió la represión policial',
#      'segment_type': 'main',
#      'inip': '716',
#      'endp': '847',
#      'confidence': '100',
#      'score_tag': 'N+',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'repudiar',
#        'inip': '819',
#        'endp': '825',
#        'confidence': '100',
#        'score_tag': 'N+',
#        'sentimented_concept_list': [{'form': 'barrera',
#          'id': '757b4c802f',
#          'variant': 'barrera',
#          'inip': '720',
#          'endp': '726',
#          'type': 'Top',
#          'score_tag': 'N+'},
#         {'form': 'barrero',
#          'id': 'b6498cb7b9',
#          'variant': 'barrera',
#          'inip': '720',
#          'endp': '726',
#          'type': 'Top>OtherEntity>Vocation',
#          'score_tag': 'N+'},
#         {'form': 'cuerpo',
#          'id': 'a21dd2d1b5',
#          'variant': 'cuerpo',
#          'inip': '750',
#          'endp': '755',
#          'type': 'Top>Organization',
#          'score_tag': 'N+'},
#         {'form': 'cuerpo',
#          'id': 'b09f3b72bb',
#          'variant': 'cuerpo',
#          'inip': '750',
#          'endp': '755',
#          'type': 'Top',
#          'score_tag': 'N+'},
#         {'form': 'piso',
#          'id': 'f8052aa1f8',
#          'variant': 'piso',
#          'inip': '774',
#          'endp': '777',
#          'type': 'Top>Location>Facility',
#          'score_tag': 'N+'},
#         {'form': 'grupo',
#          'id': '2d2ce0cce8',
#          'variant': 'grupo',
#          'inip': '783',
#          'endp': '787',
#          'type': 'Top>Organization',
#          'score_tag': 'N+'},
#         {'form': 'represión',
#          'id': '0387a12e30',
#          'variant': 'represión',
#          'inip': '830',
#          'endp': '838',
#          'type': 'Top',
#          'score_tag': 'N+'}]}],
#      'sentimented_entity_list': [{'form': 'policía',
#        'id': '5d2df7073a370',
#        'variant': 'policías',
#        'inip': '731',
#        'endp': '738',
#        'type': 'Top>Organization',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'hombre',
#        'id': '20a218cbdf',
#        'variant': 'hombre',
#        'inip': '761',
#        'endp': '766',
#        'type': 'Top>Person',
#        'score_tag': 'NONE'}],
#      'segment_list': [{'text': 'la represión policial',
#        'segment_type': 'main',
#        'inip': '827',
#        'endp': '847',
#        'confidence': '100',
#        'score_tag': 'N',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'represión',
#          'inip': '830',
#          'endp': '838',
#          'confidence': '100',
#          'score_tag': 'N',
#          'sentimented_concept_list': [{'form': 'represión',
#            'id': '0387a12e30',
#            'variant': 'represión',
#            'inip': '830',
#            'endp': '838',
#            'type': 'Top',
#            'score_tag': 'N'}]}],
#        'sentimented_entity_list': [{'form': 'policía',
#          'id': '5d2df7073a370',
#          'variant': 'policial',
#          'inip': '840',
#          'endp': '847',
#          'type': 'Top>Organization',
#          'score_tag': 'NONE'}]}]}],
#    'sentimented_entity_list': [{'form': 'policía',
#      'id': '5d2df7073a370',
#      'type': 'Top>Organization',
#      'score_tag': 'NONE'}],
#    'sentimented_concept_list': [{'form': 'represión',
#      'id': '0387a12e30',
#      'type': 'Top',
#      'score_tag': 'N+'},
#     {'form': 'hombre',
#      'id': '20a218cbdf',
#      'type': 'Top>Person',
#      'score_tag': 'NONE'},
#     {'form': 'grupo',
#      'id': '2d2ce0cce8',
#      'type': 'Top>Organization',
#      'score_tag': 'N+'},
#     {'form': 'barrera', 'id': '757b4c802f', 'type': 'Top', 'score_tag': 'N+'},
#     {'form': 'cuerpo',
#      'id': 'a21dd2d1b5',
#      'type': 'Top>Organization',
#      'score_tag': 'N+'},
#     {'form': 'cuerpo', 'id': 'b09f3b72bb', 'type': 'Top', 'score_tag': 'N+'},
#     {'form': 'barrero',
#      'id': 'b6498cb7b9',
#      'type': 'Top>OtherEntity>Vocation',
#      'score_tag': 'N+'},
#     {'form': 'piso',
#      'id': 'f8052aa1f8',
#      'type': 'Top>Location>Facility',
#      'score_tag': 'N+'}]},
#   {'text': 'El video de la represión policial contra los trabajadores migrantes en Flores pic.twitter.com/h0U82vwUB9',
#    'inip': '855',
#    'endp': '958',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'El video de la represión policial contra los trabajadores migrantes en Flores pic.twitter.com/h0U82vwUB9',
#      'segment_type': 'main',
#      'inip': '855',
#      'endp': '958',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'represión',
#        'inip': '870',
#        'endp': '878',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_entity_list': [{'form': 'Flores',
#          'id': '5d2f11b7d930f',
#          'variant': 'Flores',
#          'inip': '926',
#          'endp': '931',
#          'type': 'Top>neighborhood',
#          'score_tag': 'N'},
#         {'form': 'pic.twitter.com/h0U82vwUB9',
#          'id': '__12058973206649548745',
#          'variant': 'pic.twitter.com/h0U82vwUB9',
#          'inip': '933',
#          'endp': '958',
#          'type': 'Top>Id>Url',
#          'score_tag': 'N'}]},
#       {'text': 'contra',
#        'inip': '889',
#        'endp': '894',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_entity_list': [{'form': 'Flores',
#          'id': '5d2f11b7d930f',
#          'variant': 'Flores',
#          'inip': '926',
#          'endp': '931',
#          'type': 'Top>neighborhood',
#          'score_tag': 'N'},
#         {'form': 'pic.twitter.com/h0U82vwUB9',
#          'id': '__12058973206649548745',
#          'variant': 'pic.twitter.com/h0U82vwUB9',
#          'inip': '933',
#          'endp': '958',
#          'type': 'Top>Id>Url',
#          'score_tag': 'N'}]}],
#      'sentimented_entity_list': [{'form': 'policía',
#        'id': '5d2df7073a370',
#        'variant': 'policial',
#        'inip': '880',
#        'endp': '887',
#        'type': 'Top>Organization',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'represión',
#        'id': '0387a12e30',
#        'variant': 'represión',
#        'inip': '870',
#        'endp': '878',
#        'type': 'Top',
#        'score_tag': 'NONE'},
#       {'form': 'trabajador migrante',
#        'id': 'aa6d8064f5',
#        'variant': 'trabajadores migrantes',
#        'inip': '900',
#        'endp': '921',
#        'type': 'Top',
#        'score_tag': 'NONE'}],
#      'segment_list': [{'text': 'la represión policial contra los trabajadores migrantes',
#        'segment_type': 'main',
#        'inip': '867',
#        'endp': '921',
#        'confidence': '100',
#        'score_tag': 'N',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'represión',
#          'inip': '870',
#          'endp': '878',
#          'confidence': '100',
#          'score_tag': 'N',
#          'sentimented_concept_list': [{'form': 'represión',
#            'id': '0387a12e30',
#            'variant': 'represión',
#            'inip': '870',
#            'endp': '878',
#            'type': 'Top',
#            'score_tag': 'N'},
#           {'form': 'trabajador migrante',
#            'id': 'aa6d8064f5',
#            'variant': 'trabajadores migrantes',
#            'inip': '900',
#            'endp': '921',
#            'type': 'Top',
#            'score_tag': 'N'}]},
#         {'text': 'contra',
#          'inip': '889',
#          'endp': '894',
#          'confidence': '100',
#          'score_tag': 'N',
#          'sentimented_concept_list': [{'form': 'represión',
#            'id': '0387a12e30',
#            'variant': 'represión',
#            'inip': '870',
#            'endp': '878',
#            'type': 'Top',
#            'score_tag': 'N'},
#           {'form': 'trabajador migrante',
#            'id': 'aa6d8064f5',
#            'variant': 'trabajadores migrantes',
#            'inip': '900',
#            'endp': '921',
#            'type': 'Top',
#            'score_tag': 'N'}]}],
#        'sentimented_entity_list': [{'form': 'policía',
#          'id': '5d2df7073a370',
#          'variant': 'policial',
#          'inip': '880',
#          'endp': '887',
#          'type': 'Top>Organization',
#          'score_tag': 'NONE'}]}]}],
#    'sentimented_entity_list': [{'form': 'policía',
#      'id': '5d2df7073a370',
#      'type': 'Top>Organization',
#      'score_tag': 'NONE'},
#     {'form': 'Flores',
#      'id': '5d2f11b7d930f',
#      'type': 'Top>neighborhood',
#      'score_tag': 'N'},
#     {'form': 'pic.twitter.com/h0U82vwUB9',
#      'id': '__12058973206649548745',
#      'type': 'Top>Id>Url',
#      'score_tag': 'N'}],
#    'sentimented_concept_list': [{'form': 'represión',
#      'id': '0387a12e30',
#      'type': 'Top',
#      'score_tag': 'N'},
#     {'form': 'trabajador migrante',
#      'id': 'aa6d8064f5',
#      'type': 'Top',
#      'score_tag': 'N'}]},
#   {'text': '— cosecha roja (@cosecharoja) June 5, 2018 No es la primera vez que la Policía de la Ciudad reprime a trabajadores senegaleses.',
#    'inip': '965',
#    'endp': '1092',
#    'bop': 'n',
#    'confidence': '92',
#    'score_tag': 'P',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': '— cosecha roja (@cosecharoja) June 5, 2018 No es la primera vez que la Policía de la Ciudad reprime a trabajadores senegaleses',
#      'segment_type': 'main',
#      'inip': '965',
#      'endp': '1091',
#      'confidence': '92',
#      'score_tag': 'P',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': '(no) reprimir',
#        'inip': '1058',
#        'endp': '1064',
#        'confidence': '92',
#        'score_tag': 'P',
#        'sentimented_entity_list': [{'form': '@cosecharoja',
#          'id': '__17520478762759528415',
#          'variant': '@cosecharoja',
#          'inip': '981',
#          'endp': '992',
#          'type': 'Top>Id>Nickname',
#          'score_tag': 'P'}]}],
#      'sentimented_entity_list': [{'form': 'Senegalés',
#        'id': '5d2df4f6a4caf',
#        'variant': 'senegaleses',
#        'inip': '1081',
#        'endp': '1091',
#        'type': 'Top>Nacionalidad',
#        'score_tag': 'NONE'},
#       {'form': 'policía',
#        'id': '5d2df7073a370',
#        'variant': 'la Policía de la Ciudad',
#        'inip': '1034',
#        'endp': '1056',
#        'type': 'Top>Organization',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'trabajador',
#        'id': '04956a16c6',
#        'variant': 'trabajadores',
#        'inip': '1068',
#        'endp': '1079',
#        'type': 'Top>OtherEntity>Vocation',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [{'form': 'Senegalés',
#      'id': '5d2df4f6a4caf',
#      'type': 'Top>Nacionalidad',
#      'score_tag': 'NONE'},
#     {'form': 'policía',
#      'id': '5d2df7073a370',
#      'type': 'Top>Organization',
#      'score_tag': 'N'},
#     {'form': '@cosecharoja',
#      'id': '__17520478762759528415',
#      'type': 'Top>Id>Nickname',
#      'score_tag': 'P'}],
#    'sentimented_concept_list': [{'form': 'trabajador',
#      'id': '04956a16c6',
#      'type': 'Top>OtherEntity>Vocation',
#      'score_tag': 'N'}]},
#   {'text': 'En noviembre del año pasado efectivos de la Comisaría 16 le quisieron secuestrar la mercadería a un hombre senegalés que circulaba por la plaza de Once.',
#    'inip': '1094',
#    'endp': '1245',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N+',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'En noviembre del año pasado efectivos de la Comisaría 16 le quisieron secuestrar la mercadería a un hombre senegalés que circulaba por la plaza de Once',
#      'segment_type': 'main',
#      'inip': '1094',
#      'endp': '1244',
#      'confidence': '100',
#      'score_tag': 'N+',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': '(querer) secuestrar',
#        'inip': '1164',
#        'endp': '1173',
#        'confidence': '100',
#        'score_tag': 'N+',
#        'sentimented_concept_list': [{'form': 'hombre',
#          'id': '20a218cbdf',
#          'variant': 'hombre',
#          'inip': '1194',
#          'endp': '1199',
#          'type': 'Top>Person',
#          'score_tag': 'N+'}]}],
#      'sentimented_entity_list': [{'form': 'Senegalés',
#        'id': '5d2df4f6a4caf',
#        'variant': 'senegalés',
#        'inip': '1201',
#        'endp': '1209',
#        'type': 'Top>Nacionalidad',
#        'score_tag': 'NONE'},
#       {'form': 'plaza de Once',
#        'id': '__3458623921430058028',
#        'variant': 'plaza de Once',
#        'inip': '1232',
#        'endp': '1244',
#        'type': 'Top>Location>Address',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'comisaría',
#        'id': 'd32a5bd869',
#        'variant': 'Comisaría',
#        'inip': '1138',
#        'endp': '1146',
#        'type': 'Top>Location>Facility',
#        'score_tag': 'NONE'}],
#      'segment_list': [{'text': 'En noviembre del año pasado efectivos de la Comisaría 16',
#        'segment_type': 'main',
#        'inip': '1094',
#        'endp': '1149',
#        'confidence': '100',
#        'score_tag': 'P',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'efectivo@A',
#          'inip': '1122',
#          'endp': '1130',
#          'confidence': '100',
#          'score_tag': 'P'}],
#        'sentimented_concept_list': [{'form': 'comisaría',
#          'id': 'd32a5bd869',
#          'variant': 'Comisaría',
#          'inip': '1138',
#          'endp': '1146',
#          'type': 'Top>Location>Facility',
#          'score_tag': 'NONE'}]}]}],
#    'sentimented_entity_list': [{'form': 'Senegalés',
#      'id': '5d2df4f6a4caf',
#      'type': 'Top>Nacionalidad',
#      'score_tag': 'NONE'},
#     {'form': 'plaza de Once',
#      'id': '__3458623921430058028',
#      'type': 'Top>Location>Address',
#      'score_tag': 'NONE'}],
#    'sentimented_concept_list': [{'form': 'hombre',
#      'id': '20a218cbdf',
#      'type': 'Top>Person',
#      'score_tag': 'N+'},
#     {'form': 'comisaría',
#      'id': 'd32a5bd869',
#      'type': 'Top>Location>Facility',
#      'score_tag': 'NONE'}]},
#   {'text': 'El hombre se aferró a su tabla.',
#    'inip': '1247',
#    'endp': '1277',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'NONE',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'El hombre se aferró a su tabla',
#      'segment_type': 'secondary',
#      'inip': '1247',
#      'endp': '1276',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_concept_list': [{'form': 'hombre',
#        'id': '20a218cbdf',
#        'variant': 'hombre',
#        'inip': '1250',
#        'endp': '1255',
#        'type': 'Top>Person',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': [{'form': 'hombre',
#      'id': '20a218cbdf',
#      'type': 'Top>Person',
#      'score_tag': 'NONE'}]},
#   {'text': 'Uno de los policías lo agarró del cuello y lo tiró al piso.',
#    'inip': '1279',
#    'endp': '1337',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'NONE',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Uno de los policías lo agarró del cuello',
#      'segment_type': 'secondary',
#      'inip': '1279',
#      'endp': '1318',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_entity_list': [{'form': 'policía',
#        'id': '5d2df7073a370',
#        'variant': 'los policías',
#        'inip': '1286',
#        'endp': '1297',
#        'type': 'Top>Organization',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'cuello',
#        'id': 'dd7242134c',
#        'variant': 'cuello',
#        'inip': '1313',
#        'endp': '1318',
#        'type': 'Top>LivingThing>BodyPart',
#        'score_tag': 'NONE'}]},
#     {'text': 'lo tiró al piso',
#      'segment_type': 'secondary',
#      'inip': '1322',
#      'endp': '1336',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_concept_list': [{'form': 'piso',
#        'id': 'f8052aa1f8',
#        'variant': 'piso',
#        'inip': '1333',
#        'endp': '1336',
#        'type': 'Top>Location>Facility',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [{'form': 'policía',
#      'id': '5d2df7073a370',
#      'type': 'Top>Organization',
#      'score_tag': 'NONE'}],
#    'sentimented_concept_list': [{'form': 'cuello',
#      'id': 'dd7242134c',
#      'type': 'Top>LivingThing>BodyPart',
#      'score_tag': 'NONE'},
#     {'form': 'piso',
#      'id': 'f8052aa1f8',
#      'type': 'Top>Location>Facility',
#      'score_tag': 'NONE'}]},
#   {'text': 'Otro lo pisó con el bolceguí en la espalda, haciendo la fuerza suficiente para asfixiarlo.',
#    'inip': '1339',
#    'endp': '1428',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Otro lo pisó con el bolceguí en la espalda, haciendo la fuerza suficiente para asfixiarlo',
#      'segment_type': 'main',
#      'inip': '1339',
#      'endp': '1427',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'pisar',
#        'inip': '1347',
#        'endp': '1350',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_concept_list': [{'form': 'espalda',
#          'id': 'c485bdade4',
#          'variant': 'espalda',
#          'inip': '1374',
#          'endp': '1380',
#          'type': 'Top>LivingThing>BodyPart',
#          'score_tag': 'N'}]}],
#      'segment_list': [{'text': 'la fuerza suficiente para asfixiarlo',
#        'segment_type': 'main',
#        'inip': '1392',
#        'endp': '1427',
#        'confidence': '100',
#        'score_tag': 'N',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'asfixiar',
#          'inip': '1418',
#          'endp': '1427',
#          'confidence': '100',
#          'score_tag': 'N'}]}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': [{'form': 'espalda',
#      'id': 'c485bdade4',
#      'type': 'Top>LivingThing>BodyPart',
#      'score_tag': 'N'}]},
#   {'text': 'Entre los forcejeos de la gente, el hombre logró escapar.',
#    'inip': '1431',
#    'endp': '1487',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'P',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Entre los forcejeos de la gente, el hombre logró escapar',
#      'segment_type': 'main',
#      'inip': '1431',
#      'endp': '1486',
#      'confidence': '100',
#      'score_tag': 'P',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'lograr',
#        'inip': '1474',
#        'endp': '1478',
#        'confidence': '100',
#        'score_tag': 'P',
#        'sentimented_concept_list': [{'form': 'hombre',
#          'id': '20a218cbdf',
#          'variant': 'hombre',
#          'inip': '1467',
#          'endp': '1472',
#          'type': 'Top>Person',
#          'score_tag': 'P'}]}],
#      'sentimented_concept_list': [{'form': 'gente',
#        'id': '0e4a93483a',
#        'variant': 'gente',
#        'inip': '1457',
#        'endp': '1461',
#        'type': 'Top>Person',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': [{'form': 'gente',
#      'id': '0e4a93483a',
#      'type': 'Top>Person',
#      'score_tag': 'NONE'},
#     {'form': 'hombre',
#      'id': '20a218cbdf',
#      'type': 'Top>Person',
#      'score_tag': 'P'}]},
#   {'text': 'Dos horas después la policía volvió a la plaza.',
#    'inip': '1489',
#    'endp': '1535',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'NONE',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Dos horas después la policía volvió a la plaza',
#      'segment_type': 'secondary',
#      'inip': '1489',
#      'endp': '1534',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_entity_list': [{'form': 'policía',
#        'id': '5d2df7073a370',
#        'variant': 'policía',
#        'inip': '1510',
#        'endp': '1516',
#        'type': 'Top>Organization',
#        'score_tag': 'NONE'},
#       {'form': 'plaza de Once',
#        'id': '__3458623921430058028',
#        'variant': 'plaza',
#        'inip': '1530',
#        'endp': '1534',
#        'type': 'Top>Location>Address',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [{'form': 'policía',
#      'id': '5d2df7073a370',
#      'type': 'Top>Organization',
#      'score_tag': 'NONE'},
#     {'form': 'plaza de Once',
#      'id': '__3458623921430058028',
#      'type': 'Top>Location>Address',
#      'score_tag': 'NONE'}],
#    'sentimented_concept_list': []},
#   {'text': '“Salieron a cazar negros”, contó un testigo.',
#    'inip': '1537',
#    'endp': '1580',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'NONE',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': '“Salieron a cazar negros”',
#      'segment_type': 'secondary',
#      'inip': '1537',
#      'endp': '1561',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_concept_list': [{'form': 'negro',
#        'id': '2408c36eb8',
#        'variant': 'negros',
#        'inip': '1555',
#        'endp': '1560',
#        'type': 'Top>OtherEntity>Color',
#        'score_tag': 'NONE'},
#       {'form': 'negro',
#        'id': '977deaea89',
#        'variant': 'negros',
#        'inip': '1555',
#        'endp': '1560',
#        'type': 'Top>Person',
#        'score_tag': 'NONE'}]},
#     {'text': 'contó un testigo',
#      'segment_type': 'secondary',
#      'inip': '1564',
#      'endp': '1579',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_concept_list': [{'form': 'testigo',
#        'id': 'bfa33bf4e4',
#        'variant': 'testigo',
#        'inip': '1573',
#        'endp': '1579',
#        'type': 'Top',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': [{'form': 'negro',
#      'id': '2408c36eb8',
#      'type': 'Top>OtherEntity>Color',
#      'score_tag': 'NONE'},
#     {'form': 'negro',
#      'id': '977deaea89',
#      'type': 'Top>Person',
#      'score_tag': 'NONE'},
#     {'form': 'testigo',
#      'id': 'bfa33bf4e4',
#      'type': 'Top',
#      'score_tag': 'NONE'}]},
#   {'text': '“Ya no importaba que estuviesen vendiendo o no.',
#    'inip': '1582',
#    'endp': '1628',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'NONE',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': '“',
#      'segment_type': 'secondary',
#      'inip': '1582',
#      'endp': '1582',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': []},
#     {'text': 'no importaba',
#      'segment_type': 'main',
#      'inip': '1586',
#      'endp': '1597',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': []},
#     {'text': 'estuviesen vendiendo',
#      'segment_type': 'secondary',
#      'inip': '1603',
#      'endp': '1622',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': []},
#     {'text': 'no',
#      'segment_type': 'main',
#      'inip': '1626',
#      'endp': '1627',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': []}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': []},
#   {'text': 'Intentaban detener a todo aquel que tuviera piel oscura”.',
#    'inip': '1630',
#    'endp': '1686',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Intentaban detener a todo aquel que tuviera piel oscura”',
#      'segment_type': 'main',
#      'inip': '1630',
#      'endp': '1685',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'detener a',
#        'inip': '1641',
#        'endp': '1649',
#        'confidence': '100',
#        'score_tag': 'N'}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': []},
#   {'text': 'Se llevaron a cinco detenidos.',
#    'inip': '1689',
#    'endp': '1718',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Se llevaron a cinco detenidos',
#      'segment_type': 'main',
#      'inip': '1689',
#      'endp': '1717',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'detenido',
#        'inip': '1709',
#        'endp': '1717',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_concept_list': [{'form': 'detenido',
#          'id': '9dcebf9e40',
#          'variant': 'detenidos',
#          'inip': '1709',
#          'endp': '1717',
#          'type': 'Top>Person',
#          'score_tag': 'N'},
#         {'form': 'detenido',
#          'id': 'e7964d6701',
#          'variant': 'detenidos',
#          'inip': '1709',
#          'endp': '1717',
#          'type': 'Top>Person',
#          'score_tag': 'N'}]}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': [{'form': 'detenido',
#      'id': '9dcebf9e40',
#      'type': 'Top>Person',
#      'score_tag': 'N'},
#     {'form': 'detenido',
#      'id': 'e7964d6701',
#      'type': 'Top>Person',
#      'score_tag': 'N'}]},
#   {'text': 'Los acusaron de “resistencia a la autoridad y daños”.',
#    'inip': '1720',
#    'endp': '1772',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Los acusaron de “resistencia a la autoridad y daños”',
#      'segment_type': 'main',
#      'inip': '1720',
#      'endp': '1771',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'acusar',
#        'inip': '1724',
#        'endp': '1731',
#        'confidence': '100',
#        'score_tag': 'N'}],
#      'sentimented_concept_list': [{'form': 'autoridad',
#        'id': '66a90f4267',
#        'variant': 'autoridad',
#        'inip': '1754',
#        'endp': '1762',
#        'type': 'Top>OtherEntity>Vocation',
#        'score_tag': 'NONE'},
#       {'form': 'estrago',
#        'id': 'ab306b79fd',
#        'variant': 'daños',
#        'inip': '1766',
#        'endp': '1770',
#        'type': 'Top',
#        'score_tag': 'NONE'},
#       {'form': 'daños',
#        'id': 'f008122c40',
#        'variant': 'daños',
#        'inip': '1766',
#        'endp': '1770',
#        'type': 'Top>OtherEntity>Offence',
#        'score_tag': 'NONE'},
#       {'form': 'resistencia',
#        'id': 'fc6a254514',
#        'variant': 'resistencia',
#        'inip': '1737',
#        'endp': '1747',
#        'type': 'Top',
#        'score_tag': 'NONE'}],
#      'segment_list': [{'text': '“resistencia a la autoridad y daños”',
#        'segment_type': 'main',
#        'inip': '1736',
#        'endp': '1771',
#        'confidence': '100',
#        'score_tag': 'N',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'daño',
#          'inip': '1766',
#          'endp': '1770',
#          'confidence': '100',
#          'score_tag': 'N'}],
#        'sentimented_concept_list': [{'form': 'autoridad',
#          'id': '66a90f4267',
#          'variant': 'autoridad',
#          'inip': '1754',
#          'endp': '1762',
#          'type': 'Top>OtherEntity>Vocation',
#          'score_tag': 'NONE'},
#         {'form': 'estrago',
#          'id': 'ab306b79fd',
#          'variant': 'daños',
#          'inip': '1766',
#          'endp': '1770',
#          'type': 'Top',
#          'score_tag': 'NONE'},
#         {'form': 'daños',
#          'id': 'f008122c40',
#          'variant': 'daños',
#          'inip': '1766',
#          'endp': '1770',
#          'type': 'Top>OtherEntity>Offence',
#          'score_tag': 'NONE'},
#         {'form': 'resistencia',
#          'id': 'fc6a254514',
#          'variant': 'resistencia',
#          'inip': '1737',
#          'endp': '1747',
#          'type': 'Top',
#          'score_tag': 'NONE'}]}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': [{'form': 'autoridad',
#      'id': '66a90f4267',
#      'type': 'Top>OtherEntity>Vocation',
#      'score_tag': 'NONE'},
#     {'form': 'estrago',
#      'id': 'ab306b79fd',
#      'type': 'Top',
#      'score_tag': 'NONE'},
#     {'form': 'daños',
#      'id': 'f008122c40',
#      'type': 'Top>OtherEntity>Offence',
#      'score_tag': 'NONE'},
#     {'form': 'resistencia',
#      'id': 'fc6a254514',
#      'type': 'Top',
#      'score_tag': 'NONE'}]},
#   {'text': 'Estuvieron en la comisaría 16 hasta las 11:30 de la noche.',
#    'inip': '1774',
#    'endp': '1831',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'NONE',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Estuvieron en la comisaría 16 hasta las 11:30 de la noche',
#      'segment_type': 'secondary',
#      'inip': '1774',
#      'endp': '1830',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_concept_list': [{'form': 'comisaría',
#        'id': 'd32a5bd869',
#        'variant': 'comisaría',
#        'inip': '1791',
#        'endp': '1799',
#        'type': 'Top>Location>Facility',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': [{'form': 'comisaría',
#      'id': 'd32a5bd869',
#      'type': 'Top>Location>Facility',
#      'score_tag': 'NONE'}]},
#   {'text': 'Afuera los recibió una movilización solidaria.',
#    'inip': '1833',
#    'endp': '1878',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'P',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Afuera los recibió una movilización solidaria',
#      'segment_type': 'main',
#      'inip': '1833',
#      'endp': '1877',
#      'confidence': '100',
#      'score_tag': 'P',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'solidario',
#        'inip': '1869',
#        'endp': '1877',
#        'confidence': '100',
#        'score_tag': 'P'}],
#      'sentimented_concept_list': [{'form': 'solidario',
#        'id': '9637317dd4',
#        'variant': 'solidaria',
#        'inip': '1869',
#        'endp': '1877',
#        'type': 'Top',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': [{'form': 'solidario',
#      'id': '9637317dd4',
#      'type': 'Top',
#      'score_tag': 'NONE'}]}],
#  'sentimented_entity_list': [{'form': 'Senegalés',
#    'id': '5d2df4f6a4caf',
#    'type': 'Top>Nacionalidad',
#    'score_tag': 'NONE'},
#   {'form': 'policía',
#    'id': '5d2df7073a370',
#    'type': 'Top>Organization',
#    'score_tag': 'N'},
#   {'form': 'Buenos Aires',
#    'id': '5d2df9543aa42',
#    'type': 'Top>Location>GeoPoliticalEntity>City',
#    'score_tag': 'NONE'},
#   {'form': 'Serigne Dame Kane',
#    'id': '5d2dfcf0ae119',
#    'type': 'Top>Person',
#    'score_tag': 'N'},
#   {'form': 'Flores',
#    'id': '5d2f11b7d930f',
#    'type': 'Top>neighborhood',
#    'score_tag': 'N'},
#   {'form': 'pic.twitter.com/h0U82vwUB9',
#    'id': '__12058973206649548745',
#    'type': 'Top>Id>Url',
#    'score_tag': 'N'},
#   {'form': 'Cosecha Roja',
#    'id': '__12233334718966634480',
#    'type': 'Top',
#    'score_tag': 'NONE'},
#   {'form': '@cosecharoja',
#    'id': '__17520478762759528415',
#    'type': 'Top>Id>Nickname',
#    'score_tag': 'P'},
#   {'form': 'Hospital Álvarez',
#    'id': '__3344804039205521094',
#    'type': 'Top>Organization>Company>HealthcareCompany>HealthcareServicesCompany>Hospitals',
#    'score_tag': 'NONE'},
#   {'form': 'plaza de Once',
#    'id': '__3458623921430058028',
#    'type': 'Top>Location>Address',
#    'score_tag': 'NONE'},
#   {'form': 'Infantería de la Policía de la Ciudad',
#    'id': '__4978655492218510607',
#    'type': 'Top',
#    'score_tag': 'NONE'}],
#  'sentimented_concept_list': [{'form': 'represión',
#    'id': '0387a12e30',
#    'type': 'Top',
#    'score_tag': 'N+'},
#   {'form': 'trabajador',
#    'id': '04956a16c6',
#    'type': 'Top>OtherEntity>Vocation',
#    'score_tag': 'N'},
#   {'form': 'agente',
#    'id': '0cc03e7181',
#    'type': 'Top>Person',
#    'score_tag': 'N'},
#   {'form': 'gente',
#    'id': '0e4a93483a',
#    'type': 'Top>Person',
#    'score_tag': 'NONE'},
#   {'form': 'fractura',
#    'id': '16ff59d24a',
#    'type': 'Top>OtherEntity>Disease',
#    'score_tag': 'N'},
#   {'form': 'red social',
#    'id': '1f1d00751f',
#    'type': 'Top',
#    'score_tag': 'NONE'},
#   {'form': 'hombre',
#    'id': '20a218cbdf',
#    'type': 'Top>Person',
#    'score_tag': 'N'},
#   {'form': 'negro',
#    'id': '2408c36eb8',
#    'type': 'Top>OtherEntity>Color',
#    'score_tag': 'NONE'},
#   {'form': 'brazo',
#    'id': '24cdb52d12',
#    'type': 'Top>LivingThing>BodyPart',
#    'score_tag': 'N'},
#   {'form': 'dolor',
#    'id': '2c30c78d53',
#    'type': 'Top>OtherEntity>Disease',
#    'score_tag': 'N'},
#   {'form': 'grupo',
#    'id': '2d2ce0cce8',
#    'type': 'Top>Organization',
#    'score_tag': 'N+'},
#   {'form': 'médico',
#    'id': '305c40967f',
#    'type': 'Top>OtherEntity>Vocation',
#    'score_tag': 'N'},
#   {'form': 'agente',
#    'id': '34049c0818',
#    'type': 'Top>Person',
#    'score_tag': 'N'},
#   {'form': 'fotografía',
#    'id': '4e1219a1da',
#    'type': 'Top>Product',
#    'score_tag': 'NONE'},
#   {'form': 'ciudadano',
#    'id': '512e1a8ba7',
#    'type': 'Top>Person',
#    'score_tag': 'N'},
#   {'form': 'suelo',
#    'id': '599093b066',
#    'type': 'Top>Location',
#    'score_tag': 'NONE'},
#   {'form': 'autoridad',
#    'id': '66a90f4267',
#    'type': 'Top>OtherEntity>Vocation',
#    'score_tag': 'NONE'},
#   {'form': 'barrera', 'id': '757b4c802f', 'type': 'Top', 'score_tag': 'N+'},
#   {'form': 'vecino',
#    'id': '7a0b4e931e',
#    'type': 'Top>Person',
#    'score_tag': 'N'},
#   {'form': 'vidriero',
#    'id': '8f3616613c',
#    'type': 'Top>OtherEntity>Vocation',
#    'score_tag': 'N'},
#   {'form': 'solidario',
#    'id': '9637317dd4',
#    'type': 'Top',
#    'score_tag': 'NONE'},
#   {'form': 'negro',
#    'id': '977deaea89',
#    'type': 'Top>Person',
#    'score_tag': 'NONE'},
#   {'form': 'vidriera',
#    'id': '9b9d78cb73',
#    'type': 'Top>Product',
#    'score_tag': 'N'},
#   {'form': 'detenido',
#    'id': '9dcebf9e40',
#    'type': 'Top>Person',
#    'score_tag': 'N'},
#   {'form': 'cuerpo',
#    'id': 'a21dd2d1b5',
#    'type': 'Top>Organization',
#    'score_tag': 'N+'},
#   {'form': 'trabajador migrante',
#    'id': 'aa6d8064f5',
#    'type': 'Top',
#    'score_tag': 'N'},
#   {'form': 'estrago', 'id': 'ab306b79fd', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'cuerpo', 'id': 'b09f3b72bb', 'type': 'Top', 'score_tag': 'N+'},
#   {'form': 'barrero',
#    'id': 'b6498cb7b9',
#    'type': 'Top>OtherEntity>Vocation',
#    'score_tag': 'N+'},
#   {'form': 'testigo', 'id': 'bfa33bf4e4', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'espalda',
#    'id': 'c485bdade4',
#    'type': 'Top>LivingThing>BodyPart',
#    'score_tag': 'N'},
#   {'form': 'agente',
#    'id': 'ce19c885fb',
#    'type': 'Top>OtherEntity>Vocation',
#    'score_tag': 'N'},
#   {'form': 'comisaría',
#    'id': 'd32a5bd869',
#    'type': 'Top>Location>Facility',
#    'score_tag': 'NONE'},
#   {'form': 'cuello',
#    'id': 'dd7242134c',
#    'type': 'Top>LivingThing>BodyPart',
#    'score_tag': 'NONE'},
#   {'form': 'detenido',
#    'id': 'e7964d6701',
#    'type': 'Top>Person',
#    'score_tag': 'N'},
#   {'form': 'daños',
#    'id': 'f008122c40',
#    'type': 'Top>OtherEntity>Offence',
#    'score_tag': 'NONE'},
#   {'form': 'vidriera',
#    'id': 'f05d3a6974',
#    'type': 'Top>Location>Facility>Market',
#    'score_tag': 'N'},
#   {'form': 'charco',
#    'id': 'f065f3b2db',
#    'type': 'Top>Location>GeographicalEntity>WaterForm',
#    'score_tag': 'NONE'},
#   {'form': 'piso',
#    'id': 'f8052aa1f8',
#    'type': 'Top>Location>Facility',
#    'score_tag': 'N+'},
#   {'form': 'resistencia',
#    'id': 'fc6a254514',
#    'type': 'Top',
#    'score_tag': 'NONE'}]}

# %%
#guardamos nuestra lista con pickle
pickle.dump(sentiment_analysis, open("corpus_sentimiento", "wb"))

# %% [markdown]
# ## 4. Organización de los datos en un panda df

# %%
#Abrimos nuestro corpus
sentiment_analysis = pickle.load(open("corpus_sentimiento", "rb"))
corpus = pickle.load(open("corpus.pkl", "rb"))
analisis_sent = sentiment_analysis

# %%
#Código para representar la info del análisis en un df
score_tag = []
agreement = []
subjectivity = []
confidence = []
irony = []

for d in analisis_sent:
    score_tag.append(d['score_tag'])
    agreement.append(d['agreement'])
    subjectivity.append(d['subjectivity'])
    confidence.append(int(d['confidence']))
    irony.append(d['irony'])
    
ZippedList = list(zip(score_tag, agreement, subjectivity, irony, confidence)) #Convertimos nuestras cinco listas en una lista de tuplas
df =pd.DataFrame(ZippedList, columns = ['Polaridad', 'Acuerdo', 'Subjetividad','Ironía', 'Confianza'])

# %%
df
# Out:
#    Polaridad       Acuerdo Subjetividad     Ironía  Confianza
# 0          N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 1          N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 2          N  DISAGREEMENT   SUBJECTIVE     IRONIC         76
# 3          N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 4        NEU  DISAGREEMENT   SUBJECTIVE     IRONIC         76
# 5          N  DISAGREEMENT   SUBJECTIVE     IRONIC         76
# 6        NEU  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 7        NEU  DISAGREEMENT   SUBJECTIVE  NONIRONIC         91
# 8          P  DISAGREEMENT   SUBJECTIVE     IRONIC         76
# 9        NEU  DISAGREEMENT   SUBJECTIVE  NONIRONIC         82
# 10       NEU  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 11         P  DISAGREEMENT   SUBJECTIVE     IRONIC         76
# 12       NEU  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 13         P  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 14         P  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 15         P  DISAGREEMENT   SUBJECTIVE  NONIRONIC         91
# 16         P  DISAGREEMENT   SUBJECTIVE  NONIRONIC         84
# 17         P  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 18       NEU  DISAGREEMENT   SUBJECTIVE  NONIRONIC         94
# 19         P  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 20         P  DISAGREEMENT   SUBJECTIVE  NONIRONIC         83
# 21       NEU  DISAGREEMENT   SUBJECTIVE     IRONIC         76
# 22         P  DISAGREEMENT   SUBJECTIVE  NONIRONIC         91
# 23         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 24         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 25         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 26       NEU  DISAGREEMENT   SUBJECTIVE  NONIRONIC         83
# 27         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 28         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 29         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         84
# ..       ...           ...          ...        ...        ...
# 57         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         91
# 58         N     AGREEMENT   SUBJECTIVE  NONIRONIC         89
# 59       NEU  DISAGREEMENT   SUBJECTIVE     IRONIC         76
# 60         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         83
# 61         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         84
# 62         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         91
# 63         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         91
# 64         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 65         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 66         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 67       NEU  DISAGREEMENT   SUBJECTIVE  NONIRONIC         92
# 68         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 69         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         84
# 70         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         84
# 71         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         91
# 72         N     AGREEMENT   SUBJECTIVE  NONIRONIC         89
# 73         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         83
# 74         N     AGREEMENT   SUBJECTIVE  NONIRONIC         92
# 75         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 76         N  DISAGREEMENT   SUBJECTIVE     IRONIC         84
# 77         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 78         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 79         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 80         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         91
# 81         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         91
# 82         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 83         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 84         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         84
# 85         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
# 86         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC         86
#
# [87 rows x 5 columns]

# %%
#prueba de un diccionario
sentiment_analysis[59]
# Out:
# {'status': {'code': '0',
#   'msg': 'OK',
#   'credits': '4',
#   'remaining_credits': '18410'},
#  'model': 'general_es',
#  'score_tag': 'NEU',
#  'agreement': 'DISAGREEMENT',
#  'subjectivity': 'SUBJECTIVE',
#  'confidence': '76',
#  'irony': 'IRONIC',
#  'sentence_list': [{'text': 'Inmigrantes senegaleses son víctimas de violencia en Argentina Por Daniel Gutman © Reproducir este artículo| | Imprimir | |English version La violencia de la Policía de Buenos Aires hacia vendedores ambulantes senegaleses en los últimos meses han indignado a argentinos e inmigrantes que el 16 de junio se manifestaron contra estos hechos en la capital.',
#    'inip': '1',
#    'endp': '353',
#    'bop': 'y',
#    'confidence': '100',
#    'score_tag': 'N+',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Inmigrantes senegaleses son víctimas de violencia en Argentina Por Daniel Gutman © Reproducir este artículo| | Imprimir | |English version La violencia de la Policía de Buenos Aires hacia vendedores ambulantes senegaleses en los últimos meses han indignado a argentinos e inmigrantes que el 16 de junio se manifestaron contra estos hechos en la capital',
#      'segment_type': 'main',
#      'inip': '1',
#      'endp': '352',
#      'confidence': '100',
#      'score_tag': 'N+',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'víctima',
#        'inip': '29',
#        'endp': '36',
#        'confidence': '100',
#        'score_tag': 'N+',
#        'sentimented_entity_list': [{'form': 'Argentina',
#          'id': 'efb13c2f4e',
#          'variant': 'Argentina',
#          'inip': '54',
#          'endp': '62',
#          'type': 'Top>Location>GeoPoliticalEntity>Country',
#          'score_tag': 'N+'}],
#        'sentimented_concept_list': [{'form': 'inmigrante',
#          'id': 'ee789984b3',
#          'variant': 'Inmigrantes',
#          'inip': '1',
#          'endp': '11',
#          'type': 'Top>Person',
#          'score_tag': 'N+'},
#         {'form': 'víctima',
#          'id': '258214e1e7',
#          'variant': 'víctimas',
#          'inip': '29',
#          'endp': '36',
#          'type': 'Top>Person',
#          'score_tag': 'N+'},
#         {'form': 'violencia',
#          'id': 'cc27dae29f',
#          'variant': 'violencia',
#          'inip': '41',
#          'endp': '49',
#          'type': 'Top>OtherEntity>Offence',
#          'score_tag': 'N+'},
#         {'form': 'argentino',
#          'id': '0d65ae0c1b',
#          'variant': 'argentinos',
#          'inip': '260',
#          'endp': '269',
#          'type': 'Top',
#          'score_tag': 'N+'}]},
#       {'text': 'violencia',
#        'inip': '41',
#        'endp': '49',
#        'confidence': '100',
#        'score_tag': 'N+',
#        'sentimented_entity_list': [{'form': 'Argentina',
#          'id': 'efb13c2f4e',
#          'variant': 'Argentina',
#          'inip': '54',
#          'endp': '62',
#          'type': 'Top>Location>GeoPoliticalEntity>Country',
#          'score_tag': 'N+'}],
#        'sentimented_concept_list': [{'form': 'inmigrante',
#          'id': 'ee789984b3',
#          'variant': 'Inmigrantes',
#          'inip': '1',
#          'endp': '11',
#          'type': 'Top>Person',
#          'score_tag': 'N+'},
#         {'form': 'víctima',
#          'id': '258214e1e7',
#          'variant': 'víctimas',
#          'inip': '29',
#          'endp': '36',
#          'type': 'Top>Person',
#          'score_tag': 'N+'},
#         {'form': 'violencia',
#          'id': 'cc27dae29f',
#          'variant': 'violencia',
#          'inip': '41',
#          'endp': '49',
#          'type': 'Top>OtherEntity>Offence',
#          'score_tag': 'N+'},
#         {'form': 'argentino',
#          'id': '0d65ae0c1b',
#          'variant': 'argentinos',
#          'inip': '260',
#          'endp': '269',
#          'type': 'Top',
#          'score_tag': 'N+'}]},
#       {'text': 'violencia',
#        'inip': '143',
#        'endp': '151',
#        'confidence': '100',
#        'score_tag': 'N+',
#        'sentimented_entity_list': [{'form': 'Argentina',
#          'id': 'efb13c2f4e',
#          'variant': 'Argentina',
#          'inip': '54',
#          'endp': '62',
#          'type': 'Top>Location>GeoPoliticalEntity>Country',
#          'score_tag': 'N+'}],
#        'sentimented_concept_list': [{'form': 'inmigrante',
#          'id': 'ee789984b3',
#          'variant': 'Inmigrantes',
#          'inip': '1',
#          'endp': '11',
#          'type': 'Top>Person',
#          'score_tag': 'N+'},
#         {'form': 'víctima',
#          'id': '258214e1e7',
#          'variant': 'víctimas',
#          'inip': '29',
#          'endp': '36',
#          'type': 'Top>Person',
#          'score_tag': 'N+'},
#         {'form': 'violencia',
#          'id': 'cc27dae29f',
#          'variant': 'violencia',
#          'inip': '41',
#          'endp': '49',
#          'type': 'Top>OtherEntity>Offence',
#          'score_tag': 'N+'},
#         {'form': 'artículo',
#          'id': '24c38dbf04',
#          'variant': 'artículo',
#          'inip': '100',
#          'endp': '107',
#          'type': 'Top',
#          'score_tag': 'N+'},
#         {'form': 'artículo',
#          'id': 'ac7531be4c',
#          'variant': 'artículo',
#          'inip': '100',
#          'endp': '107',
#          'type': 'Top>Product>CulturalProduct>Printing',
#          'score_tag': 'N+'},
#         {'form': 'violencia',
#          'id': 'cc27dae29f',
#          'variant': 'violencia',
#          'inip': '143',
#          'endp': '151',
#          'type': 'Top>OtherEntity>Offence',
#          'score_tag': 'N+'},
#         {'form': 'vendedor',
#          'id': 'dacecb32bc',
#          'variant': 'vendedores',
#          'inip': '189',
#          'endp': '198',
#          'type': 'Top>OtherEntity>Vocation',
#          'score_tag': 'N+'},
#         {'form': 'argentino',
#          'id': '0d65ae0c1b',
#          'variant': 'argentinos',
#          'inip': '260',
#          'endp': '269',
#          'type': 'Top',
#          'score_tag': 'N+'}]},
#       {'text': 'indignar',
#        'inip': '244',
#        'endp': '256',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_entity_list': [{'form': 'Argentina',
#          'id': 'efb13c2f4e',
#          'variant': 'Argentina',
#          'inip': '54',
#          'endp': '62',
#          'type': 'Top>Location>GeoPoliticalEntity>Country',
#          'score_tag': 'N'}],
#        'sentimented_concept_list': [{'form': 'inmigrante',
#          'id': 'ee789984b3',
#          'variant': 'Inmigrantes',
#          'inip': '1',
#          'endp': '11',
#          'type': 'Top>Person',
#          'score_tag': 'N'},
#         {'form': 'víctima',
#          'id': '258214e1e7',
#          'variant': 'víctimas',
#          'inip': '29',
#          'endp': '36',
#          'type': 'Top>Person',
#          'score_tag': 'N'},
#         {'form': 'violencia',
#          'id': 'cc27dae29f',
#          'variant': 'violencia',
#          'inip': '41',
#          'endp': '49',
#          'type': 'Top>OtherEntity>Offence',
#          'score_tag': 'N'},
#         {'form': 'argentino',
#          'id': '0d65ae0c1b',
#          'variant': 'argentinos',
#          'inip': '260',
#          'endp': '269',
#          'type': 'Top',
#          'score_tag': 'N'}]},
#       {'text': 'contra',
#        'inip': '320',
#        'endp': '325',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_entity_list': [{'form': 'Argentina',
#          'id': 'efb13c2f4e',
#          'variant': 'Argentina',
#          'inip': '54',
#          'endp': '62',
#          'type': 'Top>Location>GeoPoliticalEntity>Country',
#          'score_tag': 'N'}],
#        'sentimented_concept_list': [{'form': 'inmigrante',
#          'id': 'ee789984b3',
#          'variant': 'Inmigrantes',
#          'inip': '1',
#          'endp': '11',
#          'type': 'Top>Person',
#          'score_tag': 'N'},
#         {'form': 'víctima',
#          'id': '258214e1e7',
#          'variant': 'víctimas',
#          'inip': '29',
#          'endp': '36',
#          'type': 'Top>Person',
#          'score_tag': 'N'},
#         {'form': 'violencia',
#          'id': 'cc27dae29f',
#          'variant': 'violencia',
#          'inip': '41',
#          'endp': '49',
#          'type': 'Top>OtherEntity>Offence',
#          'score_tag': 'N'},
#         {'form': 'argentino',
#          'id': '0d65ae0c1b',
#          'variant': 'argentinos',
#          'inip': '260',
#          'endp': '269',
#          'type': 'Top',
#          'score_tag': 'N'}]}],
#      'sentimented_entity_list': [{'form': 'Senegalés',
#        'id': '5d2df4f6a4caf',
#        'variant': 'senegaleses',
#        'inip': '13',
#        'endp': '23',
#        'type': 'Top>Nacionalidad',
#        'score_tag': 'NONE'},
#       {'form': 'policía',
#        'id': '5d2df7073a370',
#        'variant': 'Policía de Buenos Aires',
#        'inip': '159',
#        'endp': '181',
#        'type': 'Top>Organization',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'english',
#        'id': '0faeaf8483',
#        'variant': 'English',
#        'inip': '124',
#        'endp': '130',
#        'type': 'Top>OtherEntity>Language',
#        'score_tag': 'NONE'},
#       {'form': 'capital',
#        'id': 'f929e70257',
#        'variant': 'capital',
#        'inip': '346',
#        'endp': '352',
#        'type': 'Top>Location>GeoPoliticalEntity>City',
#        'score_tag': 'NONE'}],
#      'segment_list': [{'text': 'que el 16 de junio se manifestaron contra estos hechos en la capital',
#        'segment_type': 'main',
#        'inip': '285',
#        'endp': '352',
#        'confidence': '100',
#        'score_tag': 'N',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'contra',
#          'inip': '320',
#          'endp': '325',
#          'confidence': '100',
#          'score_tag': 'N',
#          'sentimented_concept_list': [{'form': 'capital',
#            'id': 'f929e70257',
#            'variant': 'capital',
#            'inip': '346',
#            'endp': '352',
#            'type': 'Top>Location>GeoPoliticalEntity>City',
#            'score_tag': 'N'}]}]},
#       {'text': 'víctimas de violencia',
#        'segment_type': 'main',
#        'inip': '29',
#        'endp': '49',
#        'confidence': '100',
#        'score_tag': 'N+',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'víctima',
#          'inip': '29',
#          'endp': '36',
#          'confidence': '100',
#          'score_tag': 'N+',
#          'sentimented_concept_list': [{'form': 'víctima',
#            'id': '258214e1e7',
#            'variant': 'víctimas',
#            'inip': '29',
#            'endp': '36',
#            'type': 'Top>Person',
#            'score_tag': 'N+'},
#           {'form': 'violencia',
#            'id': 'cc27dae29f',
#            'variant': 'violencia',
#            'inip': '41',
#            'endp': '49',
#            'type': 'Top>OtherEntity>Offence',
#            'score_tag': 'N+'}]},
#         {'text': 'violencia',
#          'inip': '41',
#          'endp': '49',
#          'confidence': '100',
#          'score_tag': 'N+',
#          'sentimented_concept_list': [{'form': 'víctima',
#            'id': '258214e1e7',
#            'variant': 'víctimas',
#            'inip': '29',
#            'endp': '36',
#            'type': 'Top>Person',
#            'score_tag': 'N+'},
#           {'form': 'violencia',
#            'id': 'cc27dae29f',
#            'variant': 'violencia',
#            'inip': '41',
#            'endp': '49',
#            'type': 'Top>OtherEntity>Offence',
#            'score_tag': 'N+'}]}]}]}],
#    'sentimented_entity_list': [{'form': 'Senegalés',
#      'id': '5d2df4f6a4caf',
#      'type': 'Top>Nacionalidad',
#      'score_tag': 'NONE'},
#     {'form': 'policía',
#      'id': '5d2df7073a370',
#      'type': 'Top>Organization',
#      'score_tag': 'NONE'},
#     {'form': 'Argentina',
#      'id': 'efb13c2f4e',
#      'type': 'Top>Location>GeoPoliticalEntity>Country',
#      'score_tag': 'N+'}],
#    'sentimented_concept_list': [{'form': 'argentino',
#      'id': '0d65ae0c1b',
#      'type': 'Top',
#      'score_tag': 'N+'},
#     {'form': 'english',
#      'id': '0faeaf8483',
#      'type': 'Top>OtherEntity>Language',
#      'score_tag': 'NONE'},
#     {'form': 'artículo', 'id': '24c38dbf04', 'type': 'Top', 'score_tag': 'N+'},
#     {'form': 'víctima',
#      'id': '258214e1e7',
#      'type': 'Top>Person',
#      'score_tag': 'N+'},
#     {'form': 'artículo',
#      'id': 'ac7531be4c',
#      'type': 'Top>Product>CulturalProduct>Printing',
#      'score_tag': 'N+'},
#     {'form': 'violencia',
#      'id': 'cc27dae29f',
#      'type': 'Top>OtherEntity>Offence',
#      'score_tag': 'N+'},
#     {'form': 'vendedor',
#      'id': 'dacecb32bc',
#      'type': 'Top>OtherEntity>Vocation',
#      'score_tag': 'N+'},
#     {'form': 'inmigrante',
#      'id': 'ee789984b3',
#      'type': 'Top>Person',
#      'score_tag': 'N+'},
#     {'form': 'capital',
#      'id': 'f929e70257',
#      'type': 'Top>Location>GeoPoliticalEntity>City',
#      'score_tag': 'N'}]},
#   {'text': 'Dos de ellos portaban carteles donde se leía:',
#    'inip': '355',
#    'endp': '399',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'NONE',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Dos de ellos portaban carteles donde se leía:',
#      'segment_type': 'secondary',
#      'inip': '355',
#      'endp': '399',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_concept_list': [{'form': 'cartel',
#        'id': '4098636df5',
#        'variant': 'carteles',
#        'inip': '377',
#        'endp': '384',
#        'type': 'Top>Organization',
#        'score_tag': 'NONE'},
#       {'form': 'cartel',
#        'id': '5d79d8a304',
#        'variant': 'carteles',
#        'inip': '377',
#        'endp': '384',
#        'type': 'Top>OtherEntity>Rule',
#        'score_tag': 'NONE'},
#       {'form': 'cartel',
#        'id': '74d0a569f7',
#        'variant': 'carteles',
#        'inip': '377',
#        'endp': '384',
#        'type': 'Top>Product>CulturalProduct>Printing>Document',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': [{'form': 'cartel',
#      'id': '4098636df5',
#      'type': 'Top>Organization',
#      'score_tag': 'NONE'},
#     {'form': 'cartel',
#      'id': '5d79d8a304',
#      'type': 'Top>OtherEntity>Rule',
#      'score_tag': 'NONE'},
#     {'form': 'cartel',
#      'id': '74d0a569f7',
#      'type': 'Top>Product>CulturalProduct>Printing>Document',
#      'score_tag': 'NONE'}]},
#   {'text': '“dejen trabajar a los senegaleses” y “cansados de esta persecución racista”.',
#    'inip': '401',
#    'endp': '476',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': '“dejen trabajar a los senegaleses”',
#      'segment_type': 'secondary',
#      'inip': '401',
#      'endp': '434',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': []},
#     {'text': '“cansados de esta persecución racista”',
#      'segment_type': 'main',
#      'inip': '438',
#      'endp': '475',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'cansado',
#        'inip': '439',
#        'endp': '446',
#        'confidence': '100',
#        'score_tag': 'N'},
#       {'text': 'persecución',
#        'inip': '456',
#        'endp': '466',
#        'confidence': '100',
#        'score_tag': 'N'},
#       {'text': 'racista',
#        'inip': '468',
#        'endp': '474',
#        'confidence': '100',
#        'score_tag': 'N'}],
#      'sentimented_concept_list': [{'form': 'racista',
#        'id': '853ceae6c7',
#        'variant': 'racista',
#        'inip': '468',
#        'endp': '474',
#        'type': 'Top',
#        'score_tag': 'NONE'},
#       {'form': 'racista',
#        'id': '85cdb3628c',
#        'variant': 'racista',
#        'inip': '468',
#        'endp': '474',
#        'type': 'Top>Person',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': [{'form': 'racista',
#      'id': '853ceae6c7',
#      'type': 'Top',
#      'score_tag': 'NONE'},
#     {'form': 'racista',
#      'id': '85cdb3628c',
#      'type': 'Top>Person',
#      'score_tag': 'NONE'}]},
#   {'text': 'Crédito:',
#    'inip': '478',
#    'endp': '485',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'NONE',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Crédito:',
#      'segment_type': 'secondary',
#      'inip': '478',
#      'endp': '485',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': []}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': []},
#   {'text': 'Daniel Gutman/IPS La violencia de la Policía de Buenos Aires hacia vendedores ambulantes senegaleses en los últimos meses han indignado a argentinos e inmigrantes que el 16 de junio se manifestaron contra estos hechos en la capital.',
#    'inip': '487',
#    'endp': '719',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Daniel Gutman/IPS La violencia de la Policía de Buenos Aires hacia vendedores ambulantes senegaleses en los últimos meses han indignado a argentinos e inmigrantes que el 16 de junio se manifestaron contra estos hechos en la capital',
#      'segment_type': 'main',
#      'inip': '487',
#      'endp': '718',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'indignar',
#        'inip': '610',
#        'endp': '622',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_entity_list': [{'form': 'Daniel Gutman',
#          'id': '__12227975631530441717',
#          'variant': 'Daniel Gutman',
#          'inip': '487',
#          'endp': '499',
#          'type': 'Top>Person>FullName',
#          'score_tag': 'N'},
#         {'form': 'Inter Press Service',
#          'id': '621975c709',
#          'variant': 'IPS',
#          'inip': '501',
#          'endp': '503',
#          'type': 'Top>Organization>Company>ConsumerGoodsCompany>Discretionary>ConsumerServicesCompany>MediaCompany',
#          'score_tag': 'N'},
#         {'form': 'policía',
#          'id': '5d2df7073a370',
#          'variant': 'Policía de Buenos Aires',
#          'inip': '525',
#          'endp': '547',
#          'type': 'Top>Organization',
#          'score_tag': 'N'}],
#        'sentimented_concept_list': [{'form': 'violencia',
#          'id': 'cc27dae29f',
#          'variant': 'violencia',
#          'inip': '509',
#          'endp': '517',
#          'type': 'Top>OtherEntity>Offence',
#          'score_tag': 'N'},
#         {'form': 'argentino',
#          'id': '0d65ae0c1b',
#          'variant': 'argentinos',
#          'inip': '626',
#          'endp': '635',
#          'type': 'Top',
#          'score_tag': 'N'}]}],
#      'sentimented_entity_list': [{'form': 'Senegalés',
#        'id': '5d2df4f6a4caf',
#        'variant': 'senegaleses',
#        'inip': '577',
#        'endp': '587',
#        'type': 'Top>Nacionalidad',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'vendedor',
#        'id': 'dacecb32bc',
#        'variant': 'vendedores',
#        'inip': '555',
#        'endp': '564',
#        'type': 'Top>OtherEntity>Vocation',
#        'score_tag': 'NONE'},
#       {'form': 'capital',
#        'id': 'f929e70257',
#        'variant': 'capital',
#        'inip': '712',
#        'endp': '718',
#        'type': 'Top>Location>GeoPoliticalEntity>City',
#        'score_tag': 'NONE'}],
#      'segment_list': [{'text': 'La violencia de la Policía de Buenos Aires hacia vendedores ambulantes senegaleses',
#        'segment_type': 'main',
#        'inip': '506',
#        'endp': '587',
#        'confidence': '100',
#        'score_tag': 'N+',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'violencia',
#          'inip': '509',
#          'endp': '517',
#          'confidence': '100',
#          'score_tag': 'N+',
#          'sentimented_entity_list': [{'form': 'policía',
#            'id': '5d2df7073a370',
#            'variant': 'Policía de Buenos Aires',
#            'inip': '525',
#            'endp': '547',
#            'type': 'Top>Organization',
#            'score_tag': 'N+'}],
#          'sentimented_concept_list': [{'form': 'violencia',
#            'id': 'cc27dae29f',
#            'variant': 'violencia',
#            'inip': '509',
#            'endp': '517',
#            'type': 'Top>OtherEntity>Offence',
#            'score_tag': 'N+'}]}],
#        'sentimented_entity_list': [{'form': 'Senegalés',
#          'id': '5d2df4f6a4caf',
#          'variant': 'senegaleses',
#          'inip': '577',
#          'endp': '587',
#          'type': 'Top>Nacionalidad',
#          'score_tag': 'NONE'}],
#        'sentimented_concept_list': [{'form': 'vendedor',
#          'id': 'dacecb32bc',
#          'variant': 'vendedores',
#          'inip': '555',
#          'endp': '564',
#          'type': 'Top>OtherEntity>Vocation',
#          'score_tag': 'NONE'}]},
#       {'text': 'que el 16 de junio se manifestaron contra estos hechos en la capital',
#        'segment_type': 'main',
#        'inip': '651',
#        'endp': '718',
#        'confidence': '100',
#        'score_tag': 'N',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'contra',
#          'inip': '686',
#          'endp': '691',
#          'confidence': '100',
#          'score_tag': 'N',
#          'sentimented_concept_list': [{'form': 'capital',
#            'id': 'f929e70257',
#            'variant': 'capital',
#            'inip': '712',
#            'endp': '718',
#            'type': 'Top>Location>GeoPoliticalEntity>City',
#            'score_tag': 'N'}]}]}]}],
#    'sentimented_entity_list': [{'form': 'Senegalés',
#      'id': '5d2df4f6a4caf',
#      'type': 'Top>Nacionalidad',
#      'score_tag': 'NONE'},
#     {'form': 'policía',
#      'id': '5d2df7073a370',
#      'type': 'Top>Organization',
#      'score_tag': 'N'},
#     {'form': 'Inter Press Service',
#      'id': '621975c709',
#      'type': 'Top>Organization>Company>ConsumerGoodsCompany>Discretionary>ConsumerServicesCompany>MediaCompany',
#      'score_tag': 'N'},
#     {'form': 'Daniel Gutman',
#      'id': '__12227975631530441717',
#      'type': 'Top>Person>FullName',
#      'score_tag': 'N'}],
#    'sentimented_concept_list': [{'form': 'argentino',
#      'id': '0d65ae0c1b',
#      'type': 'Top',
#      'score_tag': 'N'},
#     {'form': 'violencia',
#      'id': 'cc27dae29f',
#      'type': 'Top>OtherEntity>Offence',
#      'score_tag': 'N'},
#     {'form': 'vendedor',
#      'id': 'dacecb32bc',
#      'type': 'Top>OtherEntity>Vocation',
#      'score_tag': 'NONE'},
#     {'form': 'capital',
#      'id': 'f929e70257',
#      'type': 'Top>Location>GeoPoliticalEntity>City',
#      'score_tag': 'N'}]},
#   {'text': 'Dos de ellos portaban carteles donde se leía:',
#    'inip': '721',
#    'endp': '765',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'NONE',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Dos de ellos portaban carteles donde se leía:',
#      'segment_type': 'secondary',
#      'inip': '721',
#      'endp': '765',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_concept_list': [{'form': 'cartel',
#        'id': '4098636df5',
#        'variant': 'carteles',
#        'inip': '743',
#        'endp': '750',
#        'type': 'Top>Organization',
#        'score_tag': 'NONE'},
#       {'form': 'cartel',
#        'id': '5d79d8a304',
#        'variant': 'carteles',
#        'inip': '743',
#        'endp': '750',
#        'type': 'Top>OtherEntity>Rule',
#        'score_tag': 'NONE'},
#       {'form': 'cartel',
#        'id': '74d0a569f7',
#        'variant': 'carteles',
#        'inip': '743',
#        'endp': '750',
#        'type': 'Top>Product>CulturalProduct>Printing>Document',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': [{'form': 'cartel',
#      'id': '4098636df5',
#      'type': 'Top>Organization',
#      'score_tag': 'NONE'},
#     {'form': 'cartel',
#      'id': '5d79d8a304',
#      'type': 'Top>OtherEntity>Rule',
#      'score_tag': 'NONE'},
#     {'form': 'cartel',
#      'id': '74d0a569f7',
#      'type': 'Top>Product>CulturalProduct>Printing>Document',
#      'score_tag': 'NONE'}]},
#   {'text': '“dejen trabajar a los senegaleses” y “cansados de esta persecución racista”.',
#    'inip': '767',
#    'endp': '842',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': '“dejen trabajar a los senegaleses”',
#      'segment_type': 'secondary',
#      'inip': '767',
#      'endp': '800',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': []},
#     {'text': '“cansados de esta persecución racista”',
#      'segment_type': 'main',
#      'inip': '804',
#      'endp': '841',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'cansado',
#        'inip': '805',
#        'endp': '812',
#        'confidence': '100',
#        'score_tag': 'N'},
#       {'text': 'persecución',
#        'inip': '822',
#        'endp': '832',
#        'confidence': '100',
#        'score_tag': 'N'},
#       {'text': 'racista',
#        'inip': '834',
#        'endp': '840',
#        'confidence': '100',
#        'score_tag': 'N'}],
#      'sentimented_concept_list': [{'form': 'racista',
#        'id': '853ceae6c7',
#        'variant': 'racista',
#        'inip': '834',
#        'endp': '840',
#        'type': 'Top',
#        'score_tag': 'NONE'},
#       {'form': 'racista',
#        'id': '85cdb3628c',
#        'variant': 'racista',
#        'inip': '834',
#        'endp': '840',
#        'type': 'Top>Person',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': [{'form': 'racista',
#      'id': '853ceae6c7',
#      'type': 'Top',
#      'score_tag': 'NONE'},
#     {'form': 'racista',
#      'id': '85cdb3628c',
#      'type': 'Top>Person',
#      'score_tag': 'NONE'}]},
#   {'text': 'Crédito:',
#    'inip': '844',
#    'endp': '851',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'NONE',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Crédito:',
#      'segment_type': 'secondary',
#      'inip': '844',
#      'endp': '851',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': []}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': []},
#   {'text': 'Daniel Gutman/IPS BUENOS AIRES, 20 jun 2018 (IPS) - Comenzaron a llegar a Argentina en los años 90 y la mayoría se integró con naturalidad al colectivo de vendedores callejeros de Buenos Aires y otras ciudades del país.',
#    'inip': '853',
#    'endp': '1072',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'P',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Daniel Gutman/IPS BUENOS AIRES',
#      'segment_type': 'secondary',
#      'inip': '853',
#      'endp': '883',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_entity_list': [{'form': 'Buenos Aires',
#        'id': '5d2df9543aa42',
#        'variant': 'BUENOS AIRES',
#        'inip': '872',
#        'endp': '883',
#        'type': 'Top>Location>GeoPoliticalEntity>City',
#        'score_tag': 'NONE'},
#       {'form': 'Inter Press Service',
#        'id': '621975c709',
#        'variant': 'IPS',
#        'inip': '867',
#        'endp': '869',
#        'type': 'Top>Organization>Company>ConsumerGoodsCompany>Discretionary>ConsumerServicesCompany>MediaCompany',
#        'score_tag': 'NONE'},
#       {'form': 'Daniel Gutman',
#        'id': '__12227975631530441717',
#        'variant': 'Daniel Gutman',
#        'inip': '853',
#        'endp': '865',
#        'type': 'Top>Person>FullName',
#        'score_tag': 'NONE'}]},
#     {'text': '20 jun 2018 (IPS) - Comenzaron a llegar a Argentina en los años 90',
#      'segment_type': 'secondary',
#      'inip': '886',
#      'endp': '951',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_entity_list': [{'form': 'Argentina',
#        'id': 'efb13c2f4e',
#        'variant': 'Argentina',
#        'inip': '928',
#        'endp': '936',
#        'type': 'Top>Location>GeoPoliticalEntity>Country',
#        'score_tag': 'NONE'}]},
#     {'text': 'la mayoría se integró con naturalidad al colectivo de vendedores callejeros de Buenos Aires y otras ciudades del país',
#      'segment_type': 'main',
#      'inip': '955',
#      'endp': '1071',
#      'confidence': '100',
#      'score_tag': 'P',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'integrar',
#        'inip': '969',
#        'endp': '975',
#        'confidence': '100',
#        'score_tag': 'P',
#        'sentimented_concept_list': [{'form': 'colectivo',
#          'id': 'cf53d01b89',
#          'variant': 'colectivo',
#          'inip': '996',
#          'endp': '1004',
#          'type': 'Top>Organization',
#          'score_tag': 'P'},
#         {'form': 'colectivo',
#          'id': 'd701444826',
#          'variant': 'colectivo',
#          'inip': '996',
#          'endp': '1004',
#          'type': 'Top>Product>Machine>Vehicle',
#          'score_tag': 'P'}]}],
#      'sentimented_entity_list': [{'form': 'Buenos Aires',
#        'id': '5d2df9543aa42',
#        'variant': 'Buenos Aires',
#        'inip': '1034',
#        'endp': '1045',
#        'type': 'Top>Location>GeoPoliticalEntity>City',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'vendedor callejero',
#        'id': '3154aa53dc',
#        'variant': 'vendedores callejeros',
#        'inip': '1009',
#        'endp': '1029',
#        'type': 'Top',
#        'score_tag': 'NONE'},
#       {'form': 'país',
#        'id': '35229605d1',
#        'variant': 'país',
#        'inip': '1068',
#        'endp': '1071',
#        'type': 'Top>Location>GeoPoliticalEntity>Country',
#        'score_tag': 'NONE'},
#       {'form': 'ciudad',
#        'id': '817857ee40',
#        'variant': 'ciudades',
#        'inip': '1055',
#        'endp': '1062',
#        'type': 'Top>Location>GeoPoliticalEntity>City',
#        'score_tag': 'NONE'}],
#      'segment_list': [{'text': 'con naturalidad',
#        'segment_type': 'main',
#        'inip': '977',
#        'endp': '991',
#        'confidence': '100',
#        'score_tag': 'P',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'naturalidad',
#          'inip': '981',
#          'endp': '991',
#          'confidence': '100',
#          'score_tag': 'P'}]}]}],
#    'sentimented_entity_list': [{'form': 'Buenos Aires',
#      'id': '5d2df9543aa42',
#      'type': 'Top>Location>GeoPoliticalEntity>City',
#      'score_tag': 'NONE'},
#     {'form': 'Inter Press Service',
#      'id': '621975c709',
#      'type': 'Top>Organization>Company>ConsumerGoodsCompany>Discretionary>ConsumerServicesCompany>MediaCompany',
#      'score_tag': 'NONE'},
#     {'form': 'Daniel Gutman',
#      'id': '__12227975631530441717',
#      'type': 'Top>Person>FullName',
#      'score_tag': 'NONE'},
#     {'form': 'Argentina',
#      'id': 'efb13c2f4e',
#      'type': 'Top>Location>GeoPoliticalEntity>Country',
#      'score_tag': 'NONE'}],
#    'sentimented_concept_list': [{'form': 'vendedor callejero',
#      'id': '3154aa53dc',
#      'type': 'Top',
#      'score_tag': 'NONE'},
#     {'form': 'país',
#      'id': '35229605d1',
#      'type': 'Top>Location>GeoPoliticalEntity>Country',
#      'score_tag': 'NONE'},
#     {'form': 'ciudad',
#      'id': '817857ee40',
#      'type': 'Top>Location>GeoPoliticalEntity>City',
#      'score_tag': 'NONE'},
#     {'form': 'colectivo',
#      'id': 'cf53d01b89',
#      'type': 'Top>Organization',
#      'score_tag': 'P'},
#     {'form': 'colectivo',
#      'id': 'd701444826',
#      'type': 'Top>Product>Machine>Vehicle',
#      'score_tag': 'P'}]},
#   {'text': 'Pero, en los últimos meses, los inmigrantes senegaleses han sufrido hechos de violencia por parte de la policía, denunciados como una campaña de persecución racial.',
#    'inip': '1074',
#    'endp': '1237',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'N',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'en los últimos meses, los inmigrantes senegaleses han sufrido hechos de violencia por parte de la policía, denunciados como una campaña de persecución racial',
#      'segment_type': 'main',
#      'inip': '1080',
#      'endp': '1236',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'sufrir',
#        'inip': '1130',
#        'endp': '1140',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_concept_list': [{'form': 'inmigrante',
#          'id': 'ee789984b3',
#          'variant': 'inmigrantes',
#          'inip': '1106',
#          'endp': '1116',
#          'type': 'Top>Person',
#          'score_tag': 'N'},
#         {'form': 'campaña',
#          'id': '700d2e952d',
#          'variant': 'campaña',
#          'inip': '1208',
#          'endp': '1214',
#          'type': 'Top>Location>GeographicalEntity>NaturalReserve',
#          'score_tag': 'N'}]},
#       {'text': 'violencia',
#        'inip': '1152',
#        'endp': '1160',
#        'confidence': '100',
#        'score_tag': 'N+',
#        'sentimented_concept_list': [{'form': 'inmigrante',
#          'id': 'ee789984b3',
#          'variant': 'inmigrantes',
#          'inip': '1106',
#          'endp': '1116',
#          'type': 'Top>Person',
#          'score_tag': 'N+'},
#         {'form': 'campaña',
#          'id': '700d2e952d',
#          'variant': 'campaña',
#          'inip': '1208',
#          'endp': '1214',
#          'type': 'Top>Location>GeographicalEntity>NaturalReserve',
#          'score_tag': 'N+'}]},
#       {'text': 'denunciar',
#        'inip': '1187',
#        'endp': '1197',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_concept_list': [{'form': 'inmigrante',
#          'id': 'ee789984b3',
#          'variant': 'inmigrantes',
#          'inip': '1106',
#          'endp': '1116',
#          'type': 'Top>Person',
#          'score_tag': 'N'},
#         {'form': 'campaña',
#          'id': '700d2e952d',
#          'variant': 'campaña',
#          'inip': '1208',
#          'endp': '1214',
#          'type': 'Top>Location>GeographicalEntity>NaturalReserve',
#          'score_tag': 'N'}]},
#       {'text': 'persecución',
#        'inip': '1219',
#        'endp': '1229',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_concept_list': [{'form': 'inmigrante',
#          'id': 'ee789984b3',
#          'variant': 'inmigrantes',
#          'inip': '1106',
#          'endp': '1116',
#          'type': 'Top>Person',
#          'score_tag': 'N'},
#         {'form': 'campaña',
#          'id': '700d2e952d',
#          'variant': 'campaña',
#          'inip': '1208',
#          'endp': '1214',
#          'type': 'Top>Location>GeographicalEntity>NaturalReserve',
#          'score_tag': 'N'}]}],
#      'sentimented_entity_list': [{'form': 'Senegalés',
#        'id': '5d2df4f6a4caf',
#        'variant': 'senegaleses',
#        'inip': '1118',
#        'endp': '1128',
#        'type': 'Top>Nacionalidad',
#        'score_tag': 'NONE'},
#       {'form': 'policía',
#        'id': '5d2df7073a370',
#        'variant': 'policía',
#        'inip': '1178',
#        'endp': '1184',
#        'type': 'Top>Organization',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'racial',
#        'id': '4b7fe0f2f5',
#        'variant': 'racial',
#        'inip': '1231',
#        'endp': '1236',
#        'type': 'Top',
#        'score_tag': 'NONE'},
#       {'form': 'violencia',
#        'id': 'cc27dae29f',
#        'variant': 'violencia',
#        'inip': '1152',
#        'endp': '1160',
#        'type': 'Top>OtherEntity>Offence',
#        'score_tag': 'NONE'}],
#      'segment_list': [{'text': 'hechos de violencia por parte de la policía',
#        'segment_type': 'main',
#        'inip': '1142',
#        'endp': '1184',
#        'confidence': '100',
#        'score_tag': 'N+',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'violencia',
#          'inip': '1152',
#          'endp': '1160',
#          'confidence': '100',
#          'score_tag': 'N+',
#          'sentimented_entity_list': [{'form': 'policía',
#            'id': '5d2df7073a370',
#            'variant': 'policía',
#            'inip': '1178',
#            'endp': '1184',
#            'type': 'Top>Organization',
#            'score_tag': 'N+'}],
#          'sentimented_concept_list': [{'form': 'violencia',
#            'id': 'cc27dae29f',
#            'variant': 'violencia',
#            'inip': '1152',
#            'endp': '1160',
#            'type': 'Top>OtherEntity>Offence',
#            'score_tag': 'N+'}]}]}]}],
#    'sentimented_entity_list': [{'form': 'Senegalés',
#      'id': '5d2df4f6a4caf',
#      'type': 'Top>Nacionalidad',
#      'score_tag': 'NONE'},
#     {'form': 'policía',
#      'id': '5d2df7073a370',
#      'type': 'Top>Organization',
#      'score_tag': 'N+'}],
#    'sentimented_concept_list': [{'form': 'racial',
#      'id': '4b7fe0f2f5',
#      'type': 'Top',
#      'score_tag': 'NONE'},
#     {'form': 'campaña',
#      'id': '700d2e952d',
#      'type': 'Top>Location>GeographicalEntity>NaturalReserve',
#      'score_tag': 'N'},
#     {'form': 'violencia',
#      'id': 'cc27dae29f',
#      'type': 'Top>OtherEntity>Offence',
#      'score_tag': 'N+'},
#     {'form': 'inmigrante',
#      'id': 'ee789984b3',
#      'type': 'Top>Person',
#      'score_tag': 'N'}]},
#   {'text': '“Siempre tuvimos buena relación con los policías.',
#    'inip': '1240',
#    'endp': '1288',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'P',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': '“Siempre tuvimos buena relación con los policías',
#      'segment_type': 'main',
#      'inip': '1240',
#      'endp': '1287',
#      'confidence': '100',
#      'score_tag': 'P',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'bueno@A',
#        'inip': '1257',
#        'endp': '1261',
#        'confidence': '100',
#        'score_tag': 'P'}],
#      'sentimented_entity_list': [{'form': 'policía',
#        'id': '5d2df7073a370',
#        'variant': 'los policías',
#        'inip': '1276',
#        'endp': '1287',
#        'type': 'Top>Organization',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [{'form': 'policía',
#      'id': '5d2df7073a370',
#      'type': 'Top>Organization',
#      'score_tag': 'NONE'}],
#    'sentimented_concept_list': []},
#   {'text': 'Hasta me cuidaban la mercadería cuando yo iba al baño.',
#    'inip': '1290',
#    'endp': '1343',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'P',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'Hasta me cuidaban la mercadería cuando yo iba al baño',
#      'segment_type': 'main',
#      'inip': '1290',
#      'endp': '1342',
#      'confidence': '100',
#      'score_tag': 'P',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'cuidar',
#        'inip': '1299',
#        'endp': '1306',
#        'confidence': '100',
#        'score_tag': 'P'}]}],
#    'sentimented_entity_list': [],
#    'sentimented_concept_list': []},
#   {'text': 'Pero últimamente todo cambió”, dijo a IPS el senegalés Moussa Sow, de 35 años, que lleva 11 viviendo en Argentina.',
#    'inip': '1345',
#    'endp': '1458',
#    'bop': 'n',
#    'confidence': '100',
#    'score_tag': 'NONE',
#    'agreement': 'AGREEMENT',
#    'segment_list': [{'text': 'últimamente todo cambió”, dijo a IPS el senegalés Moussa Sow, de 35 años, que lleva 11 viviendo en Argentina',
#      'segment_type': 'main',
#      'inip': '1350',
#      'endp': '1457',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_entity_list': [{'form': 'Moussa Sow',
#        'id': '510bd634f8',
#        'variant': 'Moussa Sow',
#        'inip': '1400',
#        'endp': '1409',
#        'type': 'Top>Person>FullName',
#        'score_tag': 'NONE'},
#       {'form': 'Senegalés',
#        'id': '5d2df4f6a4caf',
#        'variant': 'senegalés',
#        'inip': '1390',
#        'endp': '1398',
#        'type': 'Top>Nacionalidad',
#        'score_tag': 'NONE'},
#       {'form': 'Inter Press Service',
#        'id': '621975c709',
#        'variant': 'IPS',
#        'inip': '1383',
#        'endp': '1385',
#        'type': 'Top>Organization>Company>ConsumerGoodsCompany>Discretionary>ConsumerServicesCompany>MediaCompany',
#        'score_tag': 'NONE'},
#       {'form': 'Argentina',
#        'id': 'efb13c2f4e',
#        'variant': 'Argentina',
#        'inip': '1449',
#        'endp': '1457',
#        'type': 'Top>Location>GeoPoliticalEntity>Country',
#        'score_tag': 'NONE'}]}],
#    'sentimented_entity_list': [{'form': 'Moussa Sow',
#      'id': '510bd634f8',
#      'type': 'Top>Person>FullName',
#      'score_tag': 'NONE'},
#     {'form': 'Senegalés',
#      'id': '5d2df4f6a4caf',
#      'type': 'Top>Nacionalidad',
#      'score_tag': 'NONE'},
#     {'form': 'Inter Press Service',
#      'id': '621975c709',
#      'type': 'Top>Organization>Company>ConsumerGoodsCompany>Discretionary>ConsumerServicesCompany>MediaCompany',
#      'score_tag': 'NONE'},
#     {'form': 'Argentina',
#      'id': 'efb13c2f4e',
#      'type': 'Top>Location>GeoPoliticalEntity>Country',
#      'score_tag': 'NONE'}],
#    'sentimented_concept_list': []},
#   {'text': '“Nos sacan todo lo que tenemos a los negros, muchas veces nos pegan y a quienes están vendiendo al lado nuestro no les tocan nada”, agregó Sow, quien está casado con una argentina y se traslada por la extensa geografía de Buenos Aires y los barrios suburbanos, de acuerdo a donde encuentre menor presencia policial, vendiendo bisutería, anteojos y relojes.',
#    'inip': '1461',
#    'endp': '1816',
#    'bop': 'n',
#    'confidence': '94',
#    'score_tag': 'NEU',
#    'agreement': 'DISAGREEMENT',
#    'segment_list': [{'text': '“Nos sacan todo lo que tenemos a los negros, muchas veces nos pegan y a quienes están vendiendo al lado nuestro no les tocan nada”, agregó Sow, quien está casado con una argentina',
#      'segment_type': 'main',
#      'inip': '1461',
#      'endp': '1639',
#      'confidence': '100',
#      'score_tag': 'N',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'pegar',
#        'inip': '1523',
#        'endp': '1527',
#        'confidence': '100',
#        'score_tag': 'N',
#        'sentimented_entity_list': [{'form': 'Moussa Sow',
#          'id': '510bd634f8',
#          'variant': 'Sow',
#          'inip': '1600',
#          'endp': '1602',
#          'type': 'Top>Person>FullName',
#          'score_tag': 'N'}]}],
#      'sentimented_concept_list': [{'form': 'negro',
#        'id': '2408c36eb8',
#        'variant': 'negros',
#        'inip': '1498',
#        'endp': '1503',
#        'type': 'Top>OtherEntity>Color',
#        'score_tag': 'NONE'},
#       {'form': 'negro',
#        'id': '977deaea89',
#        'variant': 'negros',
#        'inip': '1498',
#        'endp': '1503',
#        'type': 'Top>Person',
#        'score_tag': 'NONE'},
#       {'form': 'argentino',
#        'id': '9b7412f65f',
#        'variant': 'argentina',
#        'inip': '1631',
#        'endp': '1639',
#        'type': 'Top>Person',
#        'score_tag': 'NONE'}],
#      'segment_list': [{'text': '“Nos sacan todo lo que tenemos a los negros, muchas veces nos pegan y a quienes están vendiendo al lado nuestro no les tocan nada”',
#        'segment_type': 'main',
#        'inip': '1461',
#        'endp': '1590',
#        'confidence': '100',
#        'score_tag': 'N',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'pegar',
#          'inip': '1523',
#          'endp': '1527',
#          'confidence': '100',
#          'score_tag': 'N'}],
#        'sentimented_concept_list': [{'form': 'negro',
#          'id': '2408c36eb8',
#          'variant': 'negros',
#          'inip': '1498',
#          'endp': '1503',
#          'type': 'Top>OtherEntity>Color',
#          'score_tag': 'NONE'},
#         {'form': 'negro',
#          'id': '977deaea89',
#          'variant': 'negros',
#          'inip': '1498',
#          'endp': '1503',
#          'type': 'Top>Person',
#          'score_tag': 'NONE'}]}]},
#     {'text': 'se traslada por la extensa geografía de Buenos Aires y los barrios suburbanos',
#      'segment_type': 'main',
#      'inip': '1643',
#      'endp': '1719',
#      'confidence': '100',
#      'score_tag': 'NONE',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [],
#      'sentimented_entity_list': [{'form': 'Buenos Aires',
#        'id': '5d2df9543aa42',
#        'variant': 'Buenos Aires',
#        'inip': '1683',
#        'endp': '1694',
#        'type': 'Top>Location>GeoPoliticalEntity>City',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'geografía',
#        'id': '0239d78910',
#        'variant': 'geografía',
#        'inip': '1670',
#        'endp': '1678',
#        'type': 'Top>OtherEntity>Doctrine>Academic',
#        'score_tag': 'NONE'},
#       {'form': 'suburbano',
#        'id': 'c70a1ce1c1',
#        'variant': 'suburbanos',
#        'inip': '1710',
#        'endp': '1719',
#        'type': 'Top',
#        'score_tag': 'NONE'},
#       {'form': 'barrio',
#        'id': 'daef3e327d',
#        'variant': 'barrios',
#        'inip': '1702',
#        'endp': '1708',
#        'type': 'Top>Location>GeoPoliticalEntity',
#        'score_tag': 'NONE'},
#       {'form': 'geografía',
#        'id': 'eb8be48cf7',
#        'variant': 'geografía',
#        'inip': '1670',
#        'endp': '1678',
#        'type': 'Top',
#        'score_tag': 'NONE'}]},
#     {'text': 'de acuerdo a donde encuentre menor presencia policial, vendiendo bisutería, anteojos y relojes',
#      'segment_type': 'main',
#      'inip': '1722',
#      'endp': '1815',
#      'confidence': '100',
#      'score_tag': 'P',
#      'agreement': 'AGREEMENT',
#      'polarity_term_list': [{'text': 'encontrar',
#        'inip': '1741',
#        'endp': '1749',
#        'confidence': '100',
#        'score_tag': 'P'}],
#      'sentimented_entity_list': [{'form': 'policía',
#        'id': '5d2df7073a370',
#        'variant': 'policial',
#        'inip': '1767',
#        'endp': '1774',
#        'type': 'Top>Organization',
#        'score_tag': 'NONE'}],
#      'sentimented_concept_list': [{'form': 'bisutería',
#        'id': '11656d0368',
#        'variant': 'bisutería',
#        'inip': '1787',
#        'endp': '1795',
#        'type': 'Top>Location>Facility',
#        'score_tag': 'NONE'},
#       {'form': 'bisutería',
#        'id': 'a2ddc75c5e',
#        'variant': 'bisutería',
#        'inip': '1787',
#        'endp': '1795',
#        'type': 'Top',
#        'score_tag': 'NONE'}],
#      'segment_list': [{'text': 'a donde encuentre menor presencia policial',
#        'segment_type': 'main',
#        'inip': '1733',
#        'endp': '1774',
#        'confidence': '100',
#        'score_tag': 'P',
#        'agreement': 'AGREEMENT',
#        'polarity_term_list': [{'text': 'encontrar',
#          'inip': '1741',
#          'endp': '1749',
#          'confidence': '100',
#          'score_tag': 'P'}],
#        'sentimented_entity_list': [{'form': 'policía',
#          'id': '5d2df7073a370',
#          'variant': 'policial',
#          'inip': '1767',
#          'endp': '1774',
#          'type': 'Top>Organization',
#          'score_tag': 'NONE'}]}]}],
#    'sentimented_entity_list': [{'form': 'Moussa Sow',
#      'id': '510bd634f8',
#      'type': 'Top>Person>FullName',
#      'score_tag': 'N'},
#     {'form': 'policía',
#      'id': '5d2df7073a370',
#      'type': 'Top>Organization',
#      'score_tag': 'NONE'},
#     {'form': 'Buenos Aires',
#      'id': '5d2df9543aa42',
#      'type': 'Top>Location>GeoPoliticalEntity>City',
#      'score_tag': 'NONE'}],
#    'sentimented_concept_list': [{'form': 'geografía',
#      'id': '0239d78910',
#      'type': 'Top>OtherEntity>Doctrine>Academic',
#      'score_tag': 'NONE'},
#     {'form': 'bisutería',
#      'id': '11656d0368',
#      'type': 'Top>Location>Facility',
#      'score_tag': 'NONE'},
#     {'form': 'negro',
#      'id': '2408c36eb8',
#      'type': 'Top>OtherEntity>Color',
#      'score_tag': 'NONE'},
#     {'form': 'negro',
#      'id': '977deaea89',
#      'type': 'Top>Person',
#      'score_tag': 'NONE'},
#     {'form': 'argentino',
#      'id': '9b7412f65f',
#      'type': 'Top>Person',
#      'score_tag': 'NONE'},
#     {'form': 'bisutería',
#      'id': 'a2ddc75c5e',
#      'type': 'Top',
#      'score_tag': 'NONE'},
#     {'form': 'suburbano',
#      'id': 'c70a1ce1c1',
#      'type': 'Top',
#      'score_tag': 'NONE'},
#     {'form': 'barrio',
#      'id': 'daef3e327d',
#      'type': 'Top>Location>GeoPoliticalEntity',
#      'score_tag': 'NONE'},
#     {'form': 'geografía',
#      'id': 'eb8be48cf7',
#      'type': 'Top',
#      'score_tag': 'NONE'}]},
# ...
#    'score_tag': 'NONE'},
#   {'form': 'pancarta', 'id': '10e4d5152a', 'type': 'Top', 'score_tag': 'P'},
#   {'form': 'bisutería',
#    'id': '11656d0368',
#    'type': 'Top>Location>Facility',
#    'score_tag': 'NONE'},
#   {'form': 'policial', 'id': '139f9697c8', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'violento', 'id': '15a8050fe2', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'caso',
#    'id': '16362e9bf5',
#    'type': 'Top>Event',
#    'score_tag': 'NONE'},
#   {'form': 'población',
#    'id': '16766ba4bd',
#    'type': 'Top>Location>GeoPoliticalEntity>City',
#    'score_tag': 'P'},
#   {'form': 'reunificación familiar',
#    'id': '1711b91424',
#    'type': 'Top',
#    'score_tag': 'N'},
#   {'form': 'acceso',
#    'id': '1c0180d121',
#    'type': 'Top>Location>Facility',
#    'score_tag': 'NONE'},
#   {'form': 'red social', 'id': '1f1d00751f', 'type': 'Top', 'score_tag': 'P'},
#   {'form': 'hombre',
#    'id': '20a218cbdf',
#    'type': 'Top>Person',
#    'score_tag': 'N'},
#   {'form': 'negro',
#    'id': '2408c36eb8',
#    'type': 'Top>OtherEntity>Color',
#    'score_tag': 'NONE'},
#   {'form': 'uniforme', 'id': '24652cc9e1', 'type': 'Top', 'score_tag': 'P'},
#   {'form': 'mayor', 'id': '248ddcbd2d', 'type': 'Top', 'score_tag': 'P'},
#   {'form': 'artículo', 'id': '24c38dbf04', 'type': 'Top', 'score_tag': 'N+'},
#   {'form': 'brazo',
#    'id': '24cdb52d12',
#    'type': 'Top>LivingThing>BodyPart',
#    'score_tag': 'N'},
#   {'form': 'dominicano',
#    'id': '2569148ec6',
#    'type': 'Top>Person',
#    'score_tag': 'P'},
#   {'form': 'víctima',
#    'id': '258214e1e7',
#    'type': 'Top>Person',
#    'score_tag': 'N+'},
#   {'form': 'reunificación familiar',
#    'id': '2620cf94b5',
#    'type': 'Top',
#    'score_tag': 'N'},
#   {'form': 'fútbol',
#    'id': '2b505fba8a',
#    'type': 'Top>OtherEntity>Doctrine>Sports',
#    'score_tag': 'NONE'},
#   {'form': 'grupo',
#    'id': '2d2ce0cce8',
#    'type': 'Top>Organization',
#    'score_tag': 'N'},
#   {'form': 'activista',
#    'id': '2e7d45f99e',
#    'type': 'Top>Person',
#    'score_tag': 'P'},
#   {'form': 'bandeira',
#    'id': '2f120b2b89',
#    'type': 'Top>Organization>Military',
#    'score_tag': 'P'},
#   {'form': 'extranjero',
#    'id': '2fbdb0c7d9',
#    'type': 'Top>Person',
#    'score_tag': 'P'},
#   {'form': 'delito',
#    'id': '2fbf540de1',
#    'type': 'Top>OtherEntity>Offence',
#    'score_tag': 'N'},
#   {'form': 'vendedor callejero',
#    'id': '3154aa53dc',
#    'type': 'Top',
#    'score_tag': 'P'},
#   {'form': 'política', 'id': '335e4bdd2b', 'type': 'Top', 'score_tag': 'N'},
#   {'form': 'agente',
#    'id': '34049c0818',
#    'type': 'Top>Person',
#    'score_tag': 'N'},
#   {'form': 'país',
#    'id': '35229605d1',
#    'type': 'Top>Location>GeoPoliticalEntity>Country',
#    'score_tag': 'P'},
#   {'form': 'canal',
#    'id': '38b477418e',
#    'type': 'Top>Location>GeographicalEntity>WaterForm>Channel',
#    'score_tag': 'NONE'},
#   {'form': 'astro',
#    'id': '3e648e4e9c',
#    'type': 'Top>Location>AstralBody',
#    'score_tag': 'NONE'},
#   {'form': 'nacionalidad',
#    'id': '3f4bbe9273',
#    'type': 'Top>OtherEntity>Nationality',
#    'score_tag': 'NONE'},
#   {'form': 'cartel',
#    'id': '4098636df5',
#    'type': 'Top>Organization',
#    'score_tag': 'NONE'},
#   {'form': 'empresa',
#    'id': '420c1836d7',
#    'type': 'Top>Organization>Company',
#    'score_tag': 'P'},
#   {'form': 'fiscalía',
#    'id': '428134778c',
#    'type': 'Top>Location>Facility',
#    'score_tag': 'NONE'},
#   {'form': 'hijo',
#    'id': '4629d1f492',
#    'type': 'Top>Person',
#    'score_tag': 'NONE'},
#   {'form': 'norma',
#    'id': '477943913b',
#    'type': 'Top>OtherEntity>Rule',
#    'score_tag': 'N'},
#   {'form': 'coordinador',
#    'id': '478a1b5a5e',
#    'type': 'Top>OtherEntity>Title',
#    'score_tag': 'N+'},
#   {'form': 'fondo', 'id': '478ea60931', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'espacio',
#    'id': '48bfbc160d',
#    'type': 'Top>Location',
#    'score_tag': 'NONE'},
#   {'form': 'suramericano',
#    'id': '49d5ba7084',
#    'type': 'Top>Person',
#    'score_tag': 'P'},
#   {'form': 'racial', 'id': '4b7fe0f2f5', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'mayor', 'id': '4d166a30ee', 'type': 'Top', 'score_tag': 'P'},
#   {'form': 'kilómetro',
#    'id': '4dfc1b6968',
#    'type': 'Top>Unit>PhysicalExtentUnit',
#    'score_tag': 'P'},
#   {'form': 'fotografía',
#    'id': '4e1219a1da',
#    'type': 'Top>Product',
#    'score_tag': 'N'},
#   {'form': 'delincuencia',
#    'id': '4ee376091e',
#    'type': 'Top',
#    'score_tag': 'NONE'},
#   {'form': 'dependencia',
#    'id': '4fca300450',
#    'type': 'Top>Location>Facility',
#    'score_tag': 'N'},
#   {'form': 'ciudadano',
#    'id': '512e1a8ba7',
#    'type': 'Top>Person',
#    'score_tag': 'N'},
#   {'form': 'mayor',
#    'id': '52b4ddc471',
#    'type': 'Top>OtherEntity>Title',
#    'score_tag': 'P'},
#   {'form': 'ceremonia',
#    'id': '54236208be',
#    'type': 'Top>Event>Occasion',
#    'score_tag': 'P'},
#   {'form': 'canal',
#    'id': '550b58e884',
#    'type': 'Top>Organization>Company>ConsumerGoodsCompany>Discretionary>ConsumerServicesCompany>MediaCompany',
#    'score_tag': 'NONE'},
#   {'form': 'suelo',
#    'id': '599093b066',
#    'type': 'Top>Location',
#    'score_tag': 'N'},
#   {'form': 'programa',
#    'id': '5a8f20e393',
#    'type': 'Top>Product>CulturalProduct>Broadcast',
#    'score_tag': 'N+'},
#   {'form': 'cartel',
#    'id': '5d79d8a304',
#    'type': 'Top>OtherEntity>Rule',
#    'score_tag': 'NONE'},
#   {'form': 'acusación',
#    'id': '5f2a882d9a',
#    'type': 'Top>Person',
#    'score_tag': 'NEU'},
#   {'form': 'historia',
#    'id': '5f2abe2418',
#    'type': 'Top>OtherEntity>Doctrine>Academic',
#    'score_tag': 'P'},
#   {'form': 'tierra',
#    'id': '6162e5fc4e',
#    'type': 'Top>Location',
#    'score_tag': 'NONE'},
#   {'form': 'espacio',
#    'id': '631c4eb9b4',
#    'type': 'Top>Unit>SpaceUnit',
#    'score_tag': 'NONE'},
#   {'form': 'presidente',
#    'id': '646fca944e',
#    'type': 'Top>OtherEntity>Title',
#    'score_tag': 'NONE'},
#   {'form': 'mayor',
#    'id': '65816a89e5',
#    'type': 'Top>OtherEntity>Title',
#    'score_tag': 'P'},
#   {'form': 'autoridad',
#    'id': '66a90f4267',
#    'type': 'Top>OtherEntity>Vocation',
#    'score_tag': 'N'},
#   {'form': 'centro',
#    'id': '670f6212e2',
#    'type': 'Top>Location',
#    'score_tag': 'NONE'},
#   {'form': 'marido',
#    'id': '6a17861b62',
#    'type': 'Top>Person',
#    'score_tag': 'NONE'},
#   {'form': 'fondo', 'id': '6fd0506729', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'campaña',
#    'id': '700d2e952d',
#    'type': 'Top>Location>GeographicalEntity>NaturalReserve',
#    'score_tag': 'N'},
#   {'form': 'funcionario',
#    'id': '7010db55be',
#    'type': 'Top>OtherEntity>Vocation',
#    'score_tag': 'N'},
#   {'form': 'censo', 'id': '71ddefbf4b', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'continente',
#    'id': '72bcbdfc75',
#    'type': 'Top>Location>GeoPoliticalEntity',
#    'score_tag': 'NONE'},
#   {'form': 'papel',
#    'id': '74500cb010',
#    'type': 'Top>Product',
#    'score_tag': 'NONE'},
#   {'form': 'cartel',
#    'id': '74d0a569f7',
#    'type': 'Top>Product>CulturalProduct>Printing>Document',
#    'score_tag': 'NONE'},
#   {'form': 'canal',
#    'id': '78a1453083',
#    'type': 'Top>Location>GeographicalEntity>WaterForm>Channel',
#    'score_tag': 'NONE'},
#   {'form': 'trabajo',
#    'id': '7aa7306d3d',
#    'type': 'Top>OtherEntity>Vocation',
#    'score_tag': 'NONE'},
#   {'form': 'pionero',
#    'id': '7c59c21e35',
#    'type': 'Top>Person',
#    'score_tag': 'NONE'},
#   {'form': 'suburbio',
#    'id': '7c73d04cf3',
#    'type': 'Top>Location>GeoPoliticalEntity>City',
#    'score_tag': 'NONE'},
#   {'form': 'lugar',
#    'id': '7d13c3cc97',
#    'type': 'Top>Location',
#    'score_tag': 'NONE'},
#   {'form': 'ambulante',
#    'id': '7e3017a34d',
#    'type': 'Top>Person',
#    'score_tag': 'NONE'},
#   {'form': 'defensoría', 'id': '7e83a52b7b', 'type': 'Top', 'score_tag': 'P'},
#   {'form': 'software', 'id': '7e8c1e4fc4', 'type': 'Top', 'score_tag': 'N+'},
#   {'form': 'habitante',
#    'id': '7f2234457e',
#    'type': 'Top>Person',
#    'score_tag': 'NONE'},
#   {'form': 'esposa', 'id': '7f64b34cbe', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'justicia', 'id': '80b81c849e', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'decisión', 'id': '80fd14d267', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'ciudad',
#    'id': '817857ee40',
#    'type': 'Top>Location>GeoPoliticalEntity>City',
#    'score_tag': 'P'},
#   {'form': 'venta ambulante',
#    'id': '81b3a68f13',
#    'type': 'Top',
#    'score_tag': 'N'},
#   {'form': 'comunidad',
#    'id': '837097509b',
#    'type': 'Top>Location>GeoPoliticalEntity>Adm1',
#    'score_tag': 'NONE'},
#   {'form': 'racista', 'id': '853ceae6c7', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'africano',
#    'id': '857800f37b',
#    'type': 'Top>Person',
#    'score_tag': 'N'},
#   {'form': 'racista',
#    'id': '85cdb3628c',
#    'type': 'Top>Person',
#    'score_tag': 'NONE'},
#   {'form': 'zona',
#    'id': '87eb4f8d34',
#    'type': 'Top>Location',
#    'score_tag': 'NONE'},
#   {'form': 'africano', 'id': '88543b310b', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'acto',
#    'id': '8a9b9f5c9c',
#    'type': 'Top>OtherEntity>Rule',
#    'score_tag': 'P'},
#   {'form': 'comisión',
#    'id': '8c1fb4be9c',
#    'type': 'Top>Organization',
#    'score_tag': 'N'},
#   {'form': 'agresión', 'id': '8d6f91176e', 'type': 'Top', 'score_tag': 'N'},
#   {'form': 'institucional',
#    'id': '8ebed5b8f7',
#    'type': 'Top',
#    'score_tag': 'NONE'},
#   {'form': 'vidriero',
#    'id': '8f3616613c',
#    'type': 'Top>OtherEntity>Vocation',
#    'score_tag': 'N'},
#   {'form': 'suramericano',
#    'id': '904f2a3777',
#    'type': 'Top',
#    'score_tag': 'NONE'},
#   {'form': 'represalia',
#    'id': '91bc3fd7ec',
#    'type': 'Top',
#    'score_tag': 'NONE'},
#   {'form': 'negro',
#    'id': '977deaea89',
#    'type': 'Top>Person',
#    'score_tag': 'NONE'},
#   {'form': 'monumento',
#    'id': '99332f052b',
#    'type': 'Top>Location>Facility>Monument',
#    'score_tag': 'P'},
#   {'form': 'político',
#    'id': '99d457722f',
#    'type': 'Top>OtherEntity>Vocation',
#    'score_tag': 'N'},
#   {'form': 'país de la Unión Europea',
#    'id': '99e26b596a',
#    'type': 'Top',
#    'score_tag': 'NONE'},
#   {'form': 'argentino',
#    'id': '9b7412f65f',
#    'type': 'Top>Person',
#    'score_tag': 'P'},
#   {'form': 'vidriera',
#    'id': '9b9d78cb73',
#    'type': 'Top>Product',
#    'score_tag': 'N'},
#   {'form': 'economía',
#    'id': 'a13412cf6b',
#    'type': 'Top>OtherEntity>Doctrine>Academic',
#    'score_tag': 'NONE'},
#   {'form': 'centro',
#    'id': 'a2ccefa2d4',
#    'type': 'Top>Location>Facility',
#    'score_tag': 'NONE'},
#   {'form': 'alcalde',
#    'id': 'a2d7b6d1cf',
#    'type': 'Top>OtherEntity>Title',
#    'score_tag': 'P'},
#   {'form': 'bisutería',
#    'id': 'a2ddc75c5e',
#    'type': 'Top',
#    'score_tag': 'NONE'},
#   {'form': 'juicio', 'id': 'a4dd44da0e', 'type': 'Top', 'score_tag': 'N+'},
#   {'form': 'fondo', 'id': 'a5620c3e1e', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'mayor',
#    'id': 'a5f1fcf30b',
#    'type': 'Top>OtherEntity>Title',
#    'score_tag': 'P'},
#   {'form': 'decreto', 'id': 'a91f87b48b', 'type': 'Top', 'score_tag': 'P'},
#   {'form': 'extranjero',
#    'id': 'ac7160ebb8',
#    'type': 'Top>Location',
#    'score_tag': 'P'},
#   {'form': 'artículo',
#    'id': 'ac7531be4c',
#    'type': 'Top>Product>CulturalProduct>Printing',
#    'score_tag': 'N+'},
#   {'form': 'acto',
#    'id': 'ae6d6f2e1a',
#    'type': 'Top>Process',
#    'score_tag': 'P'},
#   {'form': 'acusación',
#    'id': 'b4bf727c81',
#    'type': 'Top>Process',
#    'score_tag': 'NEU'},
#   {'form': 'clima', 'id': 'b64b638ed7', 'type': 'Top', 'score_tag': 'P'},
#   {'form': 'expulsión',
#    'id': 'b6a4439ba3',
#    'type': 'Top',
#    'score_tag': 'NONE'},
#   {'form': 'conflicto',
#    'id': 'b77d7f6ebc',
#    'type': 'Top>Event',
#    'score_tag': 'NONE'},
#   {'form': 'acto',
#    'id': 'b89ae739f1',
#    'type': 'Top>Product>CulturalProduct>Composition',
#    'score_tag': 'P'},
#   {'form': 'organización',
#    'id': 'be52c55eb3',
#    'type': 'Top>Organization',
#    'score_tag': 'P'},
#   {'form': 'actividad',
#    'id': 'bf94ecc12e',
#    'type': 'Top>Process',
#    'score_tag': 'NONE'},
#   {'form': 'testigo', 'id': 'bfa33bf4e4', 'type': 'Top', 'score_tag': 'P'},
#   {'form': 'venta', 'id': 'c0ede224ef', 'type': 'Top', 'score_tag': 'N'},
#   {'form': 'edición', 'id': 'c14ee6b27e', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'navajo',
#    'id': 'c2241eeed4',
#    'type': 'Top>Person',
#    'score_tag': 'NEU'},
#   {'form': 'acusación',
#    'id': 'c3f21e8b6f',
#    'type': 'Top>Process',
#    'score_tag': 'NEU'},
#   {'form': 'suburbano',
#    'id': 'c70a1ce1c1',
#    'type': 'Top',
#    'score_tag': 'NONE'},
#   {'form': 'violencia',
#    'id': 'cc27dae29f',
#    'type': 'Top>OtherEntity>Offence',
#    'score_tag': 'N'},
#   {'form': 'senegalés',
#    'id': 'cdd30a853d',
#    'type': 'Top>Person',
#    'score_tag': 'NONE'},
#   {'form': 'agente',
#    'id': 'ce19c885fb',
#    'type': 'Top>OtherEntity>Vocation',
#    'score_tag': 'N'},
#   {'form': 'persona',
#    'id': 'cf33ac9c72',
#    'type': 'Top>Person',
#    'score_tag': 'N'},
#   {'form': 'colectivo',
#    'id': 'cf53d01b89',
#    'type': 'Top>Organization',
#    'score_tag': 'P'},
#   {'form': 'comunidad',
#    'id': 'd03089f108',
#    'type': 'Top>Organization',
#    'score_tag': 'NONE'},
#   {'form': 'físico',
#    'id': 'd19e689ecc',
#    'type': 'Top>OtherEntity>Vocation',
#    'score_tag': 'NONE'},
#   {'form': 'físico', 'id': 'd389a8e1e9', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'presión', 'id': 'd4d51d3519', 'type': 'Top', 'score_tag': 'N'},
#   {'form': 'colectivo',
#    'id': 'd701444826',
#    'type': 'Top>Product>Machine>Vehicle',
#    'score_tag': 'P'},
#   {'form': 'cárcel',
#    'id': 'd77c78b3c8',
#    'type': 'Top>Location>Facility>Prison',
#    'score_tag': 'NONE'},
#   {'form': 'detenido', 'id': 'd7b05994d8', 'type': 'Top', 'score_tag': 'N'},
#   {'form': 'conflicto',
#    'id': 'da1d87d8db',
#    'type': 'Top>Event>War',
#    'score_tag': 'NONE'},
#   {'form': 'vendedor',
#    'id': 'dacecb32bc',
#    'type': 'Top>OtherEntity>Vocation',
#    'score_tag': 'N+'},
#   {'form': 'barrio',
#    'id': 'daef3e327d',
#    'type': 'Top>Location>GeoPoliticalEntity',
#    'score_tag': 'NONE'},
#   {'form': 'organización de la sociedad civil',
#    'id': 'db8267d2cb',
#    'type': 'Top',
#    'score_tag': 'P'},
#   {'form': 'estrategia',
#    'id': 'dd6a190986',
#    'type': 'Top',
#    'score_tag': 'NONE'},
#   {'form': 'flujo migratorio',
#    'id': 'e7bd3a4c31',
#    'type': 'Top',
#    'score_tag': 'P'},
#   {'form': 'regular',
#    'id': 'eaafc2cf24',
#    'type': 'Top>OtherEntity>Vocation',
#    'score_tag': 'NONE'},
#   {'form': 'geografía',
#    'id': 'eb8be48cf7',
#    'type': 'Top',
#    'score_tag': 'NONE'},
#   {'form': 'prejuicio', 'id': 'ecdabe0cfa', 'type': 'Top', 'score_tag': 'N'},
#   {'form': 'inmigrante',
#    'id': 'ee789984b3',
#    'type': 'Top>Person',
#    'score_tag': 'N'},
#   {'form': 'senegalés',
#    'id': 'f024c61857',
#    'type': 'Top',
#    'score_tag': 'NONE'},
#   {'form': 'vidriera',
#    'id': 'f05d3a6974',
#    'type': 'Top>Location>Facility>Market',
#    'score_tag': 'N'},
#   {'form': 'charco',
#    'id': 'f065f3b2db',
#    'type': 'Top>Location>GeographicalEntity>WaterForm',
#    'score_tag': 'N'},
#   {'form': 'experto',
#    'id': 'f24e0103b0',
#    'type': 'Top>Person',
#    'score_tag': 'NONE'},
#   {'form': 'infracción',
#    'id': 'f2dd19f6a9',
#    'type': 'Top>OtherEntity>Offence',
#    'score_tag': 'N'},
#   {'form': 'ley',
#    'id': 'f3fb3bd71d',
#    'type': 'Top>OtherEntity>Rule>LawRule',
#    'score_tag': 'N'},
#   {'form': 'ilegal', 'id': 'f6e55153cf', 'type': 'Top', 'score_tag': 'NONE'},
#   {'form': 'capital',
#    'id': 'f929e70257',
#    'type': 'Top>Location>GeoPoliticalEntity>City',
#    'score_tag': 'N'},
#   {'form': 'inconstitucionalidad',
#    'id': 'f931c51125',
#    'type': 'Top',
#    'score_tag': 'NONE'},
#   {'form': 'resistencia', 'id': 'fc6a254514', 'type': 'Top', 'score_tag': 'P'},
#   {'form': 'cuento',
#    'id': 'fd6fd10378',
#    'type': 'Top>Product>CulturalProduct>Composition',
#    'score_tag': 'P'},
#   {'form': 'plan',
#    'id': 'fdadb550e9',
#    'type': 'Top>OtherEntity>Doctrine>Plan',
#    'score_tag': 'NEU'},
#   {'form': 'hospital',
#    'id': 'ffc291e721',
#    'type': 'Top>Organization>Company>HealthcareCompany>HealthcareServicesCompany>Hospitals',
#    'score_tag': 'NONE'},
#   {'form': 'padre',
#    'id': 'ffda6eca1c',
#    'type': 'Top>Person',
#    'score_tag': 'P'}]}

# %%
#concatenamos el resultado del análisis con el corpus
analisis_final_sent = pd.concat([corpus,df], axis=1)

# %%
analisis_final_sent
# Out:
#         mes                                             Título  \
# 0     Enero  Se oficializó el decreto de necesidad y urgenc...
# 1     Enero                           El desprecio - PAGINA 12
# 2     Enero  Preocupación y desconcierto” por la reforma mi...
# 3     Enero  El Gobierno modificó la Ley de Migraciones con...
# 4     Enero  Con el DNU todos los migrantes son sospechosos...
# 5   Febrero  El éxodo de venezolanos, una preocupación para...
# 6   Febrero  Bolivia rechazó el pedido de la Argentina para...
# 7   Febrero  El 70% de los argentinos cree que los inmigran...
# 8   Febrero  Marcos Peña se manifestó a favor de que el Con...
# 9   Febrero  La lupa sobre los inmigrantes: ¿qué impacto re...
# 10  Febrero  Flexibilizan más los trámites de radicación de...
# 11  Febrero  Buenos Aires “vinotinto”: cómo viven los venez...
# 12  Febrero  Los extranjeros demandan atención médica tanto...
# 13    Marzo  Buenos Aires, ciudad de expatriados: jóvenes d...
# 14    Marzo  Inmigración venezolana: en 2017 se radicaron e...
# 15    Marzo  Se aceleró el ingreso de venezolanos al país e...
# 16    Marzo  Los colombianos, la nueva cara amable de Bueno...
# 17    Marzo  Aprender 2017: mejoró la comprensión de textos...
# 18    Marzo  La Anses dio de baja las jubilaciones de 3.700...
# 19    Marzo  "Día del Primo Argentino": la llamativa campañ...
# 20    Marzo  Aprender 2017: cómo fue el rendimiento de los ...
# 21    Marzo  #Migrantazo: mitos y luchas de los inmigrantes...
# 22    Marzo  Recibirán con una gran fiesta a los jóvenes ex...
# 23    Abril  Una cacería policial contra senegaleses - PAGI...
# 24    Abril  Internan a vendedor senegalés tras brutal repr...
# 25    Abril  Argentina ¡Migrantazo! Marcha por la anulación...
# 26    Abril  Nota entregada durante el migrantazo a ambas c...
# 27    Abril  Flores: brutal ataque de la Policía de Rodrígu...
# 28    Abril  #Migrantazo: “No hay una relación directa entr...
# 29    Abril  Flores: la Policía de Rodríguez Larreta golpeó...
# ..      ...                                                ...
# 57    Junio  Rescataron a 18 nenes bolivianos que sufrían e...
# 58    Junio  Efectivos hirieron de gravedad a un mantero2 -...
# 59    Junio  Inmigrantes senegaleses son víctimas de violen...
# 60    Junio  Un senegalés recibió un profundo corte durante...
# 61    Junio  Fuerte denuncia de Amnistía Internacional cont...
# 62    Junio  De terror: rescatan a niños que hacía trabajo ...
# 63    Junio  Liberaron a niños reducidos a la servidumbre e...
# 64    Junio  El video sobre la brutal represión de la Polic...
# 65    Junio  Efectivos hirieron de gravedad a un mantero se...
# 66    Junio           Brutalidad policial en Flores - PAGINA12
# 67    Junio  POMPEYA: ALLANAN TALLER ILEGAL Y RESCATAN A 43...
# 68    Junio  Lo que no vemos en el Parque Pereyra: tres det...
# 69    Junio  Facebook censuró revista por publicar el video...
# 70    Junio  Policía de la Ciudad hirió gravemente a un ven...
# 71    Junio  La policía de la Ciudad desalojó e hirió de gr...
# 72    Junio  Efectivos hirieron de gravedad a un mantero - ...
# 73    Junio  Un senegalés recibió un profundo corte durante...
# 74    Junio  Xenofobia: reprimen a un mantero senegalés en ...
# 75    Junio  Desnutridos, con jornadas extenuantes y en con...
# 76    Junio  Policías hirieron gravemente a un inmigrante s...
# 77    Junio  Brutalidad policial contra un mantero senegalé...
# 78    Junio  Prohibido ser negro en Buenos Aires - COSECHAROJA
# 79    Junio  Desmantelaron un taller clandestino y rescatar...
# 80    Junio  Allanaron una casa quinta y encontraron niños ...
# 81    Junio  Horror en el Parque Pereyra: rescatan a niños ...
# 82    Junio  El peligro de ser negro y querer trabajar en B...
# 83    Junio  La Policía de la Ciudad volvió a reprimir a tr...
# 84    Junio  Preocupación ante la escalada de violencia eje...
# 85    Junio  La Policía de Macri acuchilló a un mantero sen...
# 86    Junio  Cae familia que explotaba bolivianos en Beraza...
#
#                                               Noticia Polaridad       Acuerdo  \
# 0   Se oficializó el decreto de necesidad y urgenc...         N  DISAGREEMENT
# 1   29 de enero de 2017\nEl desprecio\nAunque pare...         N  DISAGREEMENT
# 2   25 de enero de 2017\nMás de 130 organizaciones...         N  DISAGREEMENT
# 3   30 de enero de 2017\nEl Gobierno modificó la L...         N  DISAGREEMENT
# 4   Críticas del CELS y Amnistía Internacional a l...       NEU  DISAGREEMENT
# 5   El éxodo de venezolanos, una preocupación para...         N  DISAGREEMENT
# 6   Bolivia rechazó el pedido de la Argentina para...       NEU  DISAGREEMENT
# 7   El 70% de los argentinos cree que los inmigran...       NEU  DISAGREEMENT
# 8   Marcos Peña se manifestó a favor de que el Con...         P  DISAGREEMENT
# 9   La lupa sobre los inmigrantes: ¿qué impacto re...       NEU  DISAGREEMENT
# 10  Flexibilizan más los trámites de radicación de...       NEU  DISAGREEMENT
# 11  Buenos Aires “vinotinto”: cómo viven los venez...         P  DISAGREEMENT
# 12  Los extranjeros demandan atención médica tanto...       NEU  DISAGREEMENT
# 13  \nTendencias\nBuenos Aires, ciudad de expatria...         P  DISAGREEMENT
# 14   Inmigración venezolana: en 2017 se radicaron ...         P  DISAGREEMENT
# 15  Se aceleró el ingreso de venezolanos al país e...         P  DISAGREEMENT
# 16  Los colombianos, la nueva cara amable de Bueno...         P  DISAGREEMENT
# 17  \n\n21/03/2018 Educación\nAprender 2017: mejor...         P  DISAGREEMENT
# 18  \n\n21/03/2018 Formosa\nLa Anses dio de baja l...       NEU  DISAGREEMENT
# 19  \nTurismo\n"Día del Primo Argentino": la llama...         P  DISAGREEMENT
# 20  Aprender 2017: cómo fue el rendimiento de los ...         P  DISAGREEMENT
# 21  \n#Migrantazo: mitos y luchas de los inmigrant...       NEU  DISAGREEMENT
# 22  Recibirán con una gran fiesta a los jóvenes ex...         P  DISAGREEMENT
# 23  20 de abril de 2018\nDetienen a 28 vendedores ...         N  DISAGREEMENT
# 24  \nPoliciales 27-04-2018 15:46\nInternan a vend...         N  DISAGREEMENT
# 25  \nArgentina ¡Migrantazo! Marcha por la anulaci...         N  DISAGREEMENT
# 26  Nota entregada durante el migrantazo a ambas c...       NEU  DISAGREEMENT
# 27  \nSociedad\nFlores: brutal ataque de la Policí...         N  DISAGREEMENT
# 28  #Migrantazo: “No hay una relación directa entr...         N  DISAGREEMENT
# 29  \nPolítica\nCIUDAD DE BUENOS AIRES\nFlores: la...         N  DISAGREEMENT
# ..                                                ...       ...           ...
# 57  Rescataron a 18 nenes bolivianos que sufrían e...         N  DISAGREEMENT
# 58  Efectivos hirieron de gravedad a un mantero\n\...         N     AGREEMENT
# 59  \nInmigrantes senegaleses son víctimas de viol...       NEU  DISAGREEMENT
# 60   7 de Junio de 2018 | 8:28 hs.\nUn senegalés r...         N  DISAGREEMENT
# 61  \nFuerte denuncia de Amnistía Internacional co...         N  DISAGREEMENT
# 62  7 Jun 2018\nDe terror: rescatan a niños que ha...         N  DISAGREEMENT
# 63  Liberaron a niños reducidos a la servidumbre e...         N  DISAGREEMENT
# 64  El video sobre la brutal represión de la Polic...         N  DISAGREEMENT
# 65  Efectivos hirieron de gravedad a un mantero se...         N  DISAGREEMENT
# 66  06 de junio de 2018\nEfectivos hirieron de gra...         N  DISAGREEMENT
# 67  POMPEYA: ALLANAN TALLER ILEGAL Y RESCATAN A 43...       NEU  DISAGREEMENT
# 68  \nLo que no vemos en el Parque Pereyra: tres d...         N  DISAGREEMENT
# 69  Sociedad / IMÁGENES SENSIBLES\nFacebook censur...         N  DISAGREEMENT
# 70  Policía de la Ciudad hirió gravemente a un ven...         N  DISAGREEMENT
# 71  La policía de la Ciudad desalojó e hirió de gr...         N  DISAGREEMENT
# 72  Flores\nEfectivos hirieron de gravedad a un ma...         N     AGREEMENT
# 73  07 de junio de 2018\nUn senegalés recibió un p...         N  DISAGREEMENT
# 74  Xenofobia: reprimen a un mantero senegalés en ...         N     AGREEMENT
# 75  \nPoliciales\nDesnutridos, con jornadas extenu...         N  DISAGREEMENT
# 76  Policías hirieron gravemente a un inmigrante s...         N  DISAGREEMENT
# 77  6 Jun 2018\nBrutalidad policial contra un mant...         N  DISAGREEMENT
# 78  \nProhibido ser negro en Buenos Aires\n05/06/2...         N  DISAGREEMENT
# 79  Desmantelaron un taller clandestino y rescatar...         N  DISAGREEMENT
# 80  \nSociedad Jueves, 7 de junio de 2018\nAllanar...         N  DISAGREEMENT
# 81  \nLa Ciudad\n\nHorror en el Parque Pereyra: re...         N  DISAGREEMENT
# 82  \nEl peligro de ser negro y querer trabajar en...         N  DISAGREEMENT
# 83  La Policía de la Ciudad volvió a reprimir a tr...         N  DISAGREEMENT
# 84  \nMigrantes\n  \n19 Jun 2018\nPreocupación ant...         N  DISAGREEMENT
# 85  \n\n    Publicado por: editor IAM\n    7 junio...         N  DISAGREEMENT
# 86  \nPoliciales 07-06-2018 18:59\nCae familia que...         N  DISAGREEMENT
#
#    Subjetividad     Ironía  Confianza
# 0    SUBJECTIVE  NONIRONIC         86
# 1    SUBJECTIVE  NONIRONIC         86
# 2    SUBJECTIVE     IRONIC         76
# 3    SUBJECTIVE  NONIRONIC         86
# 4    SUBJECTIVE     IRONIC         76
# 5    SUBJECTIVE     IRONIC         76
# 6    SUBJECTIVE  NONIRONIC         86
# 7    SUBJECTIVE  NONIRONIC         91
# 8    SUBJECTIVE     IRONIC         76
# 9    SUBJECTIVE  NONIRONIC         82
# 10   SUBJECTIVE  NONIRONIC         86
# 11   SUBJECTIVE     IRONIC         76
# 12   SUBJECTIVE  NONIRONIC         86
# 13   SUBJECTIVE  NONIRONIC         86
# 14   SUBJECTIVE  NONIRONIC         86
# 15   SUBJECTIVE  NONIRONIC         91
# 16   SUBJECTIVE  NONIRONIC         84
# 17   SUBJECTIVE  NONIRONIC         86
# 18   SUBJECTIVE  NONIRONIC         94
# 19   SUBJECTIVE  NONIRONIC         86
# 20   SUBJECTIVE  NONIRONIC         83
# 21   SUBJECTIVE     IRONIC         76
# 22   SUBJECTIVE  NONIRONIC         91
# 23   SUBJECTIVE  NONIRONIC         86
# 24   SUBJECTIVE  NONIRONIC         86
# 25   SUBJECTIVE  NONIRONIC         86
# 26   SUBJECTIVE  NONIRONIC         83
# 27   SUBJECTIVE  NONIRONIC         86
# 28   SUBJECTIVE  NONIRONIC         86
# 29   SUBJECTIVE  NONIRONIC         84
# ..          ...        ...        ...
# 57   SUBJECTIVE  NONIRONIC         91
# 58   SUBJECTIVE  NONIRONIC         89
# 59   SUBJECTIVE     IRONIC         76
# 60   SUBJECTIVE  NONIRONIC         83
# 61   SUBJECTIVE  NONIRONIC         84
# 62   SUBJECTIVE  NONIRONIC         91
# 63   SUBJECTIVE  NONIRONIC         91
# 64   SUBJECTIVE  NONIRONIC         86
# 65   SUBJECTIVE  NONIRONIC         86
# 66   SUBJECTIVE  NONIRONIC         86
# 67   SUBJECTIVE  NONIRONIC         92
# 68   SUBJECTIVE  NONIRONIC         86
# 69   SUBJECTIVE  NONIRONIC         84
# 70   SUBJECTIVE  NONIRONIC         84
# 71   SUBJECTIVE  NONIRONIC         91
# 72   SUBJECTIVE  NONIRONIC         89
# 73   SUBJECTIVE  NONIRONIC         83
# 74   SUBJECTIVE  NONIRONIC         92
# 75   SUBJECTIVE  NONIRONIC         86
# 76   SUBJECTIVE     IRONIC         84
# 77   SUBJECTIVE  NONIRONIC         86
# 78   SUBJECTIVE  NONIRONIC         86
# 79   SUBJECTIVE  NONIRONIC         86
# 80   SUBJECTIVE  NONIRONIC         91
# 81   SUBJECTIVE  NONIRONIC         91
# 82   SUBJECTIVE  NONIRONIC         86
# 83   SUBJECTIVE  NONIRONIC         86
# 84   SUBJECTIVE  NONIRONIC         84
# 85   SUBJECTIVE  NONIRONIC         86
# 86   SUBJECTIVE  NONIRONIC         86
#
# [87 rows x 8 columns]

# %%
pickle.dump(analisis_final_sent, open("sentiment_final", "wb")) #guardo nuestro nuevo dataframe en un pickle

# %% [markdown]
# ## 5. Análisis estadístico de los datos

# %%
analisis_final_sent = pickle.load(open("sentiment_final", "rb"))
#analisis_final_sent.to_csv('analisis de sentimiento.csv', encoding='utf-8', index=False, sep=',')

# %%
#vemos esadísticas básicas de nuestro dataframe, que nos tira el análisis de confidence
analisis_final_sent.describe()
# Out:
#        Confianza
# count  87.000000
# mean   85.781609
# std     4.542884
# min    74.000000
# 25%    84.000000
# 50%    86.000000
# 75%    89.000000
# max    94.000000

# %%
#especificamos un df con solo las columnas de score_tag, agreement, subjectivity y irony
analisis_simple = analisis_final_sent.iloc[:, 3:-1]

# %%
analisis_simple
# Out:
#    Polaridad       Acuerdo Subjetividad     Ironía
# 0          N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 1          N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 2          N  DISAGREEMENT   SUBJECTIVE     IRONIC
# 3          N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 4        NEU  DISAGREEMENT   SUBJECTIVE     IRONIC
# 5          N  DISAGREEMENT   SUBJECTIVE     IRONIC
# 6        NEU  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 7        NEU  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 8          P  DISAGREEMENT   SUBJECTIVE     IRONIC
# 9        NEU  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 10       NEU  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 11         P  DISAGREEMENT   SUBJECTIVE     IRONIC
# 12       NEU  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 13         P  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 14         P  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 15         P  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 16         P  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 17         P  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 18       NEU  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 19         P  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 20         P  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 21       NEU  DISAGREEMENT   SUBJECTIVE     IRONIC
# 22         P  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 23         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 24         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 25         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 26       NEU  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 27         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 28         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 29         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# ..       ...           ...          ...        ...
# 57         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 58         N     AGREEMENT   SUBJECTIVE  NONIRONIC
# 59       NEU  DISAGREEMENT   SUBJECTIVE     IRONIC
# 60         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 61         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 62         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 63         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 64         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 65         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 66         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 67       NEU  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 68         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 69         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 70         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 71         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 72         N     AGREEMENT   SUBJECTIVE  NONIRONIC
# 73         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 74         N     AGREEMENT   SUBJECTIVE  NONIRONIC
# 75         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 76         N  DISAGREEMENT   SUBJECTIVE     IRONIC
# 77         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 78         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 79         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 80         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 81         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 82         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 83         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 84         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 85         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
# 86         N  DISAGREEMENT   SUBJECTIVE  NONIRONIC
#
# [87 rows x 4 columns]

# %%
#Código de prueba para saber cuántos valores únicos (niveles) tiene una variable
analisis_simple.iloc[:,0].nunique()
# Out:
# 3

# %% [markdown]
# 1. Analizamos las polaridades (polaridad) de manera global

# %%
cuenta_score_tags = analisis_simple['Polaridad'].value_counts(normalize=True) * 100

# %%
cuenta_score_tags
# Out:
# N      58.620690
# P      24.137931
# NEU    17.241379
# Name: Polaridad, dtype: float64

# %% [markdown]
# 2. Analizamos las polaridades (agreement) de manera global

# %%
cuenta_agreement = analisis_simple['Acuerdo'].value_counts(normalize=True) * 100

# %%
cuenta_agreement
# Out:
# DISAGREEMENT    94.252874
# AGREEMENT        5.747126
# Name: Acuerdo, dtype: float64

# %% [markdown]
# 3. Analizamos las polaridades (subjectividad) de manera global

# %%
cuenta_subjectivity = analisis_simple['Subjetividad'].value_counts(normalize=True) * 100
cuenta_subjectivity
# Out:
# SUBJECTIVE    97.701149
# OBJECTIVE      2.298851
# Name: Subjetividad, dtype: float64

# %% [markdown]
# 4. Analizamos las polaridades (Ironía) de manera global y mensual

# %%
cuenta_irony = analisis_simple['Ironía'].value_counts(normalize=True) * 100
cuenta_irony
# Out:
# NONIRONIC    87.356322
# IRONIC       12.643678
# Name: Ironía, dtype: float64
